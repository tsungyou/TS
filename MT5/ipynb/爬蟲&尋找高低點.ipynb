# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
import mplfinance as mpf
print(os.getcwd())
# Out:
# c:\Users\jenny\Desktop

# %%
os.chdir('台指期資料庫')
os.getcwd()
# Out:
# 'c:\\Users\\jenny\\Desktop\\台指期資料庫'

# %%
flist = [f for f in os.listdir() if f.split(".")[-1] == "csv"]
list_ = []
for f in tqdm(flist[:], desc=f"csv concat for total of {len(list_)}"):
    df = pd.read_csv(f)
    list_.append(df)
df_final = pd.concat(list_)
df_final = pd.concat(list_, ignore_index=True)

print(df_final)

# %% [markdown]
# #分離日期、時間
# def create_da_time_column(row, create='da'):
#    da, time = row['Date'].split(" ")
#    return da if create == 'da' else time
# df_final['da'] = df_final.apply(create_da_time_column, axis=1, args=('da',))
# df_final['time'] = df_final.apply(create_da_time_column, axis=1, args=('time',))

# %%
if 'Date' in df_final.columns:
  df_final['Date'] = pd.to_datetime(df_final['Date'])

df_final.to_parquet("TW_index.parquet")

# %%
df = pd.read_parquet("TW_index.parquet")

# %%
# 使用函數計算波段高低點
def find_peaks_and_troughs(df, window_size=60):
    df['High_Rolling'] = df['High'].rolling(window=window_size, center=False).max()
    df['Low_Rolling'] = df['Low'].rolling(window=window_size, center=False).min()

    df['Peak'] = np.where(df['High'] == df['High_Rolling'], df['High'], np.nan)
    df['Trough'] = np.where(df['Low'] == df['Low_Rolling'], df['Low'], np.nan)
    
    return df

find_peaks_and_troughs(df, window_size=60)
df.drop(columns=['High_Rolling', 'Low_Rolling'], inplace=True)

# %%
#新增判斷欄位，確認Peak、Trough是否有值
df['Judge_Peak'] = df['Peak'].apply(lambda x: False if pd.isna(x) else bool(x))
df['Judge_Trough'] = df['Trough'].apply(lambda x: False if pd.isna(x) else bool(x))

# %%
start_checking = False
index_peak = None
start_checking = False
df['peaks'] = 0
#for index in tqdm(range(len(df)-1, -1, -1), desc="Checking peaks"):
for index in range (len(df)-1, -1, -1):
    # check for the first peak
    if not start_checking:
        if df.iloc[index, :]['Judge_Peak']:
            start_checking = True
            index_peak = index
    # consecutive peaks
    else:
        if df.iloc[index, :]['Judge_Peak'] and start_checking:
            index_peak = index
        elif not df.iloc[index, :]['Judge_Peak'] and not df.iloc[index, :]['Judge_Trough']:
            pass
        elif df.iloc[index, :]['Judge_Trough'] and start_checking:
            print(f"Trough found at index {index}, setting peak at index {index_peak}")  
            df.at[index_peak, 'peaks'] = 1
            index_peak = None
            start_checking = False

# %%
start_checking = False
index_trough = None
start_checking = False
df['troughs'] = 0
#for index in tqdm(range(len(df)-1, -1, -1), desc="Checking peaks"):
for index in range (len(df)-1, -1, -1):
    # check for the first peak
    if not start_checking:
        if df.iloc[index, :]['Judge_Trough']:
            start_checking = True
            index_trough = index
    # consecutive peaks
    else:
        if df.iloc[index, :]['Judge_Trough'] and start_checking:
            index_trough = index
        elif not df.iloc[index, :]['Judge_Trough'] and not df.iloc[index, :]['Judge_Peak']:
            pass
        elif df.iloc[index, :]['Judge_Peak'] and start_checking:
            print(f"True found at index {index}, setting trough at index {index_trough}")  
            df.at[index_trough, 'troughs'] = 1
            index_trough = None
            start_checking = False

# %%
df['Peak_value'] = df.apply(lambda row: row['Peak'] if row['peaks'] == 1 else None, axis=1)
df['Trough_value'] = df.apply(lambda row: row['Trough'] if row['troughs'] == 1 else None, axis=1)

# %%
df['Peak_gap'] = df['Peak_value'].ffill().diff()
df['Trough_gap'] = df['Trough_value'].ffill().diff()

df.drop(columns=['Judge_Peak','Judge_Trough'], inplace=True)

# %%
#匯出檔案至桌面
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
file_path = os.path.join(desktop_path, "output.csv")
df. to_csv(file_path, index=True)

# %%
#中途加入，匯入新的csv
desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
file_path = os.path.join(desktop_path, "output.csv")
df = pd.read_csv(file_path)

# %% [markdown]
# #計算60MA
# df['60MA'] = df['Close'].rolling(window=60).mean()
# df['60MA'] = df['60MA'].apply(lambda x: int(x) if pd.notna(x) else x)

# %%
#計算short_entry
df['short_entry'] = np.nan
df['peak_copy'] = df['Peak_gap']

# %%
for index in range (len(df)-1, -1, -1):
    if (df.iloc[index, :]['peaks'] == 1 and df.iloc[index, :]['Peak_gap'] < 0) :
        index_short = index
        print(f"True found at index {index}, setting short at index {index_short}")  
        df.at[index_short, 'short_entry'] = df.at[index_short,'Peak_value']
    elif (df.iloc[index, :]['peaks'] == 1) and (df.iloc[index, :]['peak_copy'] < 0):
        index_short = index
        print(f"True found at index {index}, setting short at index {index_short}")  
        df.at[index_short, 'short_entry'] = df.at[index_short, 'Peak_value']
        
        # 找到前一個有值的 Peak_value
        for prev_index in range(index - 1, -1, -1):
            if not pd.isna(df.iloc[prev_index]['Peak_value']):
                previous_index_short = prev_index
                df.at[previous_index_short, 'short_entry'] = df.at[previous_index_short, 'Peak_value']
                print(f"Previous valid Peak_value found at index {previous_index_short}, setting short_entry")
                break  # 找到後跳出迴圈
    else:
        df.at[index, 'Peak_value']=None
        start_index = max(0, index - 50000)
        end_index = min(len(df), index + 50000)
        df['Peak_gap'] = df['Peak_value'].ffill().diff()

df.drop(columns=['peak_copy'], inplace=True)

# %%
#計算long_entry
df['long_entry'] = np.nan
df['trough_copy'] = df['Trough_gap']

# %%
for index in range(len(df) - 1, -1, -1):
    if (df.iloc[index]['troughs'] == 1 and df.iloc[index]['Trough_gap'] > 0) :
        index_long = index
        print(f"True found at index {index}, setting short at index {index_long}")  
        df.at[index_long, 'long_entry'] = df.at[index_long, 'Trough_value']
    elif (df.iloc[index]['troughs'] == 1 and df.iloc[index]['trough_copy'] > 0):
        index_long = index
        print(f"True found at index {index}, setting short at index {index_long}")  
        df.at[index_long, 'long_entry'] = df.at[index_long, 'Trough_value']
        
        # 找到前一個有值的 Trough_value
        for prev_index in range(index - 1, -1, -1):
            if not pd.isna(df.iloc[prev_index]['Trough_value']):
                previous_index_long = prev_index
                df.at[previous_index_long, 'long_entry'] = df.at[previous_index_long, 'Trough_value']
                print(f"Previous valid Trough_value found at index {previous_index_long}, setting long_entry")
                break  # 找到後跳出迴圈
    else:
        df.at[index, 'Trough_value'] = None
        start_index = max(0, index - 50000)
        end_index = min(len(df), index + 50000)
        df.loc[start_index:end_index, 'Trough_gap'] = df.loc[start_index:end_index, 'Trough_value'].ffill().diff()

df.drop(columns=['trough_copy'], inplace=True)

# %%
df['short_gap'] = df['short_entry'].ffill().diff()
df['long_gap'] = df['long_entry'].ffill().diff()

# %%
#計算short進場點
valid_indices = df['short_entry'].dropna().index
result = {}

# 遍歷有值的索引，兩兩一組進行計算
for i in range(len(valid_indices) - 1):
    first_idx = valid_indices[i]
    second_idx = valid_indices[i + 1]
    
    # 檢查 second_idx 的 short_gap 是否小於 0
    if df.loc[second_idx, 'short_gap'] < 0:
        sum_value = df.loc[first_idx, 'short_entry'] + (2/3) * df.loc[second_idx, 'short_gap']
        result[second_idx] = sum_value

# 將結果加入 DataFrame 新欄位
df['calculated_short_entry'] = np.nan
df.loc[list(result.keys()), 'calculated_short_entry'] = list(result.values())

# %%
#計算long進場點
valid_indices = df['long_entry'].dropna().index
result = {}

# 遍歷有值的索引，兩兩一組進行計算
for i in range(len(valid_indices) - 1):
    first_idx = valid_indices[i]
    second_idx = valid_indices[i + 1]
    
    # 檢查 second_idx 的 long_gap 是否大於 0
    if df.loc[second_idx, 'long_gap'] > 0:
        sum_value = df.loc[first_idx, 'long_entry'] + (2/3) * df.loc[second_idx, 'long_gap']
        result[second_idx] = sum_value

# 將結果加入 DataFrame 新欄位
df['calculated_long_entry'] = np.nan
df.loc[list(result.keys()), 'calculated_long_entry'] = list(result.values())

# %%
#多頭進場

# 初始化必要欄位
sellshort = []
buytocover = []
#profit_dict = {}
#profit_fee_dict = {}
#profit_fee_list_realized = []
open_positions = []

feePaid = 40  # 假設每次交易手續費

# 找到符合條件的 valid_indices
valid_indices =[]
valid_indices = df[(df['calculated_short_entry'].notna())].index 

for idx in valid_indices:
    # 使用 for 迴圈尋找在 idx 之後的進場機會
    for entry_idx in range(idx + 1, len(df)):
        if df.loc[entry_idx, 'Close'] > df.loc[idx, 'calculated_short_entry']:
            target_value = round(df.loc[idx+1, 'Close'])
            sellshort.append(entry_idx) 
            open_positions.append(entry_idx)  # 記錄未平倉的進場單
            print(f"Buy at {df.loc[entry_idx, 'Date']} with target value {target_value}")
            for exit_idx in range(idx - 1, -1, -1):
                if not pd.isna(df.loc[exit_idx, 'short_entry']):
                    exit_value = df.loc[exit_idx, 'short_entry']
                    print(f"exit_value = {exit_value} at {df.loc[exit_idx, 'Date']}")
                    break

            # 出場邏輯
            for next_idx in range(entry_idx + 1, len(df)):
                # 檢查出場條件：1. Close > 前一個有值的 short_entry 或 2. 遇到 troughs == 1
                if df.loc[next_idx, 'Close'] >= exit_value :
                    profit = 50 * (exit_value - target_value)
                    profit_fee = profit - feePaid * 2
                    profit_dict[next_idx] = profit
                    print(f"profit = {profit}")
                    profit_fee_dict[next_idx] = profit_fee
                    buytocover.append(next_idx)
                    print(f"Sell to cover at {df.loc[next_idx, 'Date']} with Close {df.loc[next_idx, 'Close']}")
                    print("Trade completed\n")
                    open_positions.remove(entry_idx)

                    # Realized PnL
                    profit_fee_realized = profit - feePaid * 2
                    profit_fee_list_realized.append(profit_fee_realized)
                    break
                
                elif df.loc[next_idx, 'Judge_Trough'] == 1 :
                    profit = 50 * (df.loc[next_idx+1, 'Close'] - target_value)
                    profit_fee = profit - feePaid * 2
                    profit_dict[next_idx] = profit
                    print(f"profit = {profit}")
                    profit_fee_dict[next_idx] = profit_fee
                    buytocover.append(next_idx)
                    print(f"Sell to cover at {df.loc[next_idx, 'Date']} with Close {df.loc[next_idx, 'Close']}")
                    print("Trade completed\n")
                    open_positions.remove(entry_idx)

                    # Realized PnL
                    profit_fee_realized = profit - feePaid * 2
                    profit_fee_list_realized.append(profit_fee_realized)
                    break

            # 找到一次進場機會後跳出內層進場迴圈
            break
# Out:
# Buy at 2011/1/12 8:45 with target value 8847
# exit_value = 9005.0 at 2011/1/5 9:19
# profit = 5950.0
# Sell to cover at 2011/1/12 12:05 with Close 8971.0
# Trade completed
#
# Buy at 2011/1/6 11:22 with target value 8841
# exit_value = 8847.0 at 2011/1/5 13:12
# profit = 300.0
# Sell to cover at 2011/1/6 11:24 with Close 8852.0
# Trade completed
#
# Buy at 2011/1/11 9:17 with target value 8760
# exit_value = 8839.0 at 2011/1/6 11:17
# profit = 3950.0
# Sell to cover at 2011/1/11 9:28 with Close 8843.0
# Trade completed
#
# Buy at 2011/1/10 12:38 with target value 8763
# exit_value = 8769.0 at 2011/1/7 13:30
# profit = 300.0
# Sell to cover at 2011/1/10 12:39 with Close 8769.0
# Trade completed
#
# Buy at 2011/1/18 10:08 with target value 8942
# exit_value = 8967.0 at 2011/1/14 10:43
# profit = 1250.0
# Sell to cover at 2011/1/18 10:14 with Close 8970.0
# Trade completed
#
# Buy at 2011/1/18 9:59 with target value 8940
# exit_value = 8946.0 at 2011/1/17 11:50
# profit = 300.0
# Sell to cover at 2011/1/18 10:00 with Close 8951.0
# Trade completed
#
# Buy at 2011/1/18 9:45 with target value 8930
# exit_value = 8943.0 at 2011/1/17 13:00
# profit = 650.0
# Sell to cover at 2011/1/18 9:59 with Close 8953.0
# Trade completed
#
# Buy at 2011/1/24 13:31 with target value 8931
# exit_value = 8940.0 at 2011/1/21 10:44
# profit = 450.0
# Sell to cover at 2011/1/24 13:35 with Close 8940.0
# Trade completed
#
# Buy at 2011/4/25 8:57 with target value 8903
# exit_value = 9103.0 at 2011/2/9 10:02
# profit = 4250.0
# Sell to cover at 2011/4/25 9:24 with Close 8981.0
# Trade completed
#
# Buy at 2011/4/7 8:50 with target value 8786
# exit_value = 8916.0 at 2011/2/10 11:30
# profit = 2600.0
# Sell to cover at 2011/4/7 9:27 with Close 8834.0
# Trade completed
#
# Buy at 2011/2/16 9:15 with target value 8640
# exit_value = 8782.0 at 2011/2/11 10:38
# profit = 3500.0
# Sell to cover at 2011/2/16 10:12 with Close 8720.0
# Trade completed
#
# Buy at 2011/2/22 13:01 with target value 8600
# exit_value = 8639.0 at 2011/2/14 9:05
# profit = 1950.0
# Sell to cover at 2011/2/22 13:02 with Close 8641.0
# Trade completed
#
# Buy at 2011/2/24 10:11 with target value 8547
# exit_value = 8598.0 at 2011/2/22 12:49
# profit = 2550.0
# Sell to cover at 2011/2/24 10:24 with Close 8600.0
# Trade completed
#
# Buy at 2011/3/25 11:40 with target value 8519
# exit_value = 8638.0 at 2011/3/10 13:19
# profit = 3200.0
# Sell to cover at 2011/3/25 13:00 with Close 8582.0
# Trade completed
#
# Buy at 2011/3/14 12:51 with target value 8448
# exit_value = 8522.0 at 2011/3/11 11:14
# profit = 1900.0
# Sell to cover at 2011/3/15 8:48 with Close 8482.0
# Trade completed
#
# Buy at 2011/3/16 8:45 with target value 8180
# exit_value = 8453.0 at 2011/3/14 12:30
# profit = 5350.0
# Sell to cover at 2011/3/16 9:44 with Close 8298.0
# Trade completed
#
# Buy at 2011/4/14 11:17 with target value 8732
# exit_value = 8852.0 at 2011/4/11 12:28
# profit = 2800.0
# Sell to cover at 2011/4/14 12:01 with Close 8782.0
# Trade completed
#
# Buy at 2011/4/13 11:37 with target value 8716
# exit_value = 8737.0 at 2011/4/12 11:44
# profit = 1050.0
# Sell to cover at 2011/4/13 11:38 with Close 8738.0
# Trade completed
#
# Buy at 2011/4/20 9:14 with target value 8708
# exit_value = 8722.0 at 2011/4/13 10:59
# profit = 700.0
# Sell to cover at 2011/4/20 9:15 with Close 8729.0
# Trade completed
#
# Buy at 2011/4/20 8:45 with target value 8623
# exit_value = 8716.0 at 2011/4/18 13:01
# profit = 4650.0
# Sell to cover at 2011/4/20 9:14 with Close 8723.0
# Trade completed
#
# Buy at 2011/4/19 12:38 with target value 8613
# exit_value = 8622.0 at 2011/4/19 11:00
# profit = 450.0
# Sell to cover at 2011/4/19 12:39 with Close 8625.0
# Trade completed
#
# Buy at 2011/4/27 8:45 with target value 8965
# exit_value = 8990.0 at 2011/4/22 13:15
# profit = 1250.0
# Sell to cover at 2011/4/27 8:46 with Close 9061.0
# Trade completed
#
# Buy at 2011/4/26 13:32 with target value 8921
# exit_value = 8978.0 at 2011/4/26 9:39
# profit = 2850.0
# Sell to cover at 2011/4/27 8:45 with Close 9064.0
# Trade completed
#
# Buy at 2011/4/29 13:41 with target value 8992
# exit_value = 9036.0 at 2011/4/29 9:59
# profit = 2200.0
# Sell to cover at 2011/5/3 8:45 with Close 9047.0
# Trade completed
#
# Buy at 2011/5/5 10:06 with target value 8935
# exit_value = 9000.0 at 2011/4/29 13:30
# profit = 3250.0
# Sell to cover at 2011/5/5 10:19 with Close 9016.0
# Trade completed
#
# Buy at 2011/5/4 12:44 with target value 8910
# exit_value = 8938.0 at 2011/5/3 12:08
# profit = 1400.0
# Sell to cover at 2011/5/4 13:13 with Close 8939.0
# Trade completed
#
# Buy at 2011/5/4 12:38 with target value 8902
# exit_value = 8915.0 at 2011/5/4 10:28
# profit = 650.0
# Sell to cover at 2011/5/4 12:39 with Close 8920.0
# Trade completed
#
# Buy at 2011/5/19 9:15 with target value 8953
# exit_value = 8989.0 at 2011/5/16 10:45
# profit = 1800.0
# Sell to cover at 2011/5/19 9:16 with Close 8994.0
# Trade completed
#
# Buy at 2011/5/19 8:45 with target value 8918
# exit_value = 8957.0 at 2011/5/16 12:44
# profit = 1950.0
# Sell to cover at 2011/5/19 8:47 with Close 8965.0
# Trade completed
#
# Buy at 2011/5/17 11:54 with target value 8892
# exit_value = 8928.0 at 2011/5/17 9:55
# profit = 1800.0
# Sell to cover at 2011/5/17 12:48 with Close 8933.0
# Trade completed
#
# Buy at 2011/5/31 8:45 with target value 8734
# exit_value = 8905.0 at 2011/5/20 10:13
# profit = 8550.0
# Sell to cover at 2011/5/31 9:50 with Close 8906.0
# Trade completed
#
# Buy at 2011/5/24 11:25 with target value 8712
# exit_value = 8739.0 at 2011/5/23 10:44
# profit = 1350.0
# Sell to cover at 2011/5/24 11:27 with Close 8739.0
# Trade completed
#
# Buy at 2011/5/25 12:34 with target value 8691
# exit_value = 8725.0 at 2011/5/24 11:08
# profit = 1700.0
# Sell to cover at 2011/5/25 12:35 with Close 8728.0
# Trade completed
#
# Buy at 2011/6/7 11:30 with target value 9013
# exit_value = 9018.0 at 2011/6/7 10:15
# profit = 250.0
# Sell to cover at 2011/6/7 11:31 with Close 9026.0
# Trade completed
#
# Buy at 2011/6/9 12:36 with target value 9030
# exit_value = 9040.0 at 2011/6/9 10:38
# profit = 500.0
# Sell to cover at 2011/6/9 12:48 with Close 9041.0
# Trade completed
#
# Buy at 2014/4/16 13:21 with target value 8794
# exit_value = 9029.0 at 2011/6/9 12:30
# profit = 4900.0
# Sell to cover at 2014/4/17 8:45 with Close 8893.0
# Trade completed
#
# Buy at 2011/6/14 10:03 with target value 8739
# exit_value = 8805.0 at 2011/6/13 10:10
# profit = 3300.0
# Sell to cover at 2011/6/14 10:22 with Close 8815.0
# Trade completed
#
# Buy at 2011/7/6 9:29 with target value 8525
# exit_value = 8738.0 at 2011/6/13 13:41
# profit = 8250.0
# Sell to cover at 2011/7/6 12:36 with Close 8693.0
# Trade completed
#
# Buy at 2011/6/17 8:51 with target value 8512
# exit_value = 8529.0 at 2011/6/16 10:41
# profit = 850.0
# Sell to cover at 2011/6/17 8:56 with Close 8533.0
# Trade completed
#
# Buy at 2011/6/17 11:15 with target value 8479
# exit_value = 8520.0 at 2011/6/17 8:46
# profit = 2050.0
# Sell to cover at 2011/6/17 11:20 with Close 8525.0
# Trade completed
#
# Buy at 2011/6/21 8:45 with target value 8400
# exit_value = 8494.0 at 2011/6/17 11:01
# profit = 1150.0
# Sell to cover at 2011/6/21 10:32 with Close 8418.0
# Trade completed
#
# Buy at 2011/6/28 8:45 with target value 8294
# exit_value = 8398.0 at 2011/6/24 12:09
# profit = 3700.0
# Sell to cover at 2011/6/28 11:01 with Close 8366.0
# Trade completed
#
# Buy at 2011/7/20 12:32 with target value 8606
# exit_value = 8686.0 at 2011/7/8 13:03
# profit = 4000.0
# Sell to cover at 2011/7/20 12:58 with Close 8695.0
# Trade completed
#
# Buy at 2011/7/20 8:45 with target value 8602
# exit_value = 8610.0 at 2011/7/11 11:00
# profit = 400.0
# Sell to cover at 2011/7/20 8:46 with Close 8627.0
# Trade completed
#
# Buy at 2011/7/15 13:33 with target value 8461
# exit_value = 8603.0 at 2011/7/11 12:14
# profit = 2900.0
# Sell to cover at 2011/7/18 8:45 with Close 8517.0
# Trade completed
#
# Buy at 2011/7/13 10:26 with target value 8439
# exit_value = 8464.0 at 2011/7/12 11:59
# profit = 1250.0
# Sell to cover at 2011/7/13 10:27 with Close 8464.0
# Trade completed
#
# Buy at 2011/7/14 13:17 with target value 8405
# exit_value = 8450.0 at 2011/7/13 9:28
# profit = 2250.0
# Sell to cover at 2011/7/14 13:23 with Close 8452.0
# Trade completed
#
# Buy at 2011/7/26 8:46 with target value 8617
# exit_value = 8636.0 at 2011/7/21 12:59
# profit = 950.0
# Sell to cover at 2011/7/26 8:47 with Close 8638.0
# Trade completed
#
# Buy at 2014/3/6 12:55 with target value 8686
# exit_value = 8715.0 at 2011/7/28 13:36
# profit = 1450.0
# Sell to cover at 2014/3/7 8:45 with Close 8731.0
# Trade completed
#
# Buy at 2013/12/31 8:45 with target value 8578
# exit_value = 8688.0 at 2011/8/1 11:00
# profit = 3050.0
# Sell to cover at 2013/12/31 11:38 with Close 8638.0
# Trade completed
#
# Buy at 2013/12/30 9:09 with target value 8563
# exit_value = 8587.0 at 2011/8/2 11:11
# profit = 1200.0
# Sell to cover at 2013/12/30 9:12 with Close 8589.0
# Trade completed
#
# Buy at 2013/12/27 9:44 with target value 8408
# exit_value = 8566.0 at 2011/8/2 13:00
# profit = 6200.0
# Sell to cover at 2013/12/27 12:02 with Close 8530.0
# Trade completed
#
# Buy at 2013/5/8 9:46 with target value 7910
# exit_value = 8416.0 at 2011/8/3 10:43
# profit = 17650.0
# Sell to cover at 2013/5/8 11:01 with Close 8264.0
# Trade completed
#
# Buy at 2012/2/8 13:23 with target value 7765
# exit_value = 7933.0 at 2011/8/5 10:04
# profit = 3600.0
# Sell to cover at 2012/2/9 8:55 with Close 7842.0
# Trade completed
#
# Buy at 2011/8/10 9:00 with target value 7530
# exit_value = 7765.0 at 2011/8/8 9:44
# profit = 3150.0
# Sell to cover at 2011/8/10 9:52 with Close 7608.0
# Trade completed
#
# Buy at 2011/8/9 11:37 with target value 7233
# exit_value = 7522.0 at 2011/8/8 13:28
# profit = 14450.0
# Sell to cover at 2011/8/9 12:11 with Close 7536.0
# Trade completed
#
# Buy at 2011/8/31 13:31 with target value 7500
# exit_value = 7790.0 at 2011/8/17 10:57
# profit = 14500.0
# Sell to cover at 2011/9/1 9:15 with Close 7790.0
# Trade completed
#
# Buy at 2011/8/23 12:45 with target value 7339
# exit_value = 7505.0 at 2011/8/18 13:15
# profit = 8300.0
# Sell to cover at 2011/8/23 13:13 with Close 7512.0
# Trade completed
#
# Buy at 2011/8/22 9:12 with target value 7279
# exit_value = 7355.0 at 2011/8/19 10:19
# profit = 3800.0
# Sell to cover at 2011/8/22 9:14 with Close 7355.0
# Trade completed
#
# Buy at 2011/9/7 13:28 with target value 7477
# exit_value = 7518.0 at 2011/9/5 10:58
# profit = 2050.0
# Sell to cover at 2011/9/7 13:30 with Close 7528.0
# Trade completed
#
# Buy at 2011/9/7 12:13 with target value 7456
# exit_value = 7488.0 at 2011/9/6 9:41
# profit = 1600.0
# Sell to cover at 2011/9/7 12:14 with Close 7497.0
# Trade completed
#
# Buy at 2011/9/7 12:10 with target value 7439
# exit_value = 7478.0 at 2011/9/7 8:45
# profit = 1950.0
# Sell to cover at 2011/9/7 12:13 with Close 7486.0
# Trade completed
#
# Buy at 2011/9/14 8:48 with target value 7428
# exit_value = 7448.0 at 2011/9/13 11:26
# profit = 1000.0
# Sell to cover at 2011/9/14 8:54 with Close 7450.0
# Trade completed
#
# Buy at 2011/9/15 8:45 with target value 7247
# exit_value = 7418.0 at 2011/9/14 8:45
# profit = 5300.0
# Sell to cover at 2011/9/15 9:44 with Close 7348.0
# Trade completed
#
# Buy at 2011/9/30 9:04 with target value 7040
# exit_value = 7286.0 at 2011/9/22 12:14
# profit = 6350.0
# Sell to cover at 2011/9/30 10:00 with Close 7164.0
# Trade completed
#
# Buy at 2011/10/4 13:28 with target value 6988
# exit_value = 7093.0 at 2011/9/29 9:55
# profit = 5250.0
# Sell to cover at 2011/10/4 13:44 with Close 7094.0
# Trade completed
#
# Buy at 2011/10/3 13:41 with target value 7000
# exit_value = 6997.0 at 2011/10/3 12:15
# profit = -150.0
# Sell to cover at 2011/10/3 13:42 with Close 7012.0
# Trade completed
#
# Buy at 2011/10/19 8:48 with target value 7333
# exit_value = 7384.0 at 2011/10/14 11:58
# profit = 1200.0
# Sell to cover at 2011/10/19 9:46 with Close 7357.0
# Trade completed
#
# Buy at 2011/10/24 8:45 with target value 7281
# exit_value = 7340.0 at 2011/10/18 11:49
# profit = 2950.0
# Sell to cover at 2011/10/24 8:46 with Close 7402.0
# Trade completed
#
# Buy at 2011/10/24 8:45 with target value 7238
# exit_value = 7282.0 at 2011/10/20 12:01
# profit = 2200.0
# Sell to cover at 2011/10/24 8:46 with Close 7402.0
# Trade completed
#
# Buy at 2011/10/21 13:08 with target value 7218
# exit_value = 7246.0 at 2011/10/21 9:41
# profit = 1400.0
# Sell to cover at 2011/10/21 13:14 with Close 7248.0
# Trade completed
#
# Buy at 2011/11/1 10:38 with target value 7642
# exit_value = 7671.0 at 2011/10/31 8:45
# profit = 1450.0
# Sell to cover at 2011/11/1 10:39 with Close 7671.0
# Trade completed
#
# Buy at 2011/11/1 10:04 with target value 7597
# exit_value = 7650.0 at 2011/10/31 10:59
# profit = 2650.0
# Sell to cover at 2011/11/1 10:37 with Close 7656.0
# Trade completed
#
# Buy at 2011/11/1 9:51 with target value 7584
# exit_value = 7609.0 at 2011/10/31 12:55
# profit = 1250.0
# Sell to cover at 2011/11/1 9:52 with Close 7614.0
# Trade completed
#
# Buy at 2011/11/2 11:52 with target value 7552
# exit_value = 7584.0 at 2011/11/1 9:44
# profit = 1600.0
# Sell to cover at 2011/11/2 11:57 with Close 7584.0
# Trade completed
#
# Buy at 2011/11/4 8:45 with target value 7520
# exit_value = 7558.0 at 2011/11/2 10:10
# profit = 1900.0
# Sell to cover at 2011/11/4 8:46 with Close 7595.0
# Trade completed
#
# Buy at 2011/11/8 13:00 with target value 7627
# exit_value = 7637.0 at 2011/11/7 13:43
# profit = 500.0
# Sell to cover at 2011/11/8 13:03 with Close 7637.0
# Trade completed
#
# Buy at 2012/2/2 8:45 with target value 7436
# exit_value = 7625.0 at 2011/11/8 12:56
# profit = 9450.0
# Sell to cover at 2012/2/2 8:46 with Close 7628.0
# Trade completed
#
# Buy at 2011/11/14 9:07 with target value 7329
# exit_value = 7615.0 at 2011/11/9 13:44
# profit = 10650.0
# Sell to cover at 2011/11/14 10:30 with Close 7541.0
# Trade completed
#
# Buy at 2011/11/16 8:59 with target value 7519
# exit_value = 7549.0 at 2011/11/15 9:00
# profit = 1500.0
# Sell to cover at 2011/11/16 9:05 with Close 7554.0
# Trade completed
#
# Buy at 2011/11/16 8:45 with target value 7505
# exit_value = 7525.0 at 2011/11/15 11:49
# profit = 1000.0
# Sell to cover at 2011/11/16 8:46 with Close 7527.0
# Trade completed
#
# Buy at 2012/1/31 10:35 with target value 7430
# exit_value = 7504.0 at 2011/11/15 13:33
# profit = 2450.0
# Sell to cover at 2012/1/31 11:38 with Close 7476.0
# Trade completed
#
# Buy at 2012/1/30 9:12 with target value 7369
# exit_value = 7435.0 at 2011/11/16 12:21
# profit = 3300.0
# Sell to cover at 2012/1/30 9:15 with Close 7445.0
# Trade completed
#
# Buy at 2012/1/30 8:45 with target value 7315
# exit_value = 7382.0 at 2011/11/17 9:52
# profit = 3350.0
# Sell to cover at 2012/1/30 8:52 with Close 7382.0
# Trade completed
#
# Buy at 2011/12/1 12:16 with target value 7090
# exit_value = 7321.0 at 2011/11/18 10:19
# profit = 6750.0
# Sell to cover at 2011/12/1 13:03 with Close 7229.0
# Trade completed
#
# Buy at 2011/12/1 8:45 with target value 7072
# exit_value = 7093.0 at 2011/11/21 12:22
# profit = 1050.0
# Sell to cover at 2011/12/1 8:46 with Close 7172.0
# Trade completed
#
# Buy at 2011/12/1 8:45 with target value 7026
# exit_value = 7083.0 at 2011/11/22 10:39
# profit = 2850.0
# Sell to cover at 2011/12/1 8:46 with Close 7172.0
# Trade completed
#
# Buy at 2011/11/29 13:06 with target value 6867
# exit_value = 7035.0 at 2011/11/22 12:54
# profit = 3850.0
# Sell to cover at 2011/11/30 8:45 with Close 6945.0
# Trade completed
#
# Buy at 2011/11/24 10:38 with target value 6843
# exit_value = 6885.0 at 2011/11/23 12:46
# profit = 2100.0
# Sell to cover at 2011/11/24 10:44 with Close 6892.0
# Trade completed
#
# Buy at 2011/11/28 8:45 with target value 6805
# exit_value = 6851.0 at 2011/11/24 10:25
# profit = 2300.0
# Sell to cover at 2011/11/28 8:46 with Close 6890.0
# Trade completed
#
# Buy at 2011/12/23 10:13 with target value 7028
# exit_value = 7130.0 at 2011/12/5 11:50
# profit = 4100.0
# Sell to cover at 2011/12/23 13:15 with Close 7109.0
# Trade completed
#
# Buy at 2011/12/12 9:06 with target value 6931
# exit_value = 7028.0 at 2011/12/7 8:45
# profit = 1850.0
# Sell to cover at 2011/12/12 10:20 with Close 6965.0
# Trade completed
#
# Buy at 2011/12/9 10:37 with target value 6887
# exit_value = 6938.0 at 2011/12/8 11:17
# profit = -300.0
# Sell to cover at 2011/12/9 11:05 with Close 6886.0
# Trade completed
#
# Buy at 2011/12/13 12:09 with target value 6884
# exit_value = 6894.0 at 2011/12/9 9:58
# profit = 500.0
# Sell to cover at 2011/12/13 12:10 with Close 6903.0
# Trade completed
#
# Buy at 2011/12/22 8:45 with target value 6801
# exit_value = 6872.0 at 2011/12/13 9:54
# profit = 3550.0
# Sell to cover at 2011/12/22 8:46 with Close 6955.0
# Trade completed
#
# Buy at 2011/12/16 12:27 with target value 6776
# exit_value = 6804.0 at 2011/12/15 11:03
# profit = 550.0
# Sell to cover at 2011/12/16 12:54 with Close 6787.0
# Trade completed
#
# Buy at 2011/12/16 11:24 with target value 6767
# exit_value = 6784.0 at 2011/12/16 9:12
# profit = 850.0
# Sell to cover at 2011/12/16 11:33 with Close 6793.0
# Trade completed
#
# Buy at 2011/12/22 8:45 with target value 6653
# exit_value = 6770.0 at 2011/12/16 11:13
# profit = 5850.0
# Sell to cover at 2011/12/22 8:46 with Close 6955.0
# Trade completed
#
# Buy at 2012/1/3 8:45 with target value 6960
# exit_value = 7034.0 at 2011/12/29 9:46
# profit = 3700.0
# Sell to cover at 2012/1/3 9:47 with Close 7034.0
# Trade completed
#
# Buy at 2012/1/17 8:45 with target value 7095
# exit_value = 7182.0 at 2012/1/12 12:26
# profit = 4350.0
# Sell to cover at 2012/1/17 11:01 with Close 7182.0
# Trade completed
#
# Buy at 2012/2/21 13:38 with target value 7903
# exit_value = 7936.0 at 2012/2/17 12:16
# profit = 1650.0
# Sell to cover at 2012/2/21 13:39 with Close 7940.0
# Trade completed
#
# Buy at 2012/2/21 13:16 with target value 7905
# exit_value = 7929.0 at 2012/2/21 10:56
# profit = 1200.0
# Sell to cover at 2012/2/21 13:26 with Close 7930.0
# Trade completed
#
# Buy at 2012/3/3 13:20 with target value 8117
# exit_value = 8127.0 at 2012/3/3 9:54
# profit = -1450.0
# Sell to cover at 2012/3/5 8:45 with Close 8101.0
# Trade completed
#
# Buy at 2012/3/3 12:38 with target value 8119
# exit_value = 8120.0 at 2012/3/3 11:01
# profit = 50.0
# Sell to cover at 2012/3/3 12:39 with Close 8120.0
# Trade completed
#
# Buy at 2012/3/14 8:45 with target value 8026
# exit_value = 8119.0 at 2012/3/3 12:35
# profit = 4650.0
# Sell to cover at 2012/3/14 8:46 with Close 8164.0
# Trade completed
#
# Buy at 2012/3/8 11:10 with target value 7914
# exit_value = 8032.0 at 2012/3/5 11:44
# profit = 3350.0
# Sell to cover at 2012/3/8 12:10 with Close 7980.0
# Trade completed
#
# Buy at 2012/3/8 8:45 with target value 7905
# exit_value = 7913.0 at 2012/3/6 12:57
# profit = 400.0
# Sell to cover at 2012/3/8 8:46 with Close 7938.0
# Trade completed
#
# Buy at 2013/5/2 11:42 with target value 8113
# exit_value = 8128.0 at 2012/3/15 11:20
# profit = 150.0
# Sell to cover at 2013/5/2 12:48 with Close 8115.0
# Trade completed
#
# Buy at 2013/4/30 9:28 with target value 8107
# exit_value = 8117.0 at 2012/3/16 12:05
# profit = 500.0
# Sell to cover at 2013/4/30 9:29 with Close 8120.0
# Trade completed
#
# Buy at 2012/3/22 10:05 with target value 8038
# exit_value = 8113.0 at 2012/3/19 8:45
# profit = 1900.0
# Sell to cover at 2012/3/22 10:31 with Close 8069.0
# Trade completed
#
# Buy at 2012/3/22 9:14 with target value 8006
# exit_value = 8029.0 at 2012/3/19 11:40
# profit = 1150.0
# Sell to cover at 2012/3/22 9:15 with Close 8064.0
# Trade completed
#
# Buy at 2012/3/21 9:08 with target value 7990
# exit_value = 8009.0 at 2012/3/20 11:34
# profit = 950.0
# Sell to cover at 2012/3/21 9:09 with Close 8014.0
# Trade completed
#
# Buy at 2012/3/21 12:38 with target value 7979
# exit_value = 7994.0 at 2012/3/21 9:00
# profit = 750.0
# Sell to cover at 2012/3/22 8:45 with Close 8014.0
# Trade completed
#
# Buy at 2012/3/27 8:45 with target value 7955
# exit_value = 7978.0 at 2012/3/21 12:30
# profit = 1150.0
# Sell to cover at 2012/3/27 8:46 with Close 7992.0
# Trade completed
#
# Buy at 2013/2/4 9:36 with target value 7871
# exit_value = 7957.0 at 2012/3/26 12:33
# profit = 2450.0
# Sell to cover at 2013/2/4 10:50 with Close 7922.0
# Trade completed
#
# Buy at 2012/3/30 10:16 with target value 7864
# exit_value = 7872.0 at 2012/3/29 13:22
# profit = 400.0
# Sell to cover at 2012/3/30 12:40 with Close 7877.0
# Trade completed
#
# Buy at 2012/4/2 11:27 with target value 7860
# exit_value = 7868.0 at 2012/3/30 10:07
# profit = 400.0
# Sell to cover at 2012/4/2 11:30 with Close 7871.0
# Trade completed
#
# Buy at 2013/1/3 8:55 with target value 7764
# exit_value = 7865.0 at 2012/4/2 11:17
# profit = 2500.0
# Sell to cover at 2013/1/3 11:28 with Close 7815.0
# Trade completed
#
# Buy at 2012/4/13 8:46 with target value 7589
# exit_value = 7768.0 at 2012/4/3 13:20
# profit = 6600.0
# Sell to cover at 2012/4/13 10:44 with Close 7723.0
# Trade completed
#
# Buy at 2012/4/9 10:48 with target value 7585
# exit_value = 7604.0 at 2012/4/5 10:11
# profit = 950.0
# Sell to cover at 2012/4/9 10:49 with Close 7607.0
# Trade completed
#
# Buy at 2012/9/14 9:28 with target value 7675
# exit_value = 7723.0 at 2012/4/17 8:46
# profit = 2400.0
# Sell to cover at 2012/9/14 11:59 with Close 7723.0
# Trade completed
#
# Buy at 2012/5/2 12:18 with target value 7629
# exit_value = 7692.0 at 2012/4/18 8:45
# profit = 1300.0
# Sell to cover at 2012/5/3 9:00 with Close 7659.0
# Trade completed
#
# Buy at 2012/5/2 11:17 with target value 7615
# exit_value = 7634.0 at 2012/4/18 11:15
# profit = 950.0
# Sell to cover at 2012/5/2 11:19 with Close 7638.0
# Trade completed
#
# Buy at 2012/4/19 13:27 with target value 7606
# exit_value = 7615.0 at 2012/4/19 10:37
# profit = 450.0
# Sell to cover at 2012/4/19 13:34 with Close 7615.0
# Trade completed
#
# Buy at 2012/4/25 9:15 with target value 7478
# exit_value = 7606.0 at 2012/4/19 13:23
# profit = 2200.0
# Sell to cover at 2012/4/25 9:59 with Close 7522.0
# Trade completed
#
# Buy at 2012/4/24 9:12 with target value 7472
# exit_value = 7484.0 at 2012/4/23 11:02
# profit = 600.0
# Sell to cover at 2012/4/24 9:35 with Close 7486.0
# Trade completed
#
# Buy at 2012/4/24 12:59 with target value 7463
# exit_value = 7474.0 at 2012/4/23 13:24
# profit = 550.0
# Sell to cover at 2012/4/24 13:00 with Close 7476.0
# Trade completed
#
# Buy at 2012/4/30 13:34 with target value 7440
# exit_value = 7476.0 at 2012/4/27 11:31
# profit = 1800.0
# Sell to cover at 2012/5/2 8:45 with Close 7504.0
# Trade completed
#
# Buy at 2012/8/9 11:44 with target value 7376
# exit_value = 7452.0 at 2012/5/9 12:20
# profit = 3000.0
# Sell to cover at 2012/8/9 13:30 with Close 7433.0
# Trade completed
#
# Buy at 2012/5/14 11:48 with target value 7355
# exit_value = 7379.0 at 2012/5/11 12:49
# profit = 1200.0
# Sell to cover at 2012/5/14 11:54 with Close 7382.0
# Trade completed
#
# Buy at 2012/5/15 10:09 with target value 7348
# exit_value = 7364.0 at 2012/5/14 10:55
# profit = -550.0
# Sell to cover at 2012/5/15 10:57 with Close 7333.0
# Trade completed
#
# Buy at 2012/5/17 13:01 with target value 7289
# exit_value = 7348.0 at 2012/5/15 9:59
# profit = 1300.0
# Sell to cover at 2012/5/17 13:42 with Close 7316.0
# Trade completed
#
# Buy at 2012/5/17 11:09 with target value 7280
# exit_value = 7295.0 at 2012/5/17 9:09
# profit = 750.0
# Sell to cover at 2012/5/17 11:11 with Close 7296.0
# Trade completed
#
# Buy at 2012/5/29 9:45 with target value 7209
# exit_value = 7285.0 at 2012/5/17 10:45
# profit = 3800.0
# Sell to cover at 2012/5/29 11:14 with Close 7285.0
# Trade completed
#
# Buy at 2012/5/21 9:33 with target value 7179
# exit_value = 7214.0 at 2012/5/18 9:44
# profit = 100.0
# Sell to cover at 2012/5/21 10:31 with Close 7181.0
# Trade completed
#
# Buy at 2012/5/29 9:09 with target value 7153
# exit_value = 7186.0 at 2012/5/21 8:45
# profit = 1650.0
# Sell to cover at 2012/5/29 9:14 with Close 7215.0
# Trade completed
#
# Buy at 2012/5/24 8:45 with target value 7132
# exit_value = 7170.0 at 2012/5/23 10:00
# profit = 1900.0
# Sell to cover at 2012/5/24 9:33 with Close 7170.0
# Trade completed
#
# Buy at 2012/5/24 13:35 with target value 7107
# exit_value = 7129.0 at 2012/5/23 13:41
# profit = 1100.0
# Sell to cover at 2012/5/24 13:39 with Close 7131.0
# Trade completed
#
# Buy at 2012/5/28 12:16 with target value 7078
# exit_value = 7114.0 at 2012/5/24 12:31
# profit = 1800.0
# Sell to cover at 2012/5/28 12:25 with Close 7116.0
# Trade completed
#
# Buy at 2012/6/1 10:34 with target value 7152
# exit_value = 7154.0 at 2012/5/31 12:17
# profit = 100.0
# Sell to cover at 2012/6/1 10:35 with Close 7157.0
# Trade completed
#
# Buy at 2012/6/7 8:45 with target value 6908
# exit_value = 7153.0 at 2012/6/1 10:32
# profit = 8300.0
# Sell to cover at 2012/6/7 10:07 with Close 7071.0
# Trade completed
#
# Buy at 2012/6/5 8:45 with target value 6867
# exit_value = 6908.0 at 2012/6/4 10:17
# profit = 2050.0
# Sell to cover at 2012/6/5 8:46 with Close 6954.0
# Trade completed
#
# Buy at 2012/6/11 8:45 with target value 6977
# exit_value = 7050.0 at 2012/6/7 13:39
# profit = 3650.0
# Sell to cover at 2012/6/11 8:46 with Close 7089.0
# Trade completed
#
# Buy at 2012/6/11 8:45 with target value 6964
# exit_value = 6988.0 at 2012/6/8 10:53
# profit = 1200.0
# Sell to cover at 2012/6/11 8:46 with Close 7089.0
# Trade completed
#
# Buy at 2012/7/3 9:54 with target value 7109
# exit_value = 7249.0 at 2012/6/19 13:25
# profit = 7000.0
# Sell to cover at 2012/7/3 10:28 with Close 7249.0
# Trade completed
#
# Buy at 2012/6/29 11:00 with target value 7042
# exit_value = 7112.0 at 2012/6/21 12:50
# profit = 3500.0
# Sell to cover at 2012/6/29 11:41 with Close 7115.0
# Trade completed
#
# Buy at 2012/6/28 8:45 with target value 6964
# exit_value = 7042.0 at 2012/6/22 10:33
# profit = 2350.0
# Sell to cover at 2012/6/28 9:44 with Close 7011.0
# Trade completed
#
# Buy at 2012/6/27 9:36 with target value 6953
# exit_value = 6967.0 at 2012/6/25 10:36
# profit = 700.0
# Sell to cover at 2012/6/27 9:38 with Close 6968.0
# Trade completed
#
# Buy at 2012/6/27 9:36 with target value 6950
# exit_value = 6960.0 at 2012/6/26 8:45
# profit = 500.0
# Sell to cover at 2012/6/27 9:37 with Close 6965.0
# Trade completed
#
# Buy at 2012/6/27 9:29 with target value 6939
# exit_value = 6951.0 at 2012/6/26 9:55
# profit = 600.0
# Sell to cover at 2012/6/27 9:30 with Close 6952.0
# Trade completed
#
# Buy at 2012/7/10 8:45 with target value 7239
# exit_value = 7252.0 at 2012/7/6 13:01
# profit = 650.0
# Sell to cover at 2012/7/10 8:46 with Close 7258.0
# Trade completed
#
# Buy at 2012/8/6 8:45 with target value 7181
# exit_value = 7243.0 at 2012/7/9 12:17
# profit = 3100.0
# Sell to cover at 2012/8/6 8:46 with Close 7288.0
# Trade completed
#
# Buy at 2012/7/11 10:19 with target value 7169
# exit_value = 7184.0 at 2012/7/10 12:32
# profit = 750.0
# Sell to cover at 2012/7/11 10:23 with Close 7186.0
# Trade completed
#
# Buy at 2012/7/31 10:14 with target value 7102
# exit_value = 7170.0 at 2012/7/11 9:44
# profit = 1550.0
# Sell to cover at 2012/7/31 11:28 with Close 7132.0
# Trade completed
#
# Buy at 2012/7/13 9:45 with target value 7087
# exit_value = 7114.0 at 2012/7/12 11:44
# profit = -1100.0
# Sell to cover at 2012/7/13 11:12 with Close 7063.0
# Trade completed
#
# Buy at 2012/7/17 9:16 with target value 7060
# exit_value = 7085.0 at 2012/7/12 13:15
# profit = 1250.0
# Sell to cover at 2012/7/17 9:18 with Close 7091.0
# Trade completed
#
# Buy at 2012/7/30 8:45 with target value 6975
# exit_value = 7065.0 at 2012/7/16 11:42
# profit = 4500.0
# Sell to cover at 2012/7/30 8:46 with Close 7073.0
# Trade completed
#
# Buy at 2012/7/27 8:45 with target value 6861
# exit_value = 6982.0 at 2012/7/19 9:55
# profit = 6050.0
# Sell to cover at 2012/7/27 10:13 with Close 6986.0
# Trade completed
#
# Buy at 2012/8/21 8:45 with target value 7419
# exit_value = 7463.0 at 2012/8/15 12:59
# profit = 2200.0
# Sell to cover at 2012/8/21 8:46 with Close 7465.0
# Trade completed
#
# Buy at 2012/8/27 12:01 with target value 7472
# exit_value = 7476.0 at 2012/8/24 9:57
# profit = 200.0
# Sell to cover at 2012/8/27 12:02 with Close 7480.0
# Trade completed
#
# Buy at 2012/9/3 10:10 with target value 7388
# exit_value = 7475.0 at 2012/8/27 10:55
# profit = 3500.0
# Sell to cover at 2012/9/3 12:25 with Close 7458.0
# Trade completed
#
# Buy at 2012/8/31 8:50 with target value 7361
# exit_value = 7389.0 at 2012/8/28 13:35
# profit = 1400.0
# Sell to cover at 2012/8/31 9:15 with Close 7402.0
# Trade completed
#
# Buy at 2012/9/7 8:45 with target value 7357
# exit_value = 7443.0 at 2012/9/4 13:09
# profit = 4300.0
# Sell to cover at 2012/9/7 8:46 with Close 7468.0
# Trade completed
#
# Buy at 2012/9/6 9:39 with target value 7352
# exit_value = 7358.0 at 2012/9/5 10:47
# profit = 300.0
# Sell to cover at 2012/9/6 9:40 with Close 7358.0
# Trade completed
#
# Buy at 2012/9/7 8:45 with target value 7312
# exit_value = 7354.0 at 2012/9/6 9:33
# profit = 2100.0
# Sell to cover at 2012/9/7 8:46 with Close 7468.0
# Trade completed
#
# Buy at 2012/9/20 13:35 with target value 7733
# exit_value = 7754.0 at 2012/9/19 11:24
# profit = 1050.0
# Sell to cover at 2012/9/21 8:45 with Close 7765.0
# Trade completed
#
# Buy at 2012/9/24 11:09 with target value 7709
# exit_value = 7733.0 at 2012/9/20 12:43
# profit = 1200.0
# Sell to cover at 2012/9/24 11:17 with Close 7734.0
# Trade completed
#
# Buy at 2012/9/27 9:30 with target value 7688
# exit_value = 7712.0 at 2012/9/24 10:10
# profit = 1200.0
# Sell to cover at 2012/9/27 9:52 with Close 7714.0
# Trade completed
#
# Buy at 2012/10/2 8:45 with target value 7682
# exit_value = 7700.0 at 2012/9/28 10:18
# profit = 900.0
# Sell to cover at 2012/10/2 8:46 with Close 7721.0
# Trade completed
#
# Buy at 2012/10/4 11:41 with target value 7657
# exit_value = 7708.0 at 2012/10/3 13:00
# profit = 2550.0
# Sell to cover at 2012/10/4 12:04 with Close 7709.0
# Trade completed
#
# Buy at 2012/12/5 10:51 with target value 7638
# exit_value = 7658.0 at 2012/10/4 10:31
# profit = 1000.0
# Sell to cover at 2012/12/5 10:52 with Close 7659.0
# Trade completed
#
# Buy at 2012/10/9 9:22 with target value 7632
# exit_value = 7643.0 at 2012/10/8 10:39
# profit = 550.0
# Sell to cover at 2012/10/9 9:24 with Close 7645.0
# Trade completed
#
# Buy at 2012/11/30 9:54 with target value 7450
# exit_value = 7637.0 at 2012/10/8 13:00
# profit = 7050.0
# Sell to cover at 2012/11/30 12:18 with Close 7588.0
# Trade completed
#
# Buy at 2012/10/17 8:45 with target value 7414
# exit_value = 7456.0 at 2012/10/12 9:26
# profit = 2100.0
# Sell to cover at 2012/10/17 8:46 with Close 7507.0
# Trade completed
#
# Buy at 2012/10/15 12:20 with target value 7410
# exit_value = 7414.0 at 2012/10/12 12:48
# profit = 200.0
# Sell to cover at 2012/10/15 12:21 with Close 7417.0
# Trade completed
#
# Buy at 2012/11/26 8:54 with target value 7316
# exit_value = 7413.0 at 2012/10/15 11:20
# profit = 2650.0
# Sell to cover at 2012/11/26 9:59 with Close 7372.0
# Trade completed
#
# Buy at 2012/10/24 11:58 with target value 7301
# exit_value = 7320.0 at 2012/10/22 10:39
# profit = 950.0
# Sell to cover at 2012/10/24 11:59 with Close 7320.0
# Trade completed
#
# Buy at 2012/10/24 11:34 with target value 7303
# exit_value = 7306.0 at 2012/10/24 9:38
# profit = 150.0
# Sell to cover at 2012/10/24 11:51 with Close 7306.0
# Trade completed
#
# Buy at 2012/11/9 12:16 with target value 7268
# exit_value = 7302.0 at 2012/10/24 11:31
# profit = 550.0
# Sell to cover at 2012/11/9 13:17 with Close 7275.0
# Trade completed
#
# Buy at 2012/11/6 13:15 with target value 7129
# exit_value = 7275.0 at 2012/10/26 8:50
# profit = 7300.0
# Sell to cover at 2012/11/7 10:09 with Close 7277.0
# Trade completed
#
# Buy at 2012/10/30 8:45 with target value 7122
# exit_value = 7130.0 at 2012/10/29 9:13
# profit = 400.0
# Sell to cover at 2012/10/30 8:46 with Close 7166.0
# Trade completed
#
# Buy at 2012/10/30 8:45 with target value 7122
# exit_value = 7125.0 at 2012/10/29 12:32
# profit = 150.0
# Sell to cover at 2012/10/30 8:46 with Close 7166.0
# Trade completed
#
# Buy at 2012/11/1 10:44 with target value 7084
# exit_value = 7122.0 at 2012/10/29 13:43
# profit = 1900.0
# Sell to cover at 2012/11/1 11:00 with Close 7123.0
# Trade completed
#
# Buy at 2012/11/16 9:21 with target value 7104
# exit_value = 7194.0 at 2012/11/8 12:40
# profit = 1400.0
# Sell to cover at 2012/11/16 10:13 with Close 7140.0
# Trade completed
#
# Buy at 2012/11/19 8:45 with target value 7106
# exit_value = 7112.0 at 2012/11/14 8:46
# profit = 300.0
# Sell to cover at 2012/11/19 8:46 with Close 7147.0
# Trade completed
#
# Buy at 2012/11/23 8:45 with target value 7109
# exit_value = 7151.0 at 2012/11/20 13:37
# profit = 2100.0
# Sell to cover at 2012/11/23 8:46 with Close 7153.0
# Trade completed
#
# Buy at 2012/11/23 8:45 with target value 7103
# exit_value = 7112.0 at 2012/11/22 8:45
# profit = 450.0
# Sell to cover at 2012/11/23 8:46 with Close 7153.0
# Trade completed
#
# Buy at 2012/12/11 13:01 with target value 7612
# exit_value = 7625.0 at 2012/12/10 12:39
# profit = 650.0
# Sell to cover at 2012/12/11 13:29 with Close 7627.0
# Trade completed
#
# Buy at 2012/12/11 12:59 with target value 7609
# exit_value = 7615.0 at 2012/12/11 10:48
# profit = 300.0
# Sell to cover at 2012/12/11 13:00 with Close 7618.0
# Trade completed
#
# Buy at 2012/12/25 12:28 with target value 7618
# exit_value = 7638.0 at 2012/12/17 13:20
# profit = 1000.0
# Sell to cover at 2012/12/25 12:29 with Close 7639.0
# Trade completed
#
# Buy at 2012/12/25 11:39 with target value 7600
# exit_value = 7624.0 at 2012/12/20 10:11
# profit = 1200.0
# Sell to cover at 2012/12/25 12:25 with Close 7625.0
# Trade completed
#
# Buy at 2012/12/25 11:18 with target value 7488
# exit_value = 7604.0 at 2012/12/20 12:09
# profit = 5800.0
# Sell to cover at 2012/12/25 11:30 with Close 7613.0
# Trade completed
#
# Buy at 2013/1/9 10:05 with target value 7750
# exit_value = 7768.0 at 2013/1/4 12:21
# profit = -100.0
# Sell to cover at 2013/1/9 11:14 with Close 7748.0
# Trade completed
#
# Buy at 2013/1/9 10:04 with target value 7744
# exit_value = 7762.0 at 2013/1/7 10:40
# profit = 900.0
# Sell to cover at 2013/1/9 10:05 with Close 7768.0
# Trade completed
#
# Buy at 2013/1/9 9:55 with target value 7710
# exit_value = 7749.0 at 2013/1/7 12:43
# profit = 1950.0
# Sell to cover at 2013/1/9 10:00 with Close 7752.0
# Trade completed
#
# Buy at 2013/1/9 9:11 with target value 7692
# exit_value = 7720.0 at 2013/1/8 10:53
# profit = 1400.0
# Sell to cover at 2013/1/9 9:14 with Close 7720.0
# Trade completed
#
# Buy at 2013/1/15 12:59 with target value 7754
# exit_value = 7757.0 at 2013/1/14 10:05
# profit = 150.0
# Sell to cover at 2013/1/15 13:07 with Close 7757.0
# Trade completed
#
# Buy at 2013/1/16 10:43 with target value 7736
# exit_value = 7752.0 at 2013/1/15 12:45
# profit = 800.0
# Sell to cover at 2013/1/16 10:50 with Close 7753.0
# Trade completed
#
# Buy at 2013/1/22 8:45 with target value 7700
# exit_value = 7739.0 at 2013/1/16 10:22
# profit = -750.0
# Sell to cover at 2013/1/22 9:32 with Close 7695.0
# Trade completed
#
# Buy at 2013/1/18 13:29 with target value 7690
# exit_value = 7712.0 at 2013/1/18 8:45
# profit = 1100.0
# Sell to cover at 2013/1/18 13:30 with Close 7714.0
# Trade completed
#
# Buy at 2013/1/28 9:03 with target value 7675
# exit_value = 7700.0 at 2013/1/24 10:02
# profit = 1250.0
# Sell to cover at 2013/1/28 9:04 with Close 7709.0
# Trade completed
#
# Buy at 2013/1/28 8:58 with target value 7637
# exit_value = 7688.0 at 2013/1/25 9:04
# profit = 2550.0
# Sell to cover at 2013/1/28 9:00 with Close 7689.0
# Trade completed
#
# Buy at 2013/3/1 8:45 with target value 7884
# exit_value = 7949.0 at 2013/2/22 10:12
# profit = 2450.0
# Sell to cover at 2013/3/1 11:17 with Close 7934.0
# Trade completed
#
# Buy at 2013/3/5 9:50 with target value 7874
# exit_value = 7887.0 at 2013/2/26 9:59
# profit = 650.0
# Sell to cover at 2013/3/5 10:04 with Close 7887.0
# Trade completed
#
# Buy at 2013/3/13 12:16 with target value 7982
# exit_value = 8006.0 at 2013/3/13 8:45
# profit = 1200.0
# Sell to cover at 2013/3/13 13:01 with Close 8007.0
# Trade completed
#
# Buy at 2013/3/15 8:46 with target value 7970
# exit_value = 7987.0 at 2013/3/13 11:58
# profit = -950.0
# Sell to cover at 2013/3/15 9:43 with Close 7952.0
# Trade completed
#
# Buy at 2013/3/15 11:25 with target value 7953
# exit_value = 7970.0 at 2013/3/14 12:41
# profit = 850.0
# Sell to cover at 2013/3/15 11:37 with Close 7970.0
# Trade completed
#
# Buy at 2013/3/29 12:26 with target value 7794
# exit_value = 7950.0 at 2013/3/15 11:07
# profit = 6300.0
# Sell to cover at 2013/4/1 9:41 with Close 7921.0
# Trade completed
#
# Buy at 2013/3/22 11:50 with target value 7797
# exit_value = 7800.0 at 2013/3/22 10:32
# profit = 150.0
# Sell to cover at 2013/3/22 11:51 with Close 7803.0
# Trade completed
#
# Buy at 2013/4/19 9:36 with target value 7759
# exit_value = 7916.0 at 2013/4/2 11:51
# profit = 7850.0
# Sell to cover at 2013/4/19 10:04 with Close 7926.0
# Trade completed
#
# Buy at 2013/4/11 8:45 with target value 7743
# exit_value = 7760.0 at 2013/4/8 11:43
# profit = 850.0
# Sell to cover at 2013/4/11 8:46 with Close 7768.0
# Trade completed
#
# Buy at 2013/4/10 8:45 with target value 7720
# exit_value = 7744.0 at 2013/4/9 9:49
# profit = 300.0
# Sell to cover at 2013/4/10 12:11 with Close 7726.0
# Trade completed
#
# Buy at 2013/4/16 11:45 with target value 7723
# exit_value = 7756.0 at 2013/4/15 12:58
# profit = 1650.0
# Sell to cover at 2013/4/16 11:49 with Close 7758.0
# Trade completed
#
# Buy at 2013/5/14 8:45 with target value 8251
# exit_value = 8293.0 at 2013/5/10 13:25
# profit = 2100.0
# Sell to cover at 2013/5/14 8:46 with Close 8295.0
# Trade completed
#
# Buy at 2013/5/20 12:42 with target value 8382
# exit_value = 8380.0 at 2013/5/20 11:04
# profit = -100.0
# Sell to cover at 2013/5/20 12:43 with Close 8381.0
# Trade completed
#
# Buy at 2013/10/3 12:30 with target value 8346
# exit_value = 8377.0 at 2013/5/20 12:41
# profit = 1550.0
# Sell to cover at 2013/10/3 12:31 with Close 8381.0
# Trade completed
#
# Buy at 2013/5/29 10:26 with target value 8241
# exit_value = 8355.0 at 2013/5/23 9:44
# profit = 4400.0
# Sell to cover at 2013/5/29 12:56 with Close 8328.0
# Trade completed
#
# Buy at 2013/5/27 10:22 with target value 8196
# exit_value = 8248.0 at 2013/5/24 8:45
# profit = 2600.0
# Sell to cover at 2013/5/27 10:23 with Close 8260.0
# Trade completed
#
# Buy at 2013/5/31 8:45 with target value 8231
# exit_value = 8268.0 at 2013/5/29 8:46
# profit = 1850.0
# Sell to cover at 2013/5/31 8:46 with Close 8308.0
# Trade completed
#
# Buy at 2013/7/15 10:26 with target value 8188
# exit_value = 8239.0 at 2013/5/30 12:39
# profit = 950.0
# Sell to cover at 2013/7/15 11:48 with Close 8209.0
# Trade completed
#
# Buy at 2013/6/5 10:04 with target value 8174
# exit_value = 8198.0 at 2013/6/3 10:43
# profit = -100.0
# Sell to cover at 2013/6/5 11:15 with Close 8173.0
# Trade completed
#
# Buy at 2013/6/10 8:46 with target value 8076
# exit_value = 8174.0 at 2013/6/4 12:36
# profit = 4900.0
# Sell to cover at 2013/6/10 10:29 with Close 8179.0
# Trade completed
#
# Buy at 2013/6/7 12:50 with target value 8069
# exit_value = 8079.0 at 2013/6/6 13:05
# profit = 500.0
# Sell to cover at 2013/6/7 12:51 with Close 8081.0
# Trade completed
#
# Buy at 2013/7/11 8:45 with target value 7974
# exit_value = 8074.0 at 2013/6/7 12:40
# profit = 5000.0
# Sell to cover at 2013/7/11 8:46 with Close 8099.0
# Trade completed
#
# Buy at 2013/6/17 9:33 with target value 7930
# exit_value = 7977.0 at 2013/6/13 10:50
# profit = 2350.0
# Sell to cover at 2013/6/17 11:43 with Close 7977.0
# Trade completed
#
# Buy at 2013/7/1 10:14 with target value 7752
# exit_value = 7929.0 at 2013/6/14 12:20
# profit = 6350.0
# Sell to cover at 2013/7/1 11:22 with Close 7877.0
# Trade completed
#
# Buy at 2013/6/27 8:45 with target value 7650
# exit_value = 7753.0 at 2013/6/20 13:35
# profit = 3500.0
# Sell to cover at 2013/6/27 11:10 with Close 7720.0
# Trade completed
#
# Buy at 2013/6/24 11:58 with target value 7633
# exit_value = 7647.0 at 2013/6/21 9:53
# profit = 700.0
# Sell to cover at 2013/6/24 11:59 with Close 7652.0
# Trade completed
#
# Buy at 2013/6/25 12:50 with target value 7627
# exit_value = 7627.0 at 2013/6/24 10:36
# profit = 0.0
# Sell to cover at 2013/6/25 12:52 with Close 7627.0
# Trade completed
#
# Buy at 2013/7/23 9:48 with target value 8105
# exit_value = 8113.0 at 2013/7/18 11:44
# profit = 400.0
# Sell to cover at 2013/7/23 9:49 with Close 8115.0
# Trade completed
#
# Buy at 2013/7/23 8:50 with target value 8009
# exit_value = 8110.0 at 2013/7/18 13:00
# profit = 5050.0
# Sell to cover at 2013/7/23 9:45 with Close 8110.0
# Trade completed
#
# Buy at 2013/7/22 9:01 with target value 7992
# exit_value = 8010.0 at 2013/7/19 10:25
# profit = 900.0
# Sell to cover at 2013/7/22 9:02 with Close 8015.0
# Trade completed
#
# Buy at 2013/7/30 10:45 with target value 8113
# exit_value = 8124.0 at 2013/7/25 13:26
# profit = 550.0
# Sell to cover at 2013/7/30 10:46 with Close 8124.0
# Trade completed
#
# Buy at 2013/7/30 10:44 with target value 8088
# exit_value = 8115.0 at 2013/7/26 11:42
# profit = 1350.0
# Sell to cover at 2013/7/30 10:45 with Close 8127.0
# Trade completed
#
# Buy at 2013/7/30 9:25 with target value 8065
# exit_value = 8108.0 at 2013/7/29 9:30
# profit = 2150.0
# Sell to cover at 2013/7/30 10:39 with Close 8108.0
# Trade completed
#
# Buy at 2013/8/2 8:45 with target value 8061
# exit_value = 8068.0 at 2013/7/29 11:53
# profit = 350.0
# Sell to cover at 2013/8/2 8:46 with Close 8105.0
# Trade completed
#
# Buy at 2013/8/2 8:45 with target value 8035
# exit_value = 8067.0 at 2013/8/1 10:30
# profit = 1600.0
# Sell to cover at 2013/8/2 8:46 with Close 8105.0
# Trade completed
#
# Buy at 2013/9/2 12:39 with target value 7990
# exit_value = 8038.0 at 2013/8/1 13:03
# profit = 1100.0
# Sell to cover at 2013/9/2 13:17 with Close 8014.0
# Trade completed
#
# Buy at 2013/8/30 13:34 with target value 7926
# exit_value = 7993.0 at 2013/8/6 11:16
# profit = 3350.0
# Sell to cover at 2013/9/2 9:30 with Close 7994.0
# Trade completed
#
# Buy at 2013/8/13 8:58 with target value 7873
# exit_value = 7939.0 at 2013/8/7 9:44
# profit = 3300.0
# Sell to cover at 2013/8/13 9:14 with Close 7948.0
# Trade completed
#
# Buy at 2013/8/9 10:06 with target value 7860
# exit_value = 7878.0 at 2013/8/8 9:37
# profit = -750.0
# Sell to cover at 2013/8/9 11:13 with Close 7846.0
# Trade completed
#
# Buy at 2013/8/12 9:50 with target value 7834
# exit_value = 7867.0 at 2013/8/9 9:20
# profit = 1650.0
# Sell to cover at 2013/8/12 10:09 with Close 7868.0
# Trade completed
#
# Buy at 2013/8/26 9:00 with target value 7769
# exit_value = 7859.0 at 2013/8/15 9:48
# profit = 2950.0
# Sell to cover at 2013/8/26 12:28 with Close 7828.0
# Trade completed
#
# Buy at 2013/8/22 11:17 with target value 7763
# exit_value = 7770.0 at 2013/8/22 9:45
# profit = 350.0
# Sell to cover at 2013/8/22 11:18 with Close 7772.0
# Trade completed
#
# Buy at 2013/8/29 8:45 with target value 7760
# exit_value = 7805.0 at 2013/8/27 11:59
# profit = 2250.0
# Sell to cover at 2013/8/29 8:50 with Close 7807.0
# Trade completed
#
# Buy at 2013/10/3 9:05 with target value 8175
# exit_value = 8241.0 at 2013/9/25 11:26
# profit = 3300.0
# Sell to cover at 2013/10/3 9:12 with Close 8242.0
# Trade completed
#
# Buy at 2013/9/26 12:43 with target value 8174
# exit_value = 8177.0 at 2013/9/26 10:48
# profit = 150.0
# Sell to cover at 2013/9/26 12:44 with Close 8177.0
# Trade completed
#
# Buy at 2013/10/1 9:05 with target value 8120
# exit_value = 8172.0 at 2013/9/26 12:41
# profit = 2150.0
# Sell to cover at 2013/10/1 10:45 with Close 8163.0
# Trade completed
#
# Buy at 2013/10/15 8:45 with target value 8306
# exit_value = 8340.0 at 2013/10/14 10:13
# profit = 1700.0
# Sell to cover at 2013/10/15 8:46 with Close 8358.0
# Trade completed
#
# Buy at 2013/10/24 13:13 with target value 8358
# exit_value = 8397.0 at 2013/10/22 10:35
# profit = 1950.0
# Sell to cover at 2013/10/24 13:28 with Close 8397.0
# Trade completed
#
# Buy at 2013/10/28 9:42 with target value 8312
# exit_value = 8362.0 at 2013/10/23 13:30
# profit = 2500.0
# Sell to cover at 2013/10/28 9:44 with Close 8372.0
# Trade completed
#
# Buy at 2013/11/29 11:12 with target value 8395
# exit_value = 8432.0 at 2013/10/31 9:47
# profit = 1050.0
# Sell to cover at 2013/11/29 12:18 with Close 8416.0
# Trade completed
#
# Buy at 2013/11/29 9:24 with target value 8390
# exit_value = 8397.0 at 2013/11/1 12:35
# profit = 350.0
# Sell to cover at 2013/11/29 9:35 with Close 8402.0
# Trade completed
#
# Buy at 2013/11/28 9:28 with target value 8331
# exit_value = 8394.0 at 2013/11/1 13:39
# profit = 2350.0
# Sell to cover at 2013/11/28 12:00 with Close 8379.0
# Trade completed
#
# Buy at 2013/11/28 8:45 with target value 8279
# exit_value = 8335.0 at 2013/11/4 12:17
# profit = 2800.0
# Sell to cover at 2013/11/28 8:46 with Close 8365.0
# Trade completed
#
# Buy at 2013/11/6 11:36 with target value 8262
# exit_value = 8285.0 at 2013/11/5 11:11
# profit = 0.0
# Sell to cover at 2013/11/6 12:18 with Close 8263.0
# Trade completed
#
# Buy at 2013/11/8 10:40 with target value 8243
# exit_value = 8271.0 at 2013/11/7 10:20
# profit = -100.0
# Sell to cover at 2013/11/8 11:42 with Close 8243.0
# Trade completed
#
# Buy at 2013/11/12 9:15 with target value 8223
# exit_value = 8245.0 at 2013/11/7 12:05
# profit = -250.0
# Sell to cover at 2013/11/12 10:31 with Close 8219.0
# Trade completed
#
# Buy at 2013/11/19 9:11 with target value 8208
# exit_value = 8233.0 at 2013/11/11 8:45
# profit = 1250.0
# Sell to cover at 2013/11/19 9:22 with Close 8233.0
# Trade completed
#
# Buy at 2013/11/15 9:40 with target value 8131
# exit_value = 8210.0 at 2013/11/12 13:08
# profit = 3950.0
# Sell to cover at 2013/11/15 10:46 with Close 8212.0
# Trade completed
#
# Buy at 2013/11/14 10:57 with target value 8139
# exit_value = 8146.0 at 2013/11/14 8:45
# profit = 350.0
# Sell to cover at 2013/11/14 10:58 with Close 8148.0
# Trade completed
#
# Buy at 2013/11/25 8:53 with target value 8079
# exit_value = 8230.0 at 2013/11/20 13:00
# profit = 6050.0
# Sell to cover at 2013/11/25 11:57 with Close 8200.0
# Trade completed
#
# Buy at 2013/12/5 12:59 with target value 8375
# exit_value = 8400.0 at 2013/12/3 12:08
# profit = 100.0
# Sell to cover at 2013/12/6 8:45 with Close 8381.0
# Trade completed
#
# Buy at 2013/12/19 8:59 with target value 8384
# exit_value = 8436.0 at 2013/12/11 12:55
# profit = 700.0
# Sell to cover at 2013/12/19 9:55 with Close 8402.0
# Trade completed
#
# Buy at 2013/12/13 9:45 with target value 8388
# exit_value = 8387.0 at 2013/12/12 12:21
# profit = -50.0
# Sell to cover at 2013/12/13 9:46 with Close 8391.0
# Trade completed
#
# Buy at 2013/12/17 8:46 with target value 8350
# exit_value = 8385.0 at 2013/12/13 9:44
# profit = 1000.0
# Sell to cover at 2013/12/17 11:24 with Close 8370.0
# Trade completed
#
# Buy at 2013/12/17 8:45 with target value 8335
# exit_value = 8353.0 at 2013/12/16 10:19
# profit = 900.0
# Sell to cover at 2013/12/17 8:46 with Close 8376.0
# Trade completed
#
# Buy at 2014/1/16 8:45 with target value 8603
# exit_value = 8633.0 at 2014/1/2 9:48
# profit = 1500.0
# Sell to cover at 2014/1/16 8:46 with Close 8654.0
# Trade completed
#
# Buy at 2014/1/15 9:03 with target value 8543
# exit_value = 8602.0 at 2014/1/2 11:37
# profit = 2950.0
# Sell to cover at 2014/1/15 10:38 with Close 8603.0
# Trade completed
#
# Buy at 2014/1/6 9:06 with target value 8544
# exit_value = 8546.0 at 2014/1/3 12:07
# profit = 100.0
# Sell to cover at 2014/1/6 9:07 with Close 8549.0
# Trade completed
#
# Buy at 2014/1/6 11:37 with target value 8524
# exit_value = 8544.0 at 2014/1/3 13:25
# profit = 0.0
# Sell to cover at 2014/1/6 12:27 with Close 8521.0
# Trade completed
#
# Buy at 2014/1/24 10:38 with target value 8614
# exit_value = 8622.0 at 2014/1/21 13:40
# profit = 400.0
# Sell to cover at 2014/1/24 10:39 with Close 8625.0
# Trade completed
#
# Buy at 2014/1/24 9:12 with target value 8601
# exit_value = 8612.0 at 2014/1/23 11:06
# profit = 550.0
# Sell to cover at 2014/1/24 9:13 with Close 8614.0
# Trade completed
#
# Buy at 2014/2/19 9:59 with target value 8488
# exit_value = 8601.0 at 2014/1/23 12:21
# profit = 3200.0
# Sell to cover at 2014/2/19 10:28 with Close 8551.0
# Trade completed
#
# Buy at 2014/2/11 13:33 with target value 8242
# exit_value = 8491.0 at 2014/1/27 10:49
# profit = 12450.0
# Sell to cover at 2014/2/12 13:29 with Close 8491.0
# Trade completed
#
# Buy at 2014/2/21 8:45 with target value 8515
# exit_value = 8548.0 at 2014/2/20 9:44
# profit = 1650.0
# Sell to cover at 2014/2/21 8:46 with Close 8579.0
# Trade completed
#
# Buy at 2014/3/12 12:58 with target value 8659
# exit_value = 8660.0 at 2014/3/12 10:37
# profit = 50.0
# Sell to cover at 2014/3/12 12:59 with Close 8660.0
# Trade completed
#
# Buy at 2014/3/17 10:20 with target value 8687
# exit_value = 8692.0 at 2014/3/14 13:11
# profit = -200.0
# Sell to cover at 2014/3/17 11:08 with Close 8683.0
# Trade completed
#
# Buy at 2014/3/17 13:15 with target value 8683
# exit_value = 8686.0 at 2014/3/17 10:10
# profit = 150.0
# Sell to cover at 2014/3/17 13:17 with Close 8686.0
# Trade completed
#
# Buy at 2014/3/25 11:05 with target value 8573
# exit_value = 8682.0 at 2014/3/17 12:21
# profit = 3650.0
# Sell to cover at 2014/3/25 12:45 with Close 8645.0
# Trade completed
#
# Buy at 2014/3/24 10:23 with target value 8575
# exit_value = 8579.0 at 2014/3/21 13:14
# profit = 200.0
# Sell to cover at 2014/3/24 12:15 with Close 8579.0
# Trade completed
#
# Buy at 2014/4/7 13:29 with target value 8843
# exit_value = 8859.0 at 2014/4/3 12:34
# profit = 800.0
# Sell to cover at 2014/4/7 13:33 with Close 8859.0
# Trade completed
#
# Buy at 2014/4/7 13:11 with target value 8840
# exit_value = 8844.0 at 2014/4/7 10:09
# profit = 200.0
# Sell to cover at 2014/4/7 13:13 with Close 8844.0
# Trade completed
#
# Buy at 2014/4/24 13:30 with target value 8926
# exit_value = 8933.0 at 2014/4/24 10:15
# profit = 350.0
# Sell to cover at 2014/4/24 13:42 with Close 8934.0
# Trade completed
#
# Buy at 2014/5/5 8:49 with target value 8748
# exit_value = 8927.0 at 2014/4/24 12:54
# profit = 3500.0
# Sell to cover at 2014/5/5 9:45 with Close 8826.0
# Trade completed
#
# Buy at 2014/5/12 13:42 with target value 8812
# exit_value = 8822.0 at 2014/5/12 10:40
# profit = 500.0
# Sell to cover at 2014/5/13 8:45 with Close 8858.0
# Trade completed
#
# Buy at 2014/6/3 13:33 with target value 9097
# exit_value = 9116.0 at 2014/5/30 13:08
# profit = 950.0
# ...
# profit = 1800.0
# Sell to cover at 2022/10/20 12:52 with Close 12788.0
# Trade completed
#
# Buy at 2022/10/25 11:25 with target value 12711
# exit_value = 12780.0 at 2022/10/20 12:19
# profit = 3450.0
# Sell to cover at 2022/10/25 11:30 with Close 12789.0
# Trade completed
#
# Buy at 2022/10/26 9:14 with target value 12719
# exit_value = 12740.0 at 2022/10/25 11:01
# profit = 1050.0
# Sell to cover at 2022/10/26 9:15 with Close 12744.0
# Trade completed
#
# Buy at 2022/11/4 10:17 with target value 12929
# exit_value = 12962.0 at 2022/11/3 11:57
# profit = 1650.0
# Sell to cover at 2022/11/4 10:18 with Close 12963.0
# Trade completed
#
# Buy at 2022/11/18 8:45 with target value 14428
# exit_value = 14600.0 at 2022/11/16 11:53
# profit = 8600.0
# Sell to cover at 2022/11/18 9:08 with Close 14603.0
# Trade completed
#
# Buy at 2022/11/21 12:13 with target value 14467
# exit_value = 14484.0 at 2022/11/18 13:16
# profit = 850.0
# Sell to cover at 2022/11/21 12:14 with Close 14487.0
# Trade completed
#
# Buy at 2022/11/22 10:57 with target value 14452
# exit_value = 14468.0 at 2022/11/21 12:01
# profit = 800.0
# Sell to cover at 2022/11/22 10:58 with Close 14468.0
# Trade completed
#
# Buy at 2022/11/29 9:54 with target value 14533
# exit_value = 14557.0 at 2022/11/28 10:30
# profit = 1200.0
# Sell to cover at 2022/11/29 9:56 with Close 14564.0
# Trade completed
#
# Buy at 2023/1/13 8:45 with target value 14842
# exit_value = 14911.0 at 2022/12/2 12:42
# profit = 3450.0
# Sell to cover at 2023/1/13 8:46 with Close 15005.0
# Trade completed
#
# Buy at 2023/1/10 9:46 with target value 14707
# exit_value = 14850.0 at 2022/12/6 10:33
# profit = 2300.0
# Sell to cover at 2023/1/10 10:34 with Close 14754.0
# Trade completed
#
# Buy at 2022/12/7 12:20 with target value 14675
# exit_value = 14713.0 at 2022/12/7 9:25
# profit = -1350.0
# Sell to cover at 2022/12/7 12:33 with Close 14645.0
# Trade completed
#
# Buy at 2022/12/9 8:45 with target value 14493
# exit_value = 14661.0 at 2022/12/7 11:45
# profit = 8400.0
# Sell to cover at 2022/12/9 10:16 with Close 14680.0
# Trade completed
#
# Buy at 2023/1/9 8:45 with target value 14468
# exit_value = 14498.0 at 2022/12/16 10:25
# profit = 1500.0
# Sell to cover at 2023/1/9 8:46 with Close 14613.0
# Trade completed
#
# Buy at 2023/1/9 8:45 with target value 14428
# exit_value = 14469.0 at 2022/12/19 10:06
# profit = 2050.0
# Sell to cover at 2023/1/9 8:46 with Close 14613.0
# Trade completed
#
# Buy at 2022/12/22 9:27 with target value 14207
# exit_value = 14430.0 at 2022/12/20 9:09
# profit = 7200.0
# Sell to cover at 2022/12/22 10:57 with Close 14353.0
# Trade completed
#
# Buy at 2022/12/23 9:49 with target value 14204
# exit_value = 14212.0 at 2022/12/21 8:45
# profit = 400.0
# Sell to cover at 2022/12/23 9:50 with Close 14222.0
# Trade completed
#
# Buy at 2022/12/23 11:57 with target value 14197
# exit_value = 14211.0 at 2022/12/23 9:44
# profit = 700.0
# Sell to cover at 2022/12/23 12:05 with Close 14212.0
# Trade completed
#
# Buy at 2022/12/30 8:45 with target value 14113
# exit_value = 14195.0 at 2022/12/23 11:48
# profit = 4100.0
# Sell to cover at 2022/12/30 8:55 with Close 14196.0
# Trade completed
#
# Buy at 2022/12/30 8:45 with target value 13994
# exit_value = 14115.0 at 2022/12/28 11:49
# profit = 6050.0
# Sell to cover at 2022/12/30 8:46 with Close 14179.0
# Trade completed
#
# Buy at 2023/2/7 9:16 with target value 15434
# exit_value = 15442.0 at 2023/2/6 11:40
# profit = 400.0
# Sell to cover at 2023/2/7 9:17 with Close 15444.0
# Trade completed
#
# Buy at 2023/2/8 8:45 with target value 15404
# exit_value = 15435.0 at 2023/2/7 9:13
# profit = 1550.0
# Sell to cover at 2023/2/8 8:46 with Close 15490.0
# Trade completed
#
# Buy at 2023/2/14 8:45 with target value 15509
# exit_value = 15569.0 at 2023/2/10 12:24
# profit = 3000.0
# Sell to cover at 2023/2/14 8:46 with Close 15630.0
# Trade completed
#
# Buy at 2023/2/16 8:50 with target value 15425
# exit_value = 15497.0 at 2023/2/13 11:07
# profit = 3600.0
# Sell to cover at 2023/2/16 9:05 with Close 15510.0
# Trade completed
#
# Buy at 2023/2/22 11:57 with target value 15361
# exit_value = 15430.0 at 2023/2/15 12:36
# profit = 700.0
# Sell to cover at 2023/2/22 12:33 with Close 15380.0
# Trade completed
#
# Buy at 2023/3/1 11:49 with target value 15453
# exit_value = 15574.0 at 2023/2/24 13:12
# profit = 6050.0
# Sell to cover at 2023/3/2 8:45 with Close 15594.0
# Trade completed
#
# Buy at 2023/3/13 10:25 with target value 15445
# exit_value = 15481.0 at 2023/3/10 12:49
# profit = 1800.0
# Sell to cover at 2023/3/13 10:26 with Close 15481.0
# Trade completed
#
# Buy at 2023/3/15 8:45 with target value 15412
# exit_value = 15456.0 at 2023/3/13 10:13
# profit = 2200.0
# Sell to cover at 2023/3/15 8:46 with Close 15462.0
# Trade completed
#
# Buy at 2023/3/17 9:14 with target value 15275
# exit_value = 15411.0 at 2023/3/14 10:12
# profit = 2650.0
# Sell to cover at 2023/3/17 10:32 with Close 15332.0
# Trade completed
#
# Buy at 2023/3/17 8:45 with target value 15204
# exit_value = 15291.0 at 2023/3/16 10:43
# profit = 4350.0
# Sell to cover at 2023/3/17 8:46 with Close 15303.0
# Trade completed
#
# Buy at 2023/3/29 8:45 with target value 15684
# exit_value = 15714.0 at 2023/3/28 11:09
# profit = 1500.0
# Sell to cover at 2023/3/29 8:46 with Close 15726.0
# Trade completed
#
# Buy at 2023/4/10 8:45 with target value 15783
# exit_value = 15791.0 at 2023/4/6 9:48
# profit = 400.0
# Sell to cover at 2023/4/10 8:46 with Close 15838.0
# Trade completed
#
# Buy at 2023/4/14 9:18 with target value 15876
# exit_value = 15889.0 at 2023/4/13 10:09
# profit = 650.0
# Sell to cover at 2023/4/14 9:19 with Close 15889.0
# Trade completed
#
# Buy at 2023/5/17 10:27 with target value 15767
# exit_value = 15886.0 at 2023/4/14 8:45
# profit = 5950.0
# Sell to cover at 2023/5/17 12:09 with Close 15891.0
# Trade completed
#
# Buy at 2023/4/21 8:55 with target value 15739
# exit_value = 15766.0 at 2023/4/20 9:49
# profit = 1350.0
# Sell to cover at 2023/4/21 8:59 with Close 15770.0
# Trade completed
#
# Buy at 2023/5/8 8:45 with target value 15682
# exit_value = 15745.0 at 2023/4/20 11:48
# profit = 3150.0
# Sell to cover at 2023/5/8 8:46 with Close 15747.0
# Trade completed
#
# Buy at 2023/5/5 9:07 with target value 15628
# exit_value = 15695.0 at 2023/4/21 11:17
# profit = -250.0
# Sell to cover at 2023/5/5 9:47 with Close 15622.0
# Trade completed
#
# Buy at 2023/4/25 8:45 with target value 15622
# exit_value = 15633.0 at 2023/4/24 9:35
# profit = 550.0
# Sell to cover at 2023/4/25 8:46 with Close 15651.0
# Trade completed
#
# Buy at 2023/4/28 9:29 with target value 15380
# exit_value = 15624.0 at 2023/4/24 12:54
# profit = 6350.0
# Sell to cover at 2023/4/28 11:05 with Close 15505.0
# Trade completed
#
# Buy at 2023/4/26 10:46 with target value 15382
# exit_value = 15409.0 at 2023/4/26 8:45
# profit = -2450.0
# Sell to cover at 2023/4/26 11:59 with Close 15332.0
# Trade completed
#
# Buy at 2023/4/26 12:51 with target value 15360
# exit_value = 15368.0 at 2023/4/26 10:35
# profit = 400.0
# Sell to cover at 2023/4/26 12:54 with Close 15372.0
# Trade completed
#
# Buy at 2023/5/3 13:05 with target value 15555
# exit_value = 15584.0 at 2023/5/3 10:04
# profit = 100.0
# Sell to cover at 2023/5/3 13:30 with Close 15557.0
# Trade completed
#
# Buy at 2023/5/4 10:01 with target value 15551
# exit_value = 15561.0 at 2023/5/3 12:07
# profit = 500.0
# Sell to cover at 2023/5/4 10:02 with Close 15567.0
# Trade completed
#
# Buy at 2023/5/12 12:33 with target value 15459
# exit_value = 15589.0 at 2023/5/11 11:07
# profit = 3450.0
# Sell to cover at 2023/5/12 13:23 with Close 15531.0
# Trade completed
#
# Buy at 2023/6/2 8:45 with target value 16472
# exit_value = 16524.0 at 2023/5/31 12:17
# profit = 2600.0
# Sell to cover at 2023/6/2 8:46 with Close 16573.0
# Trade completed
#
# Buy at 2023/6/1 13:09 with target value 16467
# exit_value = 16478.0 at 2023/6/1 11:08
# profit = 550.0
# Sell to cover at 2023/6/1 13:10 with Close 16485.0
# Trade completed
#
# Buy at 2023/6/21 13:03 with target value 17166
# exit_value = 17248.0 at 2023/6/19 10:00
# profit = -13700.0
# Sell to cover at 2023/6/26 8:45 with Close 16873.0
# Trade completed
#
# Buy at 2023/6/21 12:13 with target value 17175
# exit_value = 17173.0 at 2023/6/20 10:44
# profit = -100.0
# Sell to cover at 2023/6/21 12:14 with Close 17177.0
# Trade completed
#
# Buy at 2023/7/4 11:53 with target value 16903
# exit_value = 17170.0 at 2023/6/21 12:12
# profit = 8950.0
# Sell to cover at 2023/7/5 8:46 with Close 17078.0
# Trade completed
#
# Buy at 2023/6/29 8:52 with target value 16894
# exit_value = 16908.0 at 2023/6/26 11:10
# profit = 700.0
# Sell to cover at 2023/6/29 8:53 with Close 16920.0
# Trade completed
#
# Buy at 2023/6/29 8:46 with target value 16824
# exit_value = 16898.0 at 2023/6/26 12:40
# profit = 3700.0
# Sell to cover at 2023/6/29 8:49 with Close 16900.0
# Trade completed
#
# Buy at 2023/6/29 8:45 with target value 16801
# exit_value = 16835.0 at 2023/6/27 9:49
# profit = 1700.0
# Sell to cover at 2023/6/29 8:46 with Close 16887.0
# Trade completed
#
# Buy at 2023/6/29 8:45 with target value 16765
# exit_value = 16810.0 at 2023/6/28 8:45
# profit = 2250.0
# Sell to cover at 2023/6/29 8:46 with Close 16887.0
# Trade completed
#
# Buy at 2023/6/30 9:46 with target value 16762
# exit_value = 16760.0 at 2023/6/28 12:57
# profit = -100.0
# Sell to cover at 2023/6/30 10:05 with Close 16763.0
# Trade completed
#
# Buy at 2023/6/30 11:32 with target value 16751
# exit_value = 16757.0 at 2023/6/30 9:45
# profit = 300.0
# Sell to cover at 2023/6/30 11:41 with Close 16757.0
# Trade completed
#
# Buy at 2023/7/11 10:24 with target value 16725
# exit_value = 16896.0 at 2023/7/6 9:57
# profit = 6200.0
# Sell to cover at 2023/7/11 12:04 with Close 16850.0
# Trade completed
#
# Buy at 2023/7/7 11:17 with target value 16615
# exit_value = 16724.0 at 2023/7/6 12:50
# profit = 1600.0
# Sell to cover at 2023/7/7 12:01 with Close 16648.0
# Trade completed
#
# Buy at 2023/7/20 13:24 with target value 17093
# exit_value = 17118.0 at 2023/7/20 9:32
# profit = 1250.0
# Sell to cover at 2023/7/20 13:32 with Close 17120.0
# Trade completed
#
# Buy at 2023/7/25 8:45 with target value 16906
# exit_value = 17096.0 at 2023/7/20 13:05
# profit = 9500.0
# Sell to cover at 2023/7/25 8:46 with Close 17105.0
# Trade completed
#
# Buy at 2023/8/1 9:02 with target value 17115
# exit_value = 17232.0 at 2023/7/28 9:37
# profit = -150.0
# Sell to cover at 2023/8/1 9:37 with Close 17092.0
# Trade completed
#
# Buy at 2023/8/7 11:01 with target value 16835
# exit_value = 17115.0 at 2023/7/31 13:38
# profit = 6900.0
# Sell to cover at 2023/8/7 12:17 with Close 16973.0
# Trade completed
#
# Buy at 2023/8/24 10:10 with target value 16647
# exit_value = 16857.0 at 2023/8/9 13:15
# profit = 3750.0
# Sell to cover at 2023/8/24 11:07 with Close 16724.0
# Trade completed
#
# Buy at 2023/8/10 13:33 with target value 16638
# exit_value = 16650.0 at 2023/8/10 11:33
# profit = 600.0
# Sell to cover at 2023/8/10 13:34 with Close 16663.0
# Trade completed
#
# Buy at 2023/8/23 10:42 with target value 16342
# exit_value = 16647.0 at 2023/8/10 13:30
# profit = 8700.0
# Sell to cover at 2023/8/23 11:24 with Close 16518.0
# Trade completed
#
# Buy at 2023/8/17 10:03 with target value 16327
# exit_value = 16380.0 at 2023/8/16 12:56
# profit = 2650.0
# Sell to cover at 2023/8/17 10:30 with Close 16387.0
# Trade completed
#
# Buy at 2023/9/14 8:45 with target value 16633
# exit_value = 16650.0 at 2023/8/31 12:30
# profit = 850.0
# Sell to cover at 2023/9/14 8:46 with Close 16682.0
# Trade completed
#
# Buy at 2023/9/13 9:15 with target value 16524
# exit_value = 16635.0 at 2023/9/7 11:37
# profit = 5550.0
# Sell to cover at 2023/9/13 9:24 with Close 16640.0
# Trade completed
#
# Buy at 2023/9/12 10:19 with target value 16405
# exit_value = 16523.0 at 2023/9/8 10:11
# profit = 5900.0
# Sell to cover at 2023/9/12 10:44 with Close 16525.0
# Trade completed
#
# Buy at 2023/10/11 8:45 with target value 16731
# exit_value = 16748.0 at 2023/9/18 12:20
# profit = 850.0
# Sell to cover at 2023/10/11 8:46 with Close 16779.0
# Trade completed
#
# Buy at 2023/10/11 8:45 with target value 16630
# exit_value = 16730.0 at 2023/9/19 9:05
# profit = 5000.0
# Sell to cover at 2023/10/11 8:46 with Close 16779.0
# Trade completed
#
# Buy at 2023/9/20 11:28 with target value 16608
# exit_value = 16615.0 at 2023/9/20 9:41
# profit = 350.0
# Sell to cover at 2023/9/20 11:29 with Close 16616.0
# Trade completed
#
# Buy at 2023/10/2 8:45 with target value 16307
# exit_value = 16610.0 at 2023/9/20 11:25
# profit = 13650.0
# Sell to cover at 2023/10/2 11:32 with Close 16582.0
# Trade completed
#
# Buy at 2023/9/22 10:19 with target value 16300
# exit_value = 16312.0 at 2023/9/21 13:13
# profit = 600.0
# Sell to cover at 2023/9/22 10:31 with Close 16316.0
# Trade completed
#
# Buy at 2023/9/27 9:24 with target value 16301
# exit_value = 16309.0 at 2023/9/22 10:13
# profit = 400.0
# Sell to cover at 2023/9/27 9:25 with Close 16319.0
# Trade completed
#
# Buy at 2023/9/27 12:50 with target value 16274
# exit_value = 16306.0 at 2023/9/26 13:41
# profit = 1600.0
# Sell to cover at 2023/9/27 12:56 with Close 16307.0
# Trade completed
#
# Buy at 2023/10/4 12:31 with target value 16247
# exit_value = 16272.0 at 2023/9/27 12:34
# profit = 1250.0
# Sell to cover at 2023/10/4 12:35 with Close 16273.0
# Trade completed
#
# Buy at 2023/10/17 8:45 with target value 16635
# exit_value = 16715.0 at 2023/10/11 13:01
# profit = 4000.0
# Sell to cover at 2023/10/17 8:46 with Close 16778.0
# Trade completed
#
# Buy at 2023/10/16 12:48 with target value 16643
# exit_value = 16642.0 at 2023/10/16 11:42
# profit = -50.0
# Sell to cover at 2023/10/16 12:49 with Close 16644.0
# Trade completed
#
# Buy at 2023/11/6 8:45 with target value 16499
# exit_value = 16641.0 at 2023/10/16 12:47
# profit = 7100.0
# Sell to cover at 2023/11/6 8:46 with Close 16658.0
# Trade completed
#
# Buy at 2023/11/3 9:41 with target value 16463
# exit_value = 16501.0 at 2023/10/18 12:20
# profit = 1900.0
# Sell to cover at 2023/11/3 9:57 with Close 16502.0
# Trade completed
#
# Buy at 2023/10/19 12:23 with target value 16455
# exit_value = 16459.0 at 2023/10/19 9:10
# profit = 200.0
# Sell to cover at 2023/10/19 12:24 with Close 16460.0
# Trade completed
#
# Buy at 2023/10/20 10:59 with target value 16323
# exit_value = 16450.0 at 2023/10/19 12:18
# profit = 6350.0
# Sell to cover at 2023/10/20 12:49 with Close 16454.0
# Trade completed
#
# Buy at 2023/10/24 10:27 with target value 16292
# exit_value = 16324.0 at 2023/10/20 10:41
# profit = 1600.0
# Sell to cover at 2023/10/24 10:31 with Close 16324.0
# Trade completed
#
# Buy at 2023/10/24 10:24 with target value 16283
# exit_value = 16289.0 at 2023/10/23 12:15
# profit = 300.0
# Sell to cover at 2023/10/24 10:25 with Close 16311.0
# Trade completed
#
# Buy at 2023/10/24 10:23 with target value 16265
# exit_value = 16280.0 at 2023/10/24 9:12
# profit = 750.0
# Sell to cover at 2023/10/24 10:24 with Close 16302.0
# Trade completed
#
# Buy at 2023/10/30 9:03 with target value 16105
# exit_value = 16270.0 at 2023/10/24 10:20
# profit = 2700.0
# Sell to cover at 2023/10/30 10:13 with Close 16151.0
# Trade completed
#
# Buy at 2023/11/2 8:45 with target value 16099
# exit_value = 16169.0 at 2023/10/30 13:26
# profit = 3500.0
# Sell to cover at 2023/11/2 8:46 with Close 16270.0
# Trade completed
#
# Buy at 2023/11/2 8:45 with target value 16057
# exit_value = 16115.0 at 2023/11/1 8:45
# profit = 2900.0
# Sell to cover at 2023/11/2 8:46 with Close 16270.0
# Trade completed
#
# Buy at 2023/11/10 13:42 with target value 16690
# exit_value = 16742.0 at 2023/11/9 11:20
# profit = 2600.0
# Sell to cover at 2023/11/13 8:45 with Close 16976.0
# Trade completed
#
# Buy at 2023/11/10 12:23 with target value 16673
# exit_value = 16698.0 at 2023/11/10 10:17
# profit = 1250.0
# Sell to cover at 2023/11/10 12:33 with Close 16698.0
# Trade completed
#
# Buy at 2023/11/23 9:34 with target value 17289
# exit_value = 17333.0 at 2023/11/22 9:44
# profit = -650.0
# Sell to cover at 2023/11/23 10:06 with Close 17278.0
# Trade completed
#
# Buy at 2023/11/23 12:33 with target value 17262
# exit_value = 17292.0 at 2023/11/22 12:36
# profit = 1500.0
# Sell to cover at 2023/11/23 12:35 with Close 17298.0
# Trade completed
#
# Buy at 2023/11/28 9:46 with target value 17221
# exit_value = 17268.0 at 2023/11/23 11:24
# profit = 2350.0
# Sell to cover at 2023/11/28 9:56 with Close 17268.0
# Trade completed
#
# Buy at 2023/12/6 8:45 with target value 17308
# exit_value = 17372.0 at 2023/11/30 10:39
# profit = 3200.0
# Sell to cover at 2023/12/6 8:46 with Close 17392.0
# Trade completed
#
# Buy at 2023/12/5 12:01 with target value 17281
# exit_value = 17303.0 at 2023/12/5 10:07
# profit = 1100.0
# Sell to cover at 2023/12/5 12:12 with Close 17304.0
# Trade completed

# %%
#空頭進場
# 初始化必要欄位
open_positions = []
buylong = []
selltoover = []
open_positions = []

feePaid = 40  # 假設每次交易手續費

# 找到符合條件的 valid_indices
valid_indices = df[(df['calculated_long_entry'].notna())].index 

for idx in valid_indices:
    # 使用 for 迴圈尋找在 idx 之後的進場機會
    for entry_idx in range(idx + 1, len(df)):
        if df.loc[entry_idx, 'Close'] < df.loc[idx, 'calculated_long_entry']:
            target_value = round(df.loc[idx+1, 'Close'])
            buylong.append(entry_idx)
            open_positions.append(entry_idx)  # 記錄未平倉的進場單
            print(f"Sell at {df.loc[entry_idx, 'Date']} with target value {target_value}")
            for exit_idx in range(idx - 1, -1, -1):
                if not pd.isna(df.loc[exit_idx, 'long_entry']):
                    exit_value = df.loc[exit_idx, 'long_entry']
                    print(f"exit_value = {exit_value} at {df.loc[exit_idx, 'Date']}")
                    break

            # 出場邏輯
            for next_idx in range(entry_idx + 1, len(df)):
                # 檢查出場條件：1. Close > 前一個有值的 long_entry 或 2. 遇到 peaks == 1
                if df.loc[next_idx, 'Close'] <= exit_value :
                    profit = 50 * (target_value - df.loc[next_idx+1, 'Close'])
                    profit_fee = profit - feePaid * 2
                    profit_dict[next_idx] = profit
                    print(f"profit = {profit}")
                    profit_fee_dict[next_idx] = profit_fee
                    selltoover.append(next_idx)
                    print(f"Buy to cover at {df.loc[next_idx, 'Date']} with Close {df.loc[next_idx, 'Close']}")
                    print("Trade completed\n")
                    open_positions.remove(entry_idx)

                    # Realized PnL
                    profit_fee_realized = profit - feePaid * 2
                    profit_fee_list_realized.append(profit_fee_realized)
                    break
                
                elif df.loc[next_idx, 'Judge_Peak'] == 1 :
                    profit_fee = profit - feePaid * 2
                    profit_dict[next_idx] = profit
                    print(f"profit = {profit}")
                    profit_fee_dict[next_idx] = profit_fee
                    selltoover.append(next_idx)
                    print(f"Buy to cover at {df.loc[next_idx, 'Date']} with Close {df.loc[next_idx, 'Close']}")
                    print("Trade completed\n")
                    open_positions.remove(entry_idx)

                    # Realized PnL
                    profit_fee_realized = profit - feePaid * 2
                    profit_fee_list_realized.append(profit_fee_realized)
                    break

            # 找到一次進場機會後跳出內層進場迴圈
            break
# Out:
# Sell at 2011/1/18 8:45 with target value 8923
# exit_value = 8855.0 at 2011/1/7 9:30
# profit = 250.0
# Buy to cover at 2011/1/18 9:43 with Close 8927.0
# Trade completed
#
# Sell at 2011/1/13 10:55 with target value 8966
# exit_value = 8911.0 at 2011/1/11 13:04
# profit = 250.0
# Buy to cover at 2011/1/13 11:34 with Close 8987.0
# Trade completed
#
# Sell at 2011/1/13 10:21 with target value 8974
# exit_value = 8971.0 at 2011/1/12 12:05
# profit = 350.0
# Buy to cover at 2011/1/13 10:48 with Close 8971.0
# Trade completed
#
# Sell at 2011/1/21 8:45 with target value 8984
# exit_value = 8967.0 at 2011/1/18 11:52
# profit = 950.0
# Buy to cover at 2011/1/21 8:46 with Close 8967.0
# Trade completed
#
# Sell at 2011/1/21 8:45 with target value 9017
# exit_value = 8975.0 at 2011/1/18 13:30
# profit = 2600.0
# Buy to cover at 2011/1/21 8:46 with Close 8967.0
# Trade completed
#
# Sell at 2011/1/20 9:18 with target value 9020
# exit_value = 9008.0 at 2011/1/19 11:23
# profit = 600.0
# Buy to cover at 2011/1/20 9:19 with Close 9007.0
# Trade completed
#
# Sell at 2011/1/25 13:14 with target value 8995
# exit_value = 8988.0 at 2011/1/25 11:02
# profit = 600.0
# Buy to cover at 2011/1/25 13:19 with Close 8988.0
# Trade completed
#
# Sell at 2011/2/9 12:19 with target value 9049
# exit_value = 8997.0 at 2011/1/25 13:03
# profit = 2950.0
# Buy to cover at 2011/2/9 12:24 with Close 8983.0
# Trade completed
#
# Sell at 2011/2/9 9:28 with target value 9093
# exit_value = 9046.0 at 2011/1/26 13:12
# profit = 2950.0
# Buy to cover at 2011/2/9 10:02 with Close 9098.0
# Trade completed
#
# Sell at 2011/2/8 9:45 with target value 9104
# exit_value = 9095.0 at 2011/1/27 12:00
# profit = 1050.0
# Buy to cover at 2011/2/8 9:46 with Close 9089.0
# Trade completed
#
# Sell at 2011/2/8 9:44 with target value 9136
# exit_value = 9100.0 at 2011/1/28 10:19
# profit = 2350.0
# Buy to cover at 2011/2/8 9:45 with Close 9086.0
# Trade completed
#
# Sell at 2011/2/16 12:50 with target value 8739
# exit_value = 8718.0 at 2011/2/16 10:12
# profit = 800.0
# Buy to cover at 2011/2/16 12:51 with Close 8717.0
# Trade completed
#
# Sell at 2011/2/21 9:29 with target value 8796
# exit_value = 8732.0 at 2011/2/16 12:20
# profit = 800.0
# Buy to cover at 2011/2/21 10:18 with Close 8787.0
# Trade completed
#
# Sell at 2011/2/21 8:45 with target value 8817
# exit_value = 8794.0 at 2011/2/18 11:23
# profit = 1200.0
# Buy to cover at 2011/2/21 8:48 with Close 8786.0
# Trade completed
#
# Sell at 2011/3/2 12:58 with target value 8630
# exit_value = 8591.0 at 2011/3/2 8:45
# profit = 1750.0
# Buy to cover at 2011/3/2 13:00 with Close 8586.0
# Trade completed
#
# Sell at 2011/3/10 11:07 with target value 8640
# exit_value = 8630.0 at 2011/3/2 10:32
# profit = 350.0
# Buy to cover at 2011/3/10 11:59 with Close 8630.0
# Trade completed
#
# Sell at 2011/3/10 9:35 with target value 8723
# exit_value = 8648.0 at 2011/3/3 10:05
# profit = 3400.0
# Buy to cover at 2011/3/10 9:48 with Close 8646.0
# Trade completed
#
# Sell at 2011/3/9 12:22 with target value 8734
# exit_value = 8728.0 at 2011/3/3 13:07
# profit = 900.0
# Buy to cover at 2011/3/9 12:23 with Close 8723.0
# Trade completed
#
# Sell at 2011/3/8 13:27 with target value 8735
# exit_value = 8730.0 at 2011/3/8 11:34
# profit = 900.0
# Buy to cover at 2011/3/9 8:45 with Close 8794.0
# Trade completed
#
# Sell at 2011/3/9 12:16 with target value 8782
# exit_value = 8733.0 at 2011/3/8 12:45
# profit = 2950.0
# Buy to cover at 2011/3/9 12:22 with Close 8721.0
# Trade completed
#
# Sell at 2011/6/27 8:45 with target value 8411
# exit_value = 8323.0 at 2011/3/18 13:43
# profit = 6500.0
# Buy to cover at 2011/6/27 8:46 with Close 8286.0
# Trade completed
#
# Sell at 2011/3/22 13:44 with target value 8445
# exit_value = 8405.0 at 2011/3/21 10:43
# profit = 2050.0
# Buy to cover at 2011/3/23 8:45 with Close 8404.0
# Trade completed
#
# Sell at 2011/3/22 13:14 with target value 8453
# exit_value = 8437.0 at 2011/3/22 10:10
# profit = 1050.0
# Buy to cover at 2011/3/22 13:17 with Close 8437.0
# Trade completed
#
# Sell at 2011/3/22 13:07 with target value 8456
# exit_value = 8448.0 at 2011/3/22 11:45
# profit = 500.0
# Buy to cover at 2011/3/22 13:09 with Close 8445.0
# Trade completed
#
# Sell at 2011/3/23 12:50 with target value 8463
# exit_value = 8452.0 at 2011/3/22 12:50
# profit = 450.0
# Buy to cover at 2011/3/23 13:40 with Close 8451.0
# Trade completed
#
# Sell at 2011/6/17 10:14 with target value 8488
# exit_value = 8460.0 at 2011/3/23 12:40
# profit = 450.0
# Buy to cover at 2011/6/17 11:01 with Close 8483.0
# Trade completed
#
# Sell at 2011/3/29 8:45 with target value 8552
# exit_value = 8482.0 at 2011/3/24 9:55
# profit = 3550.0
# Buy to cover at 2011/3/29 8:47 with Close 8479.0
# Trade completed
#
# Sell at 2011/3/28 9:00 with target value 8583
# exit_value = 8551.0 at 2011/3/25 9:52
# profit = 1400.0
# Buy to cover at 2011/3/28 9:04 with Close 8550.0
# Trade completed
#
# Sell at 2011/3/31 11:35 with target value 8614
# exit_value = 8578.0 at 2011/3/25 13:00
# profit = 1800.0
# Buy to cover at 2011/3/31 11:36 with Close 8578.0
# Trade completed
#
# Sell at 2011/3/30 13:25 with target value 8630
# exit_value = 8612.0 at 2011/3/30 10:56
# profit = 1050.0
# Buy to cover at 2011/3/30 13:30 with Close 8610.0
# Trade completed
#
# Sell at 2011/4/19 9:03 with target value 8648
# exit_value = 8632.0 at 2011/3/30 12:59
# profit = 750.0
# Buy to cover at 2011/4/19 9:23 with Close 8626.0
# Trade completed
#
# Sell at 2011/4/12 10:48 with target value 8836
# exit_value = 8646.0 at 2011/4/1 12:28
# profit = 750.0
# Buy to cover at 2011/4/12 11:44 with Close 8736.0
# Trade completed
#
# Sell at 2011/4/11 9:12 with target value 8858
# exit_value = 8833.0 at 2011/4/6 13:00
# profit = 1450.0
# Buy to cover at 2011/4/11 9:17 with Close 8823.0
# Trade completed
#
# Sell at 2011/4/8 13:03 with target value 8872
# exit_value = 8855.0 at 2011/4/7 12:28
# profit = 850.0
# Buy to cover at 2011/4/8 13:04 with Close 8855.0
# Trade completed
#
# Sell at 2011/4/8 12:41 with target value 8909
# exit_value = 8862.0 at 2011/4/8 9:34
# profit = 2500.0
# Buy to cover at 2011/4/8 12:47 with Close 8862.0
# Trade completed
#
# Sell at 2011/4/8 12:31 with target value 8910
# exit_value = 8903.0 at 2011/4/8 11:15
# profit = 700.0
# Buy to cover at 2011/4/8 12:32 with Close 8898.0
# Trade completed
#
# Sell at 2011/4/15 9:24 with target value 8791
# exit_value = 8775.0 at 2011/4/14 12:01
# profit = 750.0
# Buy to cover at 2011/4/15 9:25 with Close 8773.0
# Trade completed
#
# Sell at 2011/5/19 13:42 with target value 8977
# exit_value = 8780.0 at 2011/4/15 8:45
# profit = 750.0
# Buy to cover at 2011/5/20 10:13 with Close 8903.0
# Trade completed
#
# Sell at 2011/4/25 9:44 with target value 8981
# exit_value = 8968.0 at 2011/4/21 12:02
# profit = 1150.0
# Buy to cover at 2011/4/25 9:46 with Close 8965.0
# Trade completed
#
# Sell at 2011/4/25 9:44 with target value 8977
# exit_value = 8972.0 at 2011/4/21 13:34
# profit = 600.0
# Buy to cover at 2011/4/25 9:45 with Close 8969.0
# Trade completed
#
# Sell at 2011/4/25 11:57 with target value 8994
# exit_value = 8982.0 at 2011/4/22 10:38
# profit = 400.0
# Buy to cover at 2011/4/25 12:05 with Close 8980.0
# Trade completed
#
# Sell at 2011/4/28 12:23 with target value 9050
# exit_value = 8994.0 at 2011/4/25 11:54
# profit = 400.0
# Buy to cover at 2011/4/28 12:46 with Close 9040.0
# Trade completed
#
# Sell at 2011/4/28 11:21 with target value 9069
# exit_value = 9048.0 at 2011/4/27 11:53
# profit = 1350.0
# Buy to cover at 2011/4/28 11:24 with Close 9035.0
# Trade completed
#
# Sell at 2011/5/6 8:45 with target value 9038
# exit_value = 9011.0 at 2011/5/5 11:33
# profit = 2600.0
# Buy to cover at 2011/5/6 8:46 with Close 8986.0
# Trade completed
#
# Sell at 2011/5/10 9:12 with target value 9088
# exit_value = 9026.0 at 2011/5/5 13:30
# profit = 2600.0
# Buy to cover at 2011/5/10 10:26 with Close 9058.0
# Trade completed
#
# Sell at 2011/5/19 12:27 with target value 9009
# exit_value = 8921.0 at 2011/5/18 10:19
# profit = 4750.0
# Buy to cover at 2011/5/19 12:45 with Close 8913.0
# Trade completed
#
# Sell at 2011/5/30 8:54 with target value 8785
# exit_value = 8723.0 at 2011/5/26 9:53
# profit = 3200.0
# Buy to cover at 2011/5/30 9:02 with Close 8722.0
# Trade completed
#
# Sell at 2011/5/27 12:51 with target value 8816
# exit_value = 8773.0 at 2011/5/27 8:45
# profit = 1950.0
# Buy to cover at 2011/5/27 13:19 with Close 8770.0
# Trade completed
#
# Sell at 2011/6/10 12:34 with target value 8920
# exit_value = 8811.0 at 2011/5/27 12:38
# profit = 7050.0
# Buy to cover at 2011/6/13 8:45 with Close 8782.0
# Trade completed
#
# Sell at 2011/6/10 10:01 with target value 9084
# exit_value = 8912.0 at 2011/5/31 11:18
# profit = 9250.0
# Buy to cover at 2011/6/10 10:44 with Close 8900.0
# Trade completed
#
# Sell at 2011/7/14 11:59 with target value 8440
# exit_value = 8363.0 at 2011/6/28 11:01
# profit = 3450.0
# Buy to cover at 2011/7/14 12:36 with Close 8360.0
# Trade completed
#
# Sell at 2011/7/12 9:59 with target value 8490
# exit_value = 8446.0 at 2011/6/29 12:23
# profit = 3450.0
# Buy to cover at 2011/7/12 11:59 with Close 8459.0
# Trade completed
#
# Sell at 2011/7/12 8:45 with target value 8595
# exit_value = 8491.0 at 2011/6/30 12:17
# profit = 5350.0
# Buy to cover at 2011/7/12 9:34 with Close 8488.0
# Trade completed
#
# Sell at 2011/7/4 13:34 with target value 8643
# exit_value = 8588.0 at 2011/7/1 12:54
# profit = 2700.0
# Buy to cover at 2011/7/5 9:03 with Close 8588.0
# Trade completed
#
# Sell at 2011/7/8 12:03 with target value 8690
# exit_value = 8638.0 at 2011/7/4 11:03
# profit = 2700.0
# Buy to cover at 2011/7/8 13:03 with Close 8679.0
# Trade completed
#
# Sell at 2011/7/8 11:02 with target value 8704
# exit_value = 8687.0 at 2011/7/6 12:36
# profit = 950.0
# Buy to cover at 2011/7/8 11:04 with Close 8679.0
# Trade completed
#
# Sell at 2011/7/18 12:36 with target value 8538
# exit_value = 8515.0 at 2011/7/15 11:43
# profit = 1300.0
# Buy to cover at 2011/7/18 12:37 with Close 8514.0
# Trade completed
#
# Sell at 2011/8/2 9:17 with target value 8642
# exit_value = 8535.0 at 2011/7/18 11:21
# profit = 1300.0
# Buy to cover at 2011/8/2 11:11 with Close 8577.0
# Trade completed
#
# Sell at 2011/7/25 8:45 with target value 8706
# exit_value = 8635.0 at 2011/7/20 11:14
# profit = 3600.0
# Buy to cover at 2011/7/25 10:02 with Close 8635.0
# Trade completed
#
# Sell at 2011/7/28 8:45 with target value 8749
# exit_value = 8707.0 at 2011/7/22 12:37
# profit = 3000.0
# Buy to cover at 2011/7/28 8:46 with Close 8693.0
# Trade completed
#
# Sell at 2011/8/11 8:45 with target value 7638
# exit_value = 7603.0 at 2011/8/10 9:52
# profit = 5200.0
# Buy to cover at 2011/8/11 8:46 with Close 7521.0
# Trade completed
#
# Sell at 2011/8/11 11:38 with target value 7657
# exit_value = 7636.0 at 2011/8/10 11:31
# profit = 1100.0
# Buy to cover at 2011/8/11 11:44 with Close 7626.0
# Trade completed
#
# Sell at 2011/8/12 11:37 with target value 7725
# exit_value = 7667.0 at 2011/8/11 11:29
# profit = 4250.0
# Buy to cover at 2011/8/12 11:40 with Close 7663.0
# Trade completed
#
# Sell at 2011/8/16 12:19 with target value 7796
# exit_value = 7720.0 at 2011/8/12 10:18
# profit = 4250.0
# Buy to cover at 2011/8/17 8:48 with Close 7789.0
# Trade completed
#
# Sell at 2011/8/24 10:18 with target value 7482
# exit_value = 7326.0 at 2011/8/22 10:38
# profit = 4250.0
# Buy to cover at 2011/8/24 11:24 with Close 7417.0
# Trade completed
#
# Sell at 2011/9/5 9:16 with target value 7569
# exit_value = 7475.0 at 2011/8/24 9:05
# profit = 4400.0
# Buy to cover at 2011/9/5 9:29 with Close 7471.0
# Trade completed
#
# Sell at 2011/8/30 11:26 with target value 7595
# exit_value = 7572.0 at 2011/8/29 12:34
# profit = 950.0
# Buy to cover at 2011/8/30 11:27 with Close 7570.0
# Trade completed
#
# Sell at 2011/9/5 8:45 with target value 7626
# exit_value = 7601.0 at 2011/8/30 11:17
# profit = 4400.0
# Buy to cover at 2011/9/5 8:46 with Close 7548.0
# Trade completed
#
# Sell at 2011/9/2 9:52 with target value 7779
# exit_value = 7630.0 at 2011/8/31 13:02
# profit = 4400.0
# Buy to cover at 2011/9/2 11:15 with Close 7690.0
# Trade completed
#
# Sell at 2011/10/3 8:45 with target value 7174
# exit_value = 7095.0 at 2011/9/27 11:45
# profit = 7050.0
# Buy to cover at 2011/10/3 8:46 with Close 7023.0
# Trade completed
#
# Sell at 2011/11/21 10:36 with target value 7160
# exit_value = 7035.0 at 2011/10/5 9:17
# profit = 7050.0
# Buy to cover at 2011/11/21 12:22 with Close 7088.0
# Trade completed
#
# Sell at 2011/11/21 8:50 with target value 7221
# exit_value = 7161.0 at 2011/10/6 10:54
# profit = 3250.0
# Buy to cover at 2011/11/21 8:56 with Close 7154.0
# Trade completed
#
# Sell at 2011/10/20 11:13 with target value 7380
# exit_value = 7215.0 at 2011/10/7 12:03
# profit = 3250.0
# Buy to cover at 2011/10/20 12:01 with Close 7282.0
# Trade completed
#
# Sell at 2011/10/12 8:51 with target value 7381
# exit_value = 7370.0 at 2011/10/11 10:49
# profit = 500.0
# Buy to cover at 2011/10/12 8:52 with Close 7370.0
# Trade completed
#
# Sell at 2011/10/12 13:03 with target value 7401
# exit_value = 7376.0 at 2011/10/11 12:52
# profit = 500.0
# Buy to cover at 2011/10/13 8:45 with Close 7450.0
# Trade completed
#
# Sell at 2011/10/18 8:45 with target value 7456
# exit_value = 7398.0 at 2011/10/12 12:37
# profit = 4550.0
# Buy to cover at 2011/10/18 8:46 with Close 7362.0
# Trade completed
#
# Sell at 2011/10/26 8:45 with target value 7493
# exit_value = 7455.0 at 2011/10/17 12:45
# profit = 3850.0
# Buy to cover at 2011/10/26 8:46 with Close 7415.0
# Trade completed
#
# Sell at 2011/10/25 13:31 with target value 7496
# exit_value = 7488.0 at 2011/10/25 10:34
# profit = 650.0
# Buy to cover at 2011/10/25 13:37 with Close 7488.0
# Trade completed
#
# Sell at 2011/11/2 8:45 with target value 7527
# exit_value = 7494.0 at 2011/10/25 13:08
# profit = 1750.0
# Buy to cover at 2011/11/2 8:46 with Close 7493.0
# Trade completed
#
# Sell at 2011/11/1 9:07 with target value 7564
# exit_value = 7518.0 at 2011/10/27 8:50
# profit = 1750.0
# Buy to cover at 2011/11/1 9:44 with Close 7577.0
# Trade completed
#
# Sell at 2011/10/31 13:10 with target value 7582
# exit_value = 7564.0 at 2011/10/27 11:17
# profit = 1350.0
# Buy to cover at 2011/10/31 13:13 with Close 7563.0
# Trade completed
#
# Sell at 2011/10/28 12:43 with target value 7716
# exit_value = 7581.0 at 2011/10/27 12:53
# profit = 1350.0
# Buy to cover at 2011/10/31 8:45 with Close 7661.0
# Trade completed
#
# Sell at 2011/11/4 10:55 with target value 7621
# exit_value = 7623.0 at 2011/11/1 13:11
# profit = -150.0
# Buy to cover at 2011/11/4 11:02 with Close 7623.0
# Trade completed
#
# Sell at 2011/11/4 13:06 with target value 7645
# exit_value = 7627.0 at 2011/11/4 10:54
# profit = 1150.0
# Buy to cover at 2011/11/4 13:09 with Close 7624.0
# Trade completed
#
# Sell at 2011/11/8 10:12 with target value 7653
# exit_value = 7638.0 at 2011/11/4 12:45
# profit = 2400.0
# Buy to cover at 2011/11/8 10:13 with Close 7611.0
# Trade completed
#
# Sell at 2011/11/14 13:00 with target value 7551
# exit_value = 7536.0 at 2011/11/14 10:30
# profit = 600.0
# Buy to cover at 2011/11/14 13:30 with Close 7534.0
# Trade completed
#
# Sell at 2011/11/30 11:14 with target value 6926
# exit_value = 6866.0 at 2011/11/28 9:59
# profit = 3000.0
# Buy to cover at 2011/11/30 11:16 with Close 6864.0
# Trade completed
#
# Sell at 2011/11/30 9:02 with target value 6944
# exit_value = 6922.0 at 2011/11/29 10:10
# profit = 1950.0
# Buy to cover at 2011/11/30 9:41 with Close 6916.0
# Trade completed
#
# Sell at 2011/12/6 11:46 with target value 7150
# exit_value = 6932.0 at 2011/11/30 8:45
# profit = 1950.0
# Buy to cover at 2011/12/7 8:45 with Close 7027.0
# Trade completed
#
# Sell at 2011/12/2 9:21 with target value 7225
# exit_value = 7146.0 at 2011/12/1 9:56
# profit = 3900.0
# Buy to cover at 2011/12/2 10:47 with Close 7145.0
# Trade completed
#
# Sell at 2011/12/22 12:56 with target value 6961
# exit_value = 6952.0 at 2011/12/22 10:32
# profit = 3900.0
# Buy to cover at 2011/12/23 8:45 with Close 7050.0
# Trade completed
#
# Sell at 2011/12/29 9:05 with target value 7110
# exit_value = 6960.0 at 2011/12/22 12:36
# profit = 3900.0
# Buy to cover at 2011/12/29 9:46 with Close 7030.0
# Trade completed
#
# Sell at 2012/1/6 10:44 with target value 7084
# exit_value = 7072.0 at 2012/1/4 10:06
# profit = 700.0
# Buy to cover at 2012/1/6 10:45 with Close 7068.0
# Trade completed
#
# Sell at 2012/1/6 10:37 with target value 7090
# exit_value = 7083.0 at 2012/1/5 12:37
# profit = 650.0
# Buy to cover at 2012/1/6 10:38 with Close 7079.0
# Trade completed
#
# Sell at 2012/1/16 9:41 with target value 7166
# exit_value = 7084.0 at 2012/1/6 9:12
# profit = 4000.0
# Buy to cover at 2012/1/16 10:16 with Close 7081.0
# Trade completed
#
# Sell at 2012/1/12 9:08 with target value 7184
# exit_value = 7165.0 at 2012/1/10 12:14
# profit = 950.0
# Buy to cover at 2012/1/12 9:11 with Close 7164.0
# Trade completed
#
# Sell at 2012/1/13 13:07 with target value 7215
# exit_value = 7181.0 at 2012/1/11 12:58
# profit = 2100.0
# Buy to cover at 2012/1/13 13:15 with Close 7169.0
# Trade completed
#
# Sell at 2012/1/18 12:42 with target value 7220
# exit_value = 7206.0 at 2012/1/13 10:18
# profit = 1150.0
# Buy to cover at 2012/1/18 12:43 with Close 7204.0
# Trade completed
#
# Sell at 2012/1/18 12:38 with target value 7227
# exit_value = 7216.0 at 2012/1/18 10:37
# profit = 600.0
# Buy to cover at 2012/1/18 12:39 with Close 7213.0
# Trade completed
#
# Sell at 2012/5/15 9:05 with target value 7422
# exit_value = 7227.0 at 2012/1/18 12:35
# profit = 600.0
# Buy to cover at 2012/5/15 9:59 with Close 7347.0
# Trade completed
#
# Sell at 2012/1/31 12:27 with target value 7479
# exit_value = 7426.0 at 2012/1/30 11:35
# profit = 600.0
# Buy to cover at 2012/1/31 13:30 with Close 7468.0
# Trade completed
#
# Sell at 2012/4/23 8:49 with target value 7512
# exit_value = 7474.0 at 2012/1/31 11:38
# profit = 2200.0
# Buy to cover at 2012/4/23 8:59 with Close 7471.0
# Trade completed
#
# Sell at 2012/4/9 9:05 with target value 7522
# exit_value = 7508.0 at 2012/2/1 10:59
# profit = 2200.0
# Buy to cover at 2012/4/9 9:45 with Close 7586.0
# Trade completed
#
# Sell at 2012/4/5 9:29 with target value 7598
# exit_value = 7521.0 at 2012/2/1 12:55
# profit = 2200.0
# Buy to cover at 2012/4/5 10:11 with Close 7592.0
# Trade completed
#
# Sell at 2012/4/5 9:01 with target value 7612
# exit_value = 7588.0 at 2012/2/2 10:23
# profit = 1600.0
# Buy to cover at 2012/4/5 9:14 with Close 7572.0
# Trade completed
#
# Sell at 2012/4/5 9:01 with target value 7615
# exit_value = 7607.0 at 2012/2/3 9:21
# profit = 600.0
# Buy to cover at 2012/4/5 9:02 with Close 7600.0
# Trade completed
#
# Sell at 2012/4/5 9:00 with target value 7630
# exit_value = 7613.0 at 2012/2/3 10:46
# profit = 1500.0
# Buy to cover at 2012/4/5 9:01 with Close 7585.0
# Trade completed
#
# Sell at 2012/4/5 8:45 with target value 7722
# exit_value = 7628.0 at 2012/2/3 12:11
# profit = 5200.0
# Buy to cover at 2012/4/5 8:46 with Close 7625.0
# Trade completed
#
# Sell at 2012/2/6 8:45 with target value 7738
# exit_value = 7722.0 at 2012/2/4 11:55
# profit = 1400.0
# Buy to cover at 2012/2/6 8:46 with Close 7707.0
# Trade completed
#
# Sell at 2012/4/3 11:43 with target value 7837
# exit_value = 7732.0 at 2012/2/4 13:23
# profit = 1400.0
# Buy to cover at 2012/4/3 13:20 with Close 7767.0
# Trade completed
#
# Sell at 2012/2/13 9:07 with target value 7866
# exit_value = 7842.0 at 2012/2/9 8:55
# profit = 1400.0
# Buy to cover at 2012/2/13 9:53 with Close 7874.0
# Trade completed
#
# Sell at 2012/2/10 10:04 with target value 7875
# exit_value = 7862.0 at 2012/2/9 12:12
# profit = 650.0
# Buy to cover at 2012/2/10 10:06 with Close 7861.0
# Trade completed
#
# Sell at 2012/2/14 9:16 with target value 7911
# exit_value = 7874.0 at 2012/2/10 9:48
# profit = 1950.0
# Buy to cover at 2012/2/14 9:42 with Close 7873.0
# Trade completed
#
# Sell at 2012/2/16 12:44 with target value 7970
# exit_value = 7913.0 at 2012/2/13 12:28
# profit = 2750.0
# Buy to cover at 2012/2/16 13:06 with Close 7912.0
# Trade completed
#
# Sell at 2012/2/17 9:46 with target value 7973
# exit_value = 7963.0 at 2012/2/16 8:45
# profit = 400.0
# Buy to cover at 2012/2/17 9:48 with Close 7958.0
# Trade completed
#
# Sell at 2012/2/23 8:45 with target value 8012
# exit_value = 7968.0 at 2012/2/17 9:44
# profit = 2800.0
# Buy to cover at 2012/2/23 8:46 with Close 7954.0
# Trade completed
#
# Sell at 2012/3/5 10:03 with target value 8099
# exit_value = 8009.0 at 2012/2/22 12:32
# profit = 2800.0
# Buy to cover at 2012/3/5 11:44 with Close 8031.0
# Trade completed
#
# Sell at 2012/3/3 8:48 with target value 8138
# exit_value = 8096.0 at 2012/2/29 12:35
# profit = 1700.0
# Buy to cover at 2012/3/3 8:55 with Close 8096.0
# Trade completed
#
# Sell at 2012/3/12 8:46 with target value 8003
# exit_value = 7978.0 at 2012/3/8 12:10
# profit = 1200.0
# Buy to cover at 2012/3/12 8:53 with Close 7978.0
# Trade completed
#
# Sell at 2012/3/19 9:48 with target value 8052
# exit_value = 8003.0 at 2012/3/9 13:38
# profit = 3150.0
# Buy to cover at 2012/3/19 10:45 with Close 7998.0
# Trade completed
#
# Sell at 2012/3/16 13:27 with target value 8167
# exit_value = 8044.0 at 2012/3/13 12:57
# profit = 3150.0
# Buy to cover at 2012/3/19 8:45 with Close 8100.0
# Trade completed
#
# Sell at 2012/3/23 9:32 with target value 8064
# exit_value = 8060.0 at 2012/3/22 10:31
# profit = 150.0
# Buy to cover at 2012/3/23 9:56 with Close 8058.0
# Trade completed
#
# Sell at 2012/3/26 8:51 with target value 8069
# exit_value = 8061.0 at 2012/3/23 9:24
# profit = 450.0
# Buy to cover at 2012/3/26 8:52 with Close 8060.0
# Trade completed
#
# Sell at 2012/4/9 8:45 with target value 7657
# exit_value = 7623.0 at 2012/4/5 13:38
# profit = 4650.0
# Buy to cover at 2012/4/9 8:46 with Close 7553.0
# Trade completed
#
# Sell at 2012/4/17 9:17 with target value 7721
# exit_value = 7652.0 at 2012/4/10 10:56
# profit = 3650.0
# Buy to cover at 2012/4/17 9:27 with Close 7647.0
# Trade completed
#
# Sell at 2012/4/16 8:45 with target value 7730
# exit_value = 7719.0 at 2012/4/13 10:44
# profit = 1800.0
# Buy to cover at 2012/4/16 8:46 with Close 7699.0
# Trade completed
#
# Sell at 2012/4/26 9:53 with target value 7533
# exit_value = 7510.0 at 2012/4/25 9:59
# profit = 1150.0
# Buy to cover at 2012/4/26 9:58 with Close 7507.0
# Trade completed
#
# Sell at 2012/4/26 9:29 with target value 7545
# exit_value = 7535.0 at 2012/4/25 12:17
# profit = 900.0
# Buy to cover at 2012/4/26 9:30 with Close 7528.0
# Trade completed
#
# Sell at 2012/5/7 8:45 with target value 7655
# exit_value = 7538.0 at 2012/4/26 9:18
# profit = 6100.0
# Buy to cover at 2012/5/7 9:05 with Close 7532.0
# Trade completed
#
# Sell at 2012/5/4 13:20 with target value 7666
# exit_value = 7657.0 at 2012/5/3 9:00
# profit = 400.0
# Buy to cover at 2012/5/4 13:21 with Close 7657.0
# Trade completed
#
# Sell at 2012/5/31 8:45 with target value 7303
# exit_value = 7112.0 at 2012/5/28 13:27
# profit = 9400.0
# Buy to cover at 2012/5/31 9:09 with Close 7110.0
# Trade completed
#
# Sell at 2012/6/8 9:04 with target value 7021
# exit_value = 6968.0 at 2012/6/5 11:20
# profit = 2900.0
# Buy to cover at 2012/6/8 9:56 with Close 6965.0
# Trade completed
#
# Sell at 2012/6/6 13:41 with target value 7029
# exit_value = 7010.0 at 2012/6/6 10:59
# profit = 2900.0
# Buy to cover at 2012/6/7 8:45 with Close 7133.0
# Trade completed
#
# Sell at 2012/6/7 12:41 with target value 7074
# exit_value = 7024.0 at 2012/6/6 12:43
# profit = 2400.0
# Buy to cover at 2012/6/7 12:56 with Close 7021.0
# Trade completed
#
# Sell at 2012/6/12 8:45 with target value 7074
# exit_value = 7065.0 at 2012/6/7 10:07
# profit = 4800.0
# Buy to cover at 2012/6/12 8:46 with Close 6980.0
# Trade completed
#
# Sell at 2012/6/22 8:45 with target value 7040
# exit_value = 7024.0 at 2012/6/13 9:49
# profit = 1550.0
# Buy to cover at 2012/6/22 8:46 with Close 7019.0
# Trade completed
#
# Sell at 2012/6/15 8:45 with target value 7090
# exit_value = 7035.0 at 2012/6/14 9:07
# profit = 1550.0
# Buy to cover at 2012/6/15 9:18 with Close 7075.0
# Trade completed
#
# Sell at 2012/6/21 12:20 with target value 7122
# exit_value = 7086.0 at 2012/6/14 12:35
# profit = 1550.0
# Buy to cover at 2012/6/21 12:50 with Close 7110.0
# Trade completed
#
# Sell at 2012/6/21 8:46 with target value 7259
# exit_value = 7117.0 at 2012/6/15 12:00
# profit = 7050.0
# Buy to cover at 2012/6/21 10:32 with Close 7117.0
# Trade completed
#
# Sell at 2012/6/19 8:50 with target value 7279
# exit_value = 7244.0 at 2012/6/18 9:54
# profit = 1900.0
# Buy to cover at 2012/6/19 9:04 with Close 7243.0
# Trade completed
#
# Sell at 2012/6/21 8:45 with target value 7284
# exit_value = 7276.0 at 2012/6/18 12:29
# profit = 6450.0
# Buy to cover at 2012/6/21 8:46 with Close 7153.0
# Trade completed
#
# Sell at 2012/6/28 9:59 with target value 7011
# exit_value = 6988.0 at 2012/6/27 12:18
# profit = 1100.0
# Buy to cover at 2012/6/28 10:00 with Close 6984.0
# Trade completed
#
# Sell at 2012/7/16 10:12 with target value 7110
# exit_value = 7010.0 at 2012/6/28 9:44
# profit = 1100.0
# Buy to cover at 2012/7/16 11:42 with Close 7062.0
# Trade completed
#
# Sell at 2012/7/12 9:29 with target value 7142
# exit_value = 7104.0 at 2012/6/29 13:10
# profit = 2600.0
# Buy to cover at 2012/7/12 9:44 with Close 7102.0
# Trade completed
#
# Sell at 2012/7/10 10:58 with target value 7250
# exit_value = 7141.0 at 2012/7/2 12:38
# profit = 2600.0
# Buy to cover at 2012/7/10 12:32 with Close 7181.0
# Trade completed
#
# Sell at 2012/7/6 9:57 with target value 7283
# exit_value = 7245.0 at 2012/7/3 13:03
# profit = 1750.0
# Buy to cover at 2012/7/6 12:03 with Close 7245.0
# Trade completed
#
# Sell at 2012/7/5 10:03 with target value 7292
# exit_value = 7285.0 at 2012/7/4 12:39
# profit = 500.0
# Buy to cover at 2012/7/5 10:04 with Close 7283.0
# Trade completed
#
# Sell at 2012/7/17 10:58 with target value 7087
# exit_value = 7074.0 at 2012/7/13 13:08
# profit = 550.0
# Buy to cover at 2012/7/17 10:59 with Close 7068.0
# Trade completed
#
# Sell at 2012/7/18 9:35 with target value 7106
# exit_value = 7081.0 at 2012/7/17 10:44
# profit = 1150.0
# Buy to cover at 2012/7/18 10:09 with Close 7080.0
# Trade completed
#
# Sell at 2012/7/25 8:45 with target value 6873
# exit_value = 6860.0 at 2012/7/24 11:31
# profit = 4350.0
# Buy to cover at 2012/7/25 8:46 with Close 6781.0
# Trade completed
#
# Sell at 2012/11/1 9:25 with target value 7085
# exit_value = 7011.0 at 2012/7/27 13:15
# profit = 4350.0
# Buy to cover at 2012/11/1 10:37 with Close 7085.0
# Trade completed
#
# Sell at 2012/10/26 13:42 with target value 7133
# exit_value = 7084.0 at 2012/7/30 12:15
# profit = 4350.0
# Buy to cover at 2012/10/29 9:13 with Close 7124.0
# Trade completed
#
# Sell at 2012/8/3 10:15 with target value 7148
# exit_value = 7128.0 at 2012/7/31 11:28
# profit = 1250.0
# Buy to cover at 2012/8/3 10:16 with Close 7123.0
# Trade completed
#
# Sell at 2012/8/3 8:45 with target value 7190
# exit_value = 7135.0 at 2012/8/1 8:45
# profit = 2750.0
# Buy to cover at 2012/8/3 9:11 with Close 7134.0
# Trade completed
#
# Sell at 2012/10/26 10:44 with target value 7268
# exit_value = 7189.0 at 2012/8/1 12:23
# profit = 4250.0
# Buy to cover at 2012/10/26 11:23 with Close 7188.0
# Trade completed
#
# Sell at 2012/10/24 8:45 with target value 7309
# exit_value = 7258.0 at 2012/8/6 9:55
# profit = 3450.0
# Buy to cover at 2012/10/24 8:46 with Close 7239.0
# Trade completed
#
# Sell at 2012/8/30 8:55 with target value 7436
# exit_value = 7308.0 at 2012/8/8 11:16
# profit = 3450.0
# Buy to cover at 2012/8/30 12:40 with Close 7364.0
# Trade completed
#
# Sell at 2012/8/10 13:04 with target value 7445
# exit_value = 7431.0 at 2012/8/9 13:30
# profit = 850.0
# Buy to cover at 2012/8/10 13:06 with Close 7431.0
# Trade completed
#
# Sell at 2012/8/13 11:37 with target value 7451
# exit_value = 7440.0 at 2012/8/10 11:22
# profit = 550.0
# Buy to cover at 2012/8/13 11:59 with Close 7438.0
# Trade completed
#
# Sell at 2012/8/14 10:26 with target value 7510
# exit_value = 7452.0 at 2012/8/13 10:58
# profit = 550.0
# Buy to cover at 2012/8/14 11:25 with Close 7477.0
# Trade completed
#
# Sell at 2012/8/16 12:57 with target value 7495
# exit_value = 7497.0 at 2012/8/14 10:05
# profit = 200.0
# Buy to cover at 2012/8/16 12:58 with Close 7493.0
# Trade completed
#
# Sell at 2012/8/21 12:18 with target value 7527
# exit_value = 7499.0 at 2012/8/16 12:56
# profit = 1600.0
# Buy to cover at 2012/8/22 8:45 with Close 7491.0
# Trade completed
#
# Sell at 2012/8/30 8:45 with target value 7401
# exit_value = 7398.0 at 2012/8/29 12:17
# profit = 2250.0
# Buy to cover at 2012/8/30 8:46 with Close 7355.0
# Trade completed
#
# Sell at 2012/9/5 8:45 with target value 7458
# exit_value = 7381.0 at 2012/8/31 12:12
# profit = 4350.0
# Buy to cover at 2012/9/5 9:13 with Close 7381.0
# Trade completed
#
# Sell at 2012/10/11 12:46 with target value 7460
# exit_value = 7450.0 at 2012/9/10 11:47
# profit = 550.0
# Buy to cover at 2012/10/11 13:19 with Close 7450.0
# Trade completed
#
# Sell at 2012/10/11 12:37 with target value 7461
# exit_value = 7458.0 at 2012/9/11 12:06
# profit = 200.0
# Buy to cover at 2012/10/11 12:39 with Close 7457.0
# Trade completed
#
# Sell at 2012/10/11 8:45 with target value 7560
# exit_value = 7459.0 at 2012/9/11 13:08
# profit = 5050.0
# Buy to cover at 2012/10/11 12:37 with Close 7458.0
# Trade completed
#
# Sell at 2012/10/11 8:45 with target value 7594
# exit_value = 7560.0 at 2012/9/12 11:27
# profit = 5000.0
# Buy to cover at 2012/10/11 8:46 with Close 7492.0
# Trade completed
#
# Sell at 2012/10/4 9:58 with target value 7738
# exit_value = 7591.0 at 2012/9/13 12:04
# profit = 5000.0
# Buy to cover at 2012/10/4 10:31 with Close 7658.0
# Trade completed
#
# Sell at 2012/9/17 11:00 with target value 7746
# exit_value = 7734.0 at 2012/9/14 13:39
# profit = 950.0
# Buy to cover at 2012/9/17 11:03 with Close 7733.0
# Trade completed
#
# Sell at 2012/9/18 13:12 with target value 7748
# exit_value = 7746.0 at 2012/9/17 10:55
# profit = 150.0
# Buy to cover at 2012/9/18 13:13 with Close 7746.0
# Trade completed
#
# Sell at 2012/9/20 10:40 with target value 7770
# exit_value = 7748.0 at 2012/9/18 13:09
# profit = 1300.0
# Buy to cover at 2012/9/20 10:44 with Close 7743.0
# Trade completed
#
# Sell at 2012/9/20 9:49 with target value 7772
# exit_value = 7761.0 at 2012/9/19 13:00
# profit = 650.0
# Buy to cover at 2012/9/20 9:50 with Close 7761.0
# Trade completed
#
# Sell at 2012/9/21 11:22 with target value 7767
# exit_value = 7765.0 at 2012/9/20 9:34
# profit = 100.0
# Buy to cover at 2012/9/21 11:23 with Close 7764.0
# Trade completed
#
# Sell at 2012/9/25 10:53 with target value 7773
# exit_value = 7766.0 at 2012/9/21 11:19
# profit = 450.0
# Buy to cover at 2012/9/25 10:55 with Close 7766.0
# Trade completed
#
# Sell at 2012/10/22 8:45 with target value 7496
# exit_value = 7399.0 at 2012/10/15 12:09
# profit = 9950.0
# Buy to cover at 2012/10/22 8:46 with Close 7298.0
# Trade completed
#
# Sell at 2012/11/7 11:03 with target value 7231
# exit_value = 7188.0 at 2012/11/2 11:15
# profit = 9950.0
# Buy to cover at 2012/11/7 12:03 with Close 7235.0
# Trade completed
#
# Sell at 2012/11/12 10:03 with target value 7279
# exit_value = 7226.0 at 2012/11/7 10:33
# profit = 9950.0
# Buy to cover at 2012/11/12 12:15 with Close 7260.0
# Trade completed
#
# Sell at 2012/11/16 10:14 with target value 7132
# exit_value = 7130.0 at 2012/11/14 13:40
# profit = 100.0
# Buy to cover at 2012/11/16 10:15 with Close 7129.0
# Trade completed
#
# Sell at 2012/11/20 10:04 with target value 7152
# exit_value = 7137.0 at 2012/11/16 10:13
# profit = 750.0
# Buy to cover at 2012/11/20 10:05 with Close 7137.0
# Trade completed
#
# Sell at 2012/11/20 12:37 with target value 7146
# exit_value = 7144.0 at 2012/11/20 9:45
# profit = 100.0
# Buy to cover at 2012/11/20 12:38 with Close 7144.0
# Trade completed
#
# Sell at 2012/11/21 10:41 with target value 7154
# exit_value = 7146.0 at 2012/11/20 12:33
# profit = 750.0
# Buy to cover at 2012/11/21 10:42 with Close 7141.0
# Trade completed
#
# Sell at 2015/8/24 10:00 with target value 7369
# exit_value = 7155.0 at 2012/11/21 10:30
# profit = 8950.0
# Buy to cover at 2015/8/24 10:14 with Close 7130.0
# Trade completed
#
# Sell at 2015/8/24 9:57 with target value 7378
# exit_value = 7366.0 at 2012/11/26 9:59
# profit = 5250.0
# Buy to cover at 2015/8/24 9:58 with Close 7325.0
# Trade completed
#
# Sell at 2015/8/24 9:57 with target value 7383
# exit_value = 7375.0 at 2012/11/26 11:15
# profit = 5500.0
# Buy to cover at 2015/8/24 9:58 with Close 7325.0
# Trade completed
#
# Sell at 2012/11/27 11:34 with target value 7400
# exit_value = 7384.0 at 2012/11/27 9:01
# profit = 5500.0
# Buy to cover at 2012/11/27 12:07 with Close 7410.0
# Trade completed
#
# Sell at 2012/11/28 9:03 with target value 7400
# exit_value = 7399.0 at 2012/11/27 11:18
# profit = 250.0
# Buy to cover at 2012/11/28 9:04 with Close 7395.0
# Trade completed
#
# Sell at 2015/8/24 9:56 with target value 7404
# exit_value = 7402.0 at 2012/11/28 8:45
# profit = 3950.0
# Buy to cover at 2015/8/24 9:57 with Close 7367.0
# Trade completed
#
# Sell at 2015/8/24 9:54 with target value 7497
# exit_value = 7403.0 at 2012/11/28 11:54
# profit = 6500.0
# Buy to cover at 2015/8/24 9:56 with Close 7399.0
# Trade completed
#
# Sell at 2012/12/21 9:48 with target value 7516
# exit_value = 7500.0 at 2012/11/29 10:30
# profit = 1300.0
# Buy to cover at 2012/12/21 9:49 with Close 7485.0
# Trade completed
#
# Sell at 2012/12/21 9:18 with target value 7591
# exit_value = 7518.0 at 2012/11/29 12:48
# profit = 4000.0
# Buy to cover at 2012/12/21 9:26 with Close 7515.0
# Trade completed
#
# Sell at 2012/12/3 12:18 with target value 7627
# exit_value = 7588.0 at 2012/11/30 12:18
# profit = 2300.0
# Buy to cover at 2012/12/3 12:19 with Close 7587.0
# Trade completed
#
# Sell at 2012/12/6 9:29 with target value 7661
# exit_value = 7625.0 at 2012/12/3 10:50
# profit = 2300.0
# Buy to cover at 2012/12/6 10:21 with Close 7663.0
# Trade completed
#
# Sell at 2012/12/7 11:48 with target value 7667
# exit_value = 7658.0 at 2012/12/5 12:40
# profit = 500.0
# Buy to cover at 2012/12/7 12:05 with Close 7656.0
# Trade completed
#
# Sell at 2012/12/17 9:16 with target value 7695
# exit_value = 7663.0 at 2012/12/7 11:27
# profit = 2050.0
# Buy to cover at 2012/12/17 9:17 with Close 7661.0
# Trade completed
#
# Sell at 2012/12/14 9:43 with target value 7760
# exit_value = 7690.0 at 2012/12/12 10:39
# profit = 2050.0
# Buy to cover at 2012/12/14 13:07 with Close 7723.0
# Trade completed
#
# Sell at 2015/8/24 9:11 with target value 7653
# exit_value = 7536.0 at 2012/12/22 12:33
# profit = 6100.0
# Buy to cover at 2015/8/24 9:36 with Close 7531.0
# Trade completed
#
# Sell at 2013/1/17 11:40 with target value 7674
# exit_value = 7657.0 at 2012/12/26 10:38
# profit = 1600.0
# Buy to cover at 2013/1/17 11:41 with Close 7653.0
# Trade completed
#
# Sell at 2012/12/28 13:44 with target value 7688
# exit_value = 7675.0 at 2012/12/28 10:30
# profit = -1450.0
# Buy to cover at 2012/12/28 13:45 with Close 7675.0
# Trade completed
#
# Sell at 2013/1/7 9:48 with target value 7784
# exit_value = 7681.0 at 2012/12/28 13:33
# profit = -1450.0
# Buy to cover at 2013/1/7 10:40 with Close 7754.0
# Trade completed
#
# Sell at 2013/1/4 9:00 with target value 7814
# exit_value = 7778.0 at 2013/1/2 12:45
# profit = 1900.0
# Buy to cover at 2013/1/4 9:05 with Close 7772.0
# Trade completed
#
# Sell at 2013/1/14 8:45 with target value 7826
# exit_value = 7745.0 at 2013/1/9 11:14
# profit = 4450.0
# Buy to cover at 2013/1/14 8:48 with Close 7739.0
# Trade completed
#
# Sell at 2013/1/22 9:32 with target value 7705
# exit_value = 7696.0 at 2013/1/21 11:05
# profit = 1250.0
# Buy to cover at 2013/1/22 9:33 with Close 7685.0
# Trade completed
#
# Sell at 2013/1/24 8:45 with target value 7752
# exit_value = 7702.0 at 2013/1/21 12:18
# profit = 3700.0
# Buy to cover at 2013/1/24 8:46 with Close 7679.0
# Trade completed
#
# Sell at 2013/4/8 10:12 with target value 7766
# exit_value = 7745.0 at 2013/1/23 9:31
# profit = 1350.0
# Buy to cover at 2013/4/8 10:14 with Close 7743.0
# Trade completed
#
# Sell at 2013/1/31 9:45 with target value 7832
# exit_value = 7762.0 at 2013/1/29 11:08
# profit = 1350.0
# Buy to cover at 2013/1/31 11:15 with Close 7816.0
# Trade completed
#
# Sell at 2013/3/4 12:40 with target value 7858
# exit_value = 7828.0 at 2013/1/30 11:39
# profit = 1400.0
# Buy to cover at 2013/3/4 13:01 with Close 7828.0
# Trade completed
#
# Sell at 2013/2/5 9:01 with target value 7920
# exit_value = 7856.0 at 2013/2/1 13:31
# profit = 1400.0
# Buy to cover at 2013/2/5 11:15 with Close 7893.0
# Trade completed
#
# Sell at 2013/2/5 8:45 with target value 7938
# exit_value = 7920.0 at 2013/2/4 10:50
# profit = 2200.0
# Buy to cover at 2013/2/5 8:46 with Close 7895.0
# Trade completed
#
# Sell at 2013/2/18 10:03 with target value 7938
# exit_value = 7935.0 at 2013/2/6 12:57
# profit = 100.0
# Buy to cover at 2013/2/18 10:16 with Close 7935.0
# Trade completed
#
# Sell at 2013/2/22 9:11 with target value 7955
# exit_value = 7939.0 at 2013/2/18 9:50
# profit = 1450.0
# Buy to cover at 2013/2/22 9:12 with Close 7925.0
# Trade completed
#
# Sell at 2013/2/21 11:01 with target value 8002
# exit_value = 7953.0 at 2013/2/19 10:37
# profit = 1450.0
# Buy to cover at 2013/2/21 12:33 with Close 7973.0
# Trade completed
#
# Sell at 2013/3/1 13:17 with target value 7935
# exit_value = 7933.0 at 2013/3/1 11:17
# profit = 100.0
# Buy to cover at 2013/3/1 13:18 with Close 7933.0
# Trade completed
#
# Sell at 2013/3/7 8:45 with target value 7956
# exit_value = 7934.0 at 2013/3/1 13:12
# profit = 1650.0
# Buy to cover at 2013/3/7 8:46 with Close 7924.0
# Trade completed
#
# Sell at 2013/3/13 10:44 with target value 8012
# exit_value = 7953.0 at 2013/3/6 12:25
# profit = 2850.0
# Buy to cover at 2013/3/13 11:19 with Close 7952.0
# Trade completed
#
# Sell at 2013/3/8 12:51 with target value 8018
# exit_value = 8010.0 at 2013/3/8 10:38
# profit = 350.0
# Buy to cover at 2013/3/8 13:21 with Close 8010.0
# Trade completed
#
# Sell at 2013/3/12 11:40 with target value 8048
# exit_value = 8015.0 at 2013/3/8 12:26
# profit = 1650.0
# Buy to cover at 2013/3/12 12:02 with Close 8012.0
# Trade completed
#
# Sell at 2013/3/28 9:35 with target value 7857
# exit_value = 7838.0 at 2013/3/25 10:24
# profit = 950.0
# Buy to cover at 2013/3/28 9:49 with Close 7838.0
# Trade completed
#
# Sell at 2013/3/28 9:31 with target value 7853
# exit_value = 7852.0 at 2013/3/27 10:53
# profit = 500.0
# Buy to cover at 2013/3/28 9:32 with Close 7845.0
# Trade completed
#
# Sell at 2013/4/8 8:45 with target value 7881
# exit_value = 7853.0 at 2013/3/27 12:48
# profit = 2550.0
# Buy to cover at 2013/4/8 9:02 with Close 7833.0
# Trade completed
#
# Sell at 2013/4/2 9:02 with target value 7920
# exit_value = 7879.0 at 2013/3/29 11:30
# profit = 1950.0
# Buy to cover at 2013/4/2 9:15 with Close 7878.0
# Trade completed
#
# Sell at 2013/4/12 10:33 with target value 7813
# exit_value = 7806.0 at 2013/4/11 12:48
# profit = 450.0
# Buy to cover at 2013/4/12 10:36 with Close 7805.0
# Trade completed
#
# Sell at 2013/6/20 8:45 with target value 7908
# exit_value = 7780.0 at 2013/4/17 11:52
# profit = 7100.0
# Buy to cover at 2013/6/20 9:45 with Close 7764.0
# Trade completed
#
# Sell at 2013/4/23 9:45 with target value 7959
# exit_value = 7907.0 at 2013/4/19 12:03
# profit = 2550.0
# Buy to cover at 2013/4/23 10:11 with Close 7907.0
# Trade completed
#
# Sell at 2013/6/13 9:54 with target value 7995
# exit_value = 7957.0 at 2013/4/22 11:11
# profit = 1800.0
# Buy to cover at 2013/6/13 9:57 with Close 7957.0
# Trade completed
#
# Sell at 2013/4/26 13:31 with target value 8042
# exit_value = 7996.0 at 2013/4/24 12:29
# profit = 1800.0
# Buy to cover at 2013/4/29 8:50 with Close 8031.0
# Trade completed
#
# Sell at 2013/6/7 12:03 with target value 8095
# exit_value = 8038.0 at 2013/4/26 10:22
# profit = 1800.0
# Buy to cover at 2013/6/7 12:40 with Close 8071.0
# Trade completed
#
# Sell at 2013/6/6 8:45 with target value 8116
# exit_value = 8096.0 at 2013/4/30 11:27
# profit = 800.0
# Buy to cover at 2013/6/6 8:53 with Close 8095.0
# Trade completed
#
# Sell at 2013/5/3 12:29 with target value 8154
# exit_value = 8112.0 at 2013/5/2 12:48
# profit = 800.0
# Buy to cover at 2013/5/3 13:42 with Close 8135.0
# Trade completed
#
# Sell at 2013/5/6 10:01 with target value 8158
# exit_value = 8157.0 at 2013/5/3 11:23
# profit = -50.0
# Buy to cover at 2013/5/6 10:05 with Close 8157.0
# Trade completed
#
# Sell at 2013/5/24 12:44 with target value 8165
# exit_value = 8161.0 at 2013/5/6 10:00
# profit = 150.0
# Buy to cover at 2013/5/24 12:45 with Close 8157.0
# Trade completed
#
# Sell at 2013/5/24 12:37 with target value 8175
# exit_value = 8163.0 at 2013/5/7 10:55
# profit = 900.0
# Buy to cover at 2013/5/24 12:44 with Close 8151.0
# Trade completed
#
# Sell at 2013/5/24 12:20 with target value 8263
# exit_value = 8171.0 at 2013/5/7 13:14
# profit = 4600.0
# Buy to cover at 2013/5/24 12:37 with Close 8165.0
# Trade completed
#
# Sell at 2013/5/13 9:06 with target value 8309
# exit_value = 8262.0 at 2013/5/8 11:01
# profit = 2250.0
# Buy to cover at 2013/5/13 9:08 with Close 8262.0
# Trade completed
#
# Sell at 2013/5/9 13:10 with target value 8309
# exit_value = 8307.0 at 2013/5/9 11:31
# profit = 50.0
# Buy to cover at 2013/5/9 13:11 with Close 8307.0
# Trade completed
#
# Sell at 2013/5/23 8:45 with target value 8420
# exit_value = 8282.0 at 2013/5/15 12:49
# profit = 50.0
# Buy to cover at 2013/5/23 9:44 with Close 8355.0
# Trade completed
#
# Sell at 2013/5/22 11:54 with target value 8405
# exit_value = 8403.0 at 2013/5/22 10:00
# profit = 50.0
# Buy to cover at 2013/5/22 11:55 with Close 8402.0
# Trade completed
#
# Sell at 2013/5/30 11:10 with target value 8265
# exit_value = 8253.0 at 2013/5/28 8:52
# profit = 700.0
# Buy to cover at 2013/5/30 11:13 with Close 8252.0
# Trade completed
#
# Sell at 2013/5/30 8:45 with target value 8329
# exit_value = 8265.0 at 2013/5/28 11:10
# profit = 700.0
# Buy to cover at 2013/5/30 9:50 with Close 8296.0
# Trade completed
#
# Sell at 2013/6/19 10:29 with target value 8011
# exit_value = 7993.0 at 2013/6/18 12:26
# profit = 950.0
# Buy to cover at 2013/6/19 10:39 with Close 7989.0
# Trade completed
#
# Sell at 2015/8/24 8:45 with target value 7720
# exit_value = 7648.0 at 2013/6/25 11:05
# profit = 3950.0
# Buy to cover at 2015/8/24 8:46 with Close 7628.0
# Trade completed
#
# Sell at 2013/8/22 8:45 with target value 7790
# exit_value = 7718.0 at 2013/6/27 11:10
# profit = 3850.0
# Buy to cover at 2013/8/22 8:46 with Close 7712.0
# Trade completed
#
# Sell at 2013/7/3 10:55 with target value 7879
# exit_value = 7788.0 at 2013/6/28 12:32
# profit = 3850.0
# Buy to cover at 2013/7/3 13:36 with Close 7817.0
# Trade completed
#
# Sell at 2013/7/3 8:56 with target value 7898
# exit_value = 7876.0 at 2013/7/1 11:22
# profit = 1050.0
# Buy to cover at 2013/7/3 9:00 with Close 7876.0
# Trade completed
#
# Sell at 2013/7/8 9:30 with target value 7960
# exit_value = 7897.0 at 2013/7/1 13:39
# profit = 3750.0
# Buy to cover at 2013/7/8 9:34 with Close 7880.0
# Trade completed
#
# Sell at 2013/7/10 12:20 with target value 7974
# exit_value = 7956.0 at 2013/7/5 12:15
# profit = 950.0
# Buy to cover at 2013/7/10 12:25 with Close 7956.0
# Trade completed
#
# Sell at 2013/7/19 9:10 with target value 8134
# exit_value = 7977.0 at 2013/7/10 10:29
# profit = 950.0
# Buy to cover at 2013/7/19 10:25 with Close 8010.0
# Trade completed
#
# Sell at 2013/7/18 9:24 with target value 8144
# exit_value = 8134.0 at 2013/7/11 12:25
# profit = 1550.0
# Buy to cover at 2013/7/18 9:25 with Close 8113.0
# Trade completed
#
# Sell at 2013/7/15 8:45 with target value 8154
# exit_value = 8138.0 at 2013/7/12 9:02
# profit = 1550.0
# Buy to cover at 2013/7/15 9:33 with Close 8187.0
# Trade completed
#
# Sell at 2013/7/18 8:45 with target value 8207
# exit_value = 8153.0 at 2013/7/12 11:11
# profit = 2750.0
# Buy to cover at 2013/7/18 8:46 with Close 8153.0
# Trade completed
#
# Sell at 2013/7/17 9:49 with target value 8216
# exit_value = 8209.0 at 2013/7/15 11:48
# profit = 150.0
# Buy to cover at 2013/7/17 9:50 with Close 8209.0
# Trade completed
#
# Sell at 2013/7/18 8:45 with target value 8225
# exit_value = 8214.0 at 2013/7/16 12:17
# profit = 3650.0
# Buy to cover at 2013/7/18 8:46 with Close 8153.0
# Trade completed
#
# Sell at 2013/7/29 9:01 with target value 8138
# exit_value = 8021.0 at 2013/7/22 13:40
# profit = 3650.0
# Buy to cover at 2013/7/29 9:30 with Close 8096.0
# Trade completed
#
# Sell at 2013/8/19 8:45 with target value 7928
# exit_value = 7855.0 at 2013/8/15 13:00
# profit = 3650.0
# Buy to cover at 2013/8/19 10:17 with Close 7886.0
# Trade completed
#
# Sell at 2013/8/23 13:21 with target value 7808
# exit_value = 7798.0 at 2013/8/23 11:46
# profit = 500.0
# Buy to cover at 2013/8/23 13:24 with Close 7796.0
# Trade completed
#
# Sell at 2013/8/27 8:45 with target value 7828
# exit_value = 7805.0 at 2013/8/23 13:15
# profit = 1350.0
# Buy to cover at 2013/8/27 8:46 with Close 7801.0
# Trade completed
#
# Sell at 2015/8/21 8:45 with target value 7881
# exit_value = 7827.0 at 2013/8/26 12:28
# profit = 2500.0
# Buy to cover at 2015/8/21 9:30 with Close 7825.0
# Trade completed
#
# Sell at 2015/8/21 8:45 with target value 7884
# exit_value = 7878.0 at 2013/8/29 13:22
# profit = 1800.0
# Buy to cover at 2015/8/21 8:46 with Close 7858.0
# Trade completed
#
# Sell at 2015/8/20 10:22 with target value 7980
# exit_value = 7883.0 at 2013/8/30 9:43
# profit = 1800.0
# Buy to cover at 2015/8/20 11:08 with Close 7971.0
# Trade completed
#
# Sell at 2015/8/20 8:45 with target value 8012
# exit_value = 7983.0 at 2013/9/2 10:32
# profit = 3750.0
# Buy to cover at 2015/8/20 8:46 with Close 7935.0
# Trade completed
#
# Sell at 2013/9/4 8:46 with target value 8044
# exit_value = 8012.0 at 2013/9/2 13:17
# profit = 1700.0
# Buy to cover at 2013/9/4 9:15 with Close 8009.0
# Trade completed
#
# Sell at 2013/9/4 8:45 with target value 8049
# exit_value = 8041.0 at 2013/9/3 11:21
# profit = 1550.0
# Buy to cover at 2013/9/4 8:46 with Close 8017.0
# Trade completed
#
# Sell at 2013/11/21 13:01 with target value 8112
# exit_value = 8047.0 at 2013/9/3 12:50
# profit = 1550.0
# Buy to cover at 2013/11/21 13:15 with Close 8080.0
# Trade completed
#
# Sell at 2013/9/9 9:09 with target value 8124
# exit_value = 8114.0 at 2013/9/5 12:02
# profit = 200.0
# Buy to cover at 2013/9/9 9:10 with Close 8113.0
# Trade completed
#
# Sell at 2013/9/9 9:08 with target value 8144
# exit_value = 8121.0 at 2013/9/6 8:45
# profit = 1550.0
# Buy to cover at 2013/9/9 9:09 with Close 8111.0
# Trade completed
#
# Sell at 2013/9/10 11:23 with target value 8151
# exit_value = 8141.0 at 2013/9/6 12:05
# profit = 450.0
# Buy to cover at 2013/9/10 11:25 with Close 8140.0
# Trade completed
#
# Sell at 2013/9/10 11:07 with target value 8179
# exit_value = 8152.0 at 2013/9/9 12:09
# profit = 1300.0
# Buy to cover at 2013/9/10 11:21 with Close 8152.0
# Trade completed
#
# Sell at 2013/9/13 10:14 with target value 8202
# exit_value = 8174.0 at 2013/9/10 10:54
# profit = 1700.0
# Buy to cover at 2013/9/13 10:15 with Close 8173.0
# Trade completed
#
# Sell at 2013/9/23 8:45 with target value 8243
# exit_value = 8197.0 at 2013/9/12 11:32
# profit = 1700.0
# Buy to cover at 2013/9/23 9:45 with Close 8240.0
# Trade completed
#
# Sell at 2013/9/17 8:45 with target value 8247
# exit_value = 8240.0 at 2013/9/16 11:45
# profit = 1650.0
# Buy to cover at 2013/9/17 8:46 with Close 8213.0
# Trade completed
#
# Sell at 2013/9/24 11:01 with target value 8258
# exit_value = 8242.0 at 2013/9/18 11:38
# profit = 1500.0
# Buy to cover at 2013/9/24 11:04 with Close 8230.0
# Trade completed
#
# Sell at 2013/10/2 10:11 with target value 8172
# exit_value = 8161.0 at 2013/10/1 10:45
# profit = 550.0
# Buy to cover at 2013/10/2 10:12 with Close 8161.0
# Trade completed
#
# Sell at 2013/11/8 8:45 with target value 8363
# exit_value = 8167.0 at 2013/10/2 9:46
# profit = 550.0
# Buy to cover at 2013/11/8 9:45 with Close 8249.0
# Trade completed
#
# Sell at 2013/10/4 13:19 with target value 8377
# exit_value = 8353.0 at 2013/10/3 13:33
# profit = 3000.0
# Buy to cover at 2013/10/7 8:48 with Close 8351.0
# Trade completed
#
# Sell at 2013/10/9 13:13 with target value 8347
# exit_value = 8342.0 at 2013/10/9 10:33
# profit = 650.0
# Buy to cover at 2013/10/9 13:14 with Close 8341.0
# Trade completed
#
# Sell at 2013/10/11 13:32 with target value 8384
# exit_value = 8348.0 at 2013/10/9 12:36
# profit = 2200.0
# Buy to cover at 2013/10/14 8:45 with Close 8341.0
# Trade completed
#
# Sell at 2013/10/16 10:39 with target value 8354
# exit_value = 8343.0 at 2013/10/15 11:04
# profit = 2200.0
# Buy to cover at 2013/10/16 11:27 with Close 8354.0
# Trade completed
#
# Sell at 2013/10/17 10:36 with target value 8373
# exit_value = 8355.0 at 2013/10/15 13:43
# profit = 2200.0
# Buy to cover at 2013/10/17 12:45 with Close 8370.0
# Trade completed
#
# Sell at 2013/10/22 8:48 with target value 8394
# exit_value = 8366.0 at 2013/10/17 9:55
# profit = 1200.0
# Buy to cover at 2013/10/22 9:00 with Close 8361.0
# Trade completed
#
# Sell at 2013/10/21 9:48 with target value 8434
# exit_value = 8391.0 at 2013/10/18 12:00
# profit = 1200.0
# Buy to cover at 2013/10/21 11:10 with Close 8413.0
# Trade completed
#
# Sell at 2013/11/1 10:13 with target value 8422
# exit_value = 8392.0 at 2013/10/28 12:07
# profit = 1900.0
# Buy to cover at 2013/11/1 10:43 with Close 8389.0
# Trade completed
#
# Sell at 2013/10/31 8:45 with target value 8428
# exit_value = 8423.0 at 2013/10/30 10:49
# profit = 600.0
# Buy to cover at 2013/10/31 8:46 with Close 8419.0
# Trade completed
#
# Sell at 2013/10/31 12:58 with target value 8445
# exit_value = 8427.0 at 2013/10/30 12:28
# profit = -850.0
# Buy to cover at 2013/10/31 13:44 with Close 8427.0
# Trade completed
#
# Sell at 2013/11/18 10:59 with target value 8195
# exit_value = 8196.0 at 2013/11/15 11:26
# profit = 150.0
# Buy to cover at 2013/11/18 11:00 with Close 8190.0
# Trade completed
#
# Sell at 2013/11/21 8:45 with target value 8232
# exit_value = 8198.0 at 2013/11/18 10:58
# profit = 3400.0
# Buy to cover at 2013/11/21 8:46 with Close 8164.0
# Trade completed
#
# Sell at 2013/11/20 8:45 with target value 8243
# exit_value = 8231.0 at 2013/11/19 11:02
# profit = 500.0
# Buy to cover at 2013/11/20 9:04 with Close 8231.0
# Trade completed
#
# Sell at 2014/2/5 9:44 with target value 8293
# exit_value = 8243.0 at 2013/11/26 12:44
# profit = 2700.0
# Buy to cover at 2014/2/5 10:39 with Close 8243.0
# ...
# exit_value = 13975.0 at 2022/11/11 12:08
# profit = 7200.0
# Buy to cover at 2022/12/29 8:48 with Close 13973.0
# Trade completed
#
# Sell at 2022/11/14 13:43 with target value 14163
# exit_value = 14096.0 at 2022/11/14 9:44
# profit = 7200.0
# Buy to cover at 2022/11/15 8:45 with Close 14257.0
# Trade completed
#
# Sell at 2022/12/20 11:14 with target value 14516
# exit_value = 14161.0 at 2022/11/14 12:06
# profit = 18300.0
# Buy to cover at 2022/12/20 12:06 with Close 14156.0
# Trade completed
#
# Sell at 2022/11/16 11:15 with target value 14554
# exit_value = 14526.0 at 2022/11/15 13:35
# profit = 1150.0
# Buy to cover at 2022/11/16 11:21 with Close 14523.0
# Trade completed
#
# Sell at 2022/11/28 8:46 with target value 14567
# exit_value = 14491.0 at 2022/11/22 12:27
# profit = 4350.0
# Buy to cover at 2022/11/28 8:52 with Close 14484.0
# Trade completed
#
# Sell at 2022/11/28 8:45 with target value 14601
# exit_value = 14556.0 at 2022/11/23 9:49
# profit = 4400.0
# Buy to cover at 2022/11/28 8:46 with Close 14509.0
# Trade completed
#
# Sell at 2022/11/28 8:45 with target value 14673
# exit_value = 14601.0 at 2022/11/23 13:11
# profit = 8000.0
# Buy to cover at 2022/11/28 8:46 with Close 14509.0
# Trade completed
#
# Sell at 2022/11/28 8:45 with target value 14765
# exit_value = 14661.0 at 2022/11/24 11:16
# profit = 12600.0
# Buy to cover at 2022/11/28 8:46 with Close 14509.0
# Trade completed
#
# Sell at 2022/12/6 9:26 with target value 15038
# exit_value = 14747.0 at 2022/11/25 8:45
# profit = 12600.0
# Buy to cover at 2022/12/6 10:33 with Close 14842.0
# Trade completed
#
# Sell at 2022/12/15 8:45 with target value 14703
# exit_value = 14690.0 at 2022/12/14 12:18
# profit = 4200.0
# Buy to cover at 2022/12/15 8:46 with Close 14622.0
# Trade completed
#
# Sell at 2022/12/28 8:45 with target value 14240
# exit_value = 14199.0 at 2022/12/26 10:47
# profit = 3250.0
# Buy to cover at 2022/12/28 8:46 with Close 14174.0
# Trade completed
#
# Sell at 2022/12/28 8:45 with target value 14351
# exit_value = 14236.0 at 2022/12/26 13:39
# profit = 8800.0
# Buy to cover at 2022/12/28 8:46 with Close 14174.0
# Trade completed
#
# Sell at 2023/1/3 8:45 with target value 14163
# exit_value = 14031.0 at 2022/12/29 13:43
# profit = 6550.0
# Buy to cover at 2023/1/3 8:57 with Close 14029.0
# Trade completed
#
# Sell at 2022/12/30 13:25 with target value 14168
# exit_value = 14151.0 at 2022/12/30 9:53
# profit = 1650.0
# Buy to cover at 2022/12/30 13:26 with Close 14138.0
# Trade completed
#
# Sell at 2023/1/4 11:41 with target value 14215
# exit_value = 14191.0 at 2023/1/4 8:45
# profit = 1000.0
# Buy to cover at 2023/1/4 11:47 with Close 14188.0
# Trade completed
#
# Sell at 2023/1/11 10:49 with target value 14804
# exit_value = 14753.0 at 2023/1/10 10:34
# profit = 2750.0
# Buy to cover at 2023/1/11 11:09 with Close 14753.0
# Trade completed
#
# Sell at 2023/1/12 9:47 with target value 14796
# exit_value = 14786.0 at 2023/1/11 9:27
# profit = 500.0
# Buy to cover at 2023/1/12 9:49 with Close 14785.0
# Trade completed
#
# Sell at 2023/1/31 10:03 with target value 15414
# exit_value = 15384.0 at 2023/1/30 10:30
# profit = 1350.0
# Buy to cover at 2023/1/31 10:43 with Close 15384.0
# Trade completed
#
# Sell at 2023/2/7 8:45 with target value 15474
# exit_value = 15337.0 at 2023/2/1 12:08
# profit = 1350.0
# Buy to cover at 2023/2/7 9:13 with Close 15433.0
# Trade completed
#
# Sell at 2023/2/3 9:11 with target value 15582
# exit_value = 15478.0 at 2023/2/2 9:44
# profit = 1350.0
# Buy to cover at 2023/2/3 10:34 with Close 15561.0
# Trade completed
#
# Sell at 2023/2/9 8:45 with target value 15606
# exit_value = 15578.0 at 2023/2/2 13:38
# profit = 3550.0
# Buy to cover at 2023/2/9 8:46 with Close 15544.0
# Trade completed
#
# Sell at 2023/2/15 8:45 with target value 15651
# exit_value = 15578.0 at 2023/2/10 8:46
# profit = 6350.0
# Buy to cover at 2023/2/15 8:46 with Close 15520.0
# Trade completed
#
# Sell at 2023/2/24 11:01 with target value 15627
# exit_value = 15568.0 at 2023/2/16 12:34
# profit = 6350.0
# Buy to cover at 2023/2/24 11:15 with Close 15611.0
# Trade completed
#
# Sell at 2023/3/10 9:12 with target value 15577
# exit_value = 15547.0 at 2023/3/2 13:22
# profit = 1750.0
# Buy to cover at 2023/3/10 9:13 with Close 15546.0
# Trade completed
#
# Sell at 2023/3/10 8:50 with target value 15609
# exit_value = 15578.0 at 2023/3/3 9:46
# profit = 1050.0
# Buy to cover at 2023/3/10 8:51 with Close 15578.0
# Trade completed
#
# Sell at 2023/3/10 8:45 with target value 15804
# exit_value = 15612.0 at 2023/3/3 12:19
# profit = 9800.0
# Buy to cover at 2023/3/10 8:47 with Close 15612.0
# Trade completed
#
# Sell at 2023/3/8 8:45 with target value 15875
# exit_value = 15797.0 at 2023/3/6 12:16
# profit = 6050.0
# Buy to cover at 2023/3/8 8:46 with Close 15742.0
# Trade completed
#
# Sell at 2023/3/20 9:40 with target value 15393
# exit_value = 15384.0 at 2023/3/17 13:11
# profit = 850.0
# Buy to cover at 2023/3/20 9:51 with Close 15382.0
# Trade completed
#
# Sell at 2023/4/25 11:56 with target value 15471
# exit_value = 15387.0 at 2023/3/20 9:37
# profit = 4350.0
# Buy to cover at 2023/4/25 12:33 with Close 15386.0
# Trade completed
#
# Sell at 2023/4/25 10:15 with target value 15678
# exit_value = 15467.0 at 2023/3/21 11:00
# profit = 10700.0
# Buy to cover at 2023/4/25 10:38 with Close 15461.0
# Trade completed
#
# Sell at 2023/3/28 10:07 with target value 15703
# exit_value = 15673.0 at 2023/3/22 10:49
# profit = 1650.0
# Buy to cover at 2023/3/28 10:09 with Close 15669.0
# Trade completed
#
# Sell at 2023/3/28 9:41 with target value 15814
# exit_value = 15683.0 at 2023/3/23 8:45
# profit = 6350.0
# Buy to cover at 2023/3/28 10:01 with Close 15682.0
# Trade completed
#
# Sell at 2023/3/27 9:21 with target value 15831
# exit_value = 15812.0 at 2023/3/23 11:43
# profit = 1250.0
# Buy to cover at 2023/3/27 9:24 with Close 15807.0
# Trade completed
#
# Sell at 2023/3/27 9:07 with target value 15874
# exit_value = 15828.0 at 2023/3/24 10:35
# profit = 2400.0
# Buy to cover at 2023/3/27 9:15 with Close 15825.0
# Trade completed
#
# Sell at 2023/4/6 8:45 with target value 15905
# exit_value = 15793.0 at 2023/3/30 10:45
# profit = 7200.0
# Buy to cover at 2023/4/6 8:46 with Close 15759.0
# Trade completed
#
# Sell at 2023/4/6 8:45 with target value 15907
# exit_value = 15815.0 at 2023/3/30 13:44
# profit = 7300.0
# Buy to cover at 2023/4/6 8:46 with Close 15759.0
# Trade completed
#
# Sell at 2023/4/12 9:37 with target value 15931
# exit_value = 15862.0 at 2023/4/10 12:01
# profit = 7300.0
# Buy to cover at 2023/4/12 10:33 with Close 15903.0
# Trade completed
#
# Sell at 2023/4/14 13:39 with target value 15965
# exit_value = 15930.0 at 2023/4/11 11:47
# profit = 2450.0
# Buy to cover at 2023/4/17 8:45 with Close 15924.0
# Trade completed
#
# Sell at 2023/4/27 13:15 with target value 15402
# exit_value = 15396.0 at 2023/4/27 11:47
# profit = 700.0
# Buy to cover at 2023/4/27 13:16 with Close 15392.0
# Trade completed
#
# Sell at 2023/5/12 8:46 with target value 15507
# exit_value = 15405.0 at 2023/4/27 13:07
# profit = 700.0
# Buy to cover at 2023/5/12 9:44 with Close 15470.0
# Trade completed
#
# Sell at 2023/5/3 11:21 with target value 15600
# exit_value = 15500.0 at 2023/4/28 11:05
# profit = 700.0
# Buy to cover at 2023/5/3 12:07 with Close 15559.0
# Trade completed
#
# Sell at 2023/5/3 8:45 with target value 15635
# exit_value = 15600.0 at 2023/5/2 10:31
# profit = 4250.0
# Buy to cover at 2023/5/3 8:46 with Close 15549.0
# Trade completed
#
# Sell at 2023/5/5 10:09 with target value 15623
# exit_value = 15595.0 at 2023/5/5 8:45
# profit = 1300.0
# Buy to cover at 2023/5/5 10:10 with Close 15595.0
# Trade completed
#
# Sell at 2023/5/10 9:43 with target value 15724
# exit_value = 15617.0 at 2023/5/5 9:47
# profit = 5650.0
# Buy to cover at 2023/5/10 9:55 with Close 15614.0
# Trade completed
#
# Sell at 2023/5/8 13:19 with target value 15726
# exit_value = 15708.0 at 2023/5/8 10:22
# profit = 1400.0
# Buy to cover at 2023/5/10 8:45 with Close 15699.0
# Trade completed
#
# Sell at 2023/5/24 8:45 with target value 16108
# exit_value = 16046.0 at 2023/5/18 11:51
# profit = 3600.0
# Buy to cover at 2023/5/24 9:11 with Close 16037.0
# Trade completed
#
# Sell at 2023/5/23 11:46 with target value 16135
# exit_value = 16106.0 at 2023/5/22 10:03
# profit = 1600.0
# Buy to cover at 2023/5/23 12:08 with Close 16106.0
# Trade completed
#
# Sell at 2023/8/17 9:27 with target value 16417
# exit_value = 16132.0 at 2023/5/23 11:30
# profit = 1600.0
# Buy to cover at 2023/8/17 9:49 with Close 16324.0
# Trade completed
#
# Sell at 2023/5/31 10:18 with target value 16580
# exit_value = 16417.0 at 2023/5/26 10:54
# profit = 1600.0
# Buy to cover at 2023/5/31 12:17 with Close 16523.0
# Trade completed
#
# Sell at 2023/5/30 11:09 with target value 16576
# exit_value = 16561.0 at 2023/5/29 9:44
# profit = 1200.0
# Buy to cover at 2023/5/30 11:10 with Close 16556.0
# Trade completed
#
# Sell at 2023/7/7 8:45 with target value 16720
# exit_value = 16570.0 at 2023/5/30 11:05
# profit = 8450.0
# Buy to cover at 2023/7/7 9:43 with Close 16560.0
# Trade completed
#
# Sell at 2023/6/5 12:17 with target value 16731
# exit_value = 16709.0 at 2023/6/2 12:33
# profit = 1200.0
# Buy to cover at 2023/6/5 12:24 with Close 16708.0
# Trade completed
#
# Sell at 2023/6/8 11:16 with target value 16842
# exit_value = 16734.0 at 2023/6/5 12:06
# profit = 5500.0
# Buy to cover at 2023/6/8 11:41 with Close 16732.0
# Trade completed
#
# Sell at 2023/6/9 12:02 with target value 16852
# exit_value = 16848.0 at 2023/6/8 8:45
# profit = 250.0
# Buy to cover at 2023/6/9 12:05 with Close 16848.0
# Trade completed
#
# Sell at 2023/6/26 8:45 with target value 16956
# exit_value = 16856.0 at 2023/6/9 11:33
# profit = 5950.0
# Buy to cover at 2023/6/26 9:05 with Close 16851.0
# Trade completed
#
# Sell at 2023/6/26 8:45 with target value 17227
# exit_value = 16951.0 at 2023/6/12 12:10
# profit = 16450.0
# Buy to cover at 2023/6/26 8:46 with Close 16892.0
# Trade completed
#
# Sell at 2023/6/16 9:31 with target value 17305
# exit_value = 17225.0 at 2023/6/13 12:26
# profit = 3800.0
# Buy to cover at 2023/6/16 9:33 with Close 17217.0
# Trade completed
#
# Sell at 2023/7/4 9:33 with target value 17013
# exit_value = 16978.0 at 2023/7/3 10:24
# profit = 3800.0
# Buy to cover at 2023/7/4 10:15 with Close 17048.0
# Trade completed
#
# Sell at 2023/7/4 9:22 with target value 17004
# exit_value = 17010.0 at 2023/7/3 13:02
# profit = -250.0
# Buy to cover at 2023/7/4 9:23 with Close 17007.0
# Trade completed
#
# Sell at 2023/7/5 10:07 with target value 17082
# exit_value = 17012.0 at 2023/7/4 9:21
# profit = 3400.0
# Buy to cover at 2023/7/5 10:13 with Close 17011.0
# Trade completed
#
# Sell at 2023/7/21 8:47 with target value 16862
# exit_value = 16849.0 at 2023/7/11 12:04
# profit = 450.0
# Buy to cover at 2023/7/21 8:48 with Close 16846.0
# Trade completed
#
# Sell at 2023/7/21 8:45 with target value 17221
# exit_value = 16861.0 at 2023/7/12 11:26
# profit = 18850.0
# Buy to cover at 2023/7/21 8:46 with Close 16856.0
# Trade completed
#
# Sell at 2023/7/13 12:39 with target value 17231
# exit_value = 17215.0 at 2023/7/13 11:03
# profit = 1300.0
# Buy to cover at 2023/7/13 12:40 with Close 17211.0
# Trade completed
#
# Sell at 2023/7/17 8:46 with target value 17260
# exit_value = 17231.0 at 2023/7/13 12:32
# profit = 1300.0
# Buy to cover at 2023/7/17 9:20 with Close 17294.0
# Trade completed
#
# Sell at 2023/7/17 8:45 with target value 17279
# exit_value = 17257.0 at 2023/7/14 12:07
# profit = 1900.0
# Buy to cover at 2023/7/17 8:46 with Close 17239.0
# Trade completed
#
# Sell at 2023/7/17 11:44 with target value 17303
# exit_value = 17268.0 at 2023/7/14 13:19
# profit = 2150.0
# Buy to cover at 2023/7/17 11:52 with Close 17268.0
# Trade completed
#
# Sell at 2023/7/24 12:16 with target value 16971
# exit_value = 16938.0 at 2023/7/21 13:30
# profit = 1900.0
# Buy to cover at 2023/7/24 12:21 with Close 16935.0
# Trade completed
#
# Sell at 2023/8/2 10:13 with target value 17139
# exit_value = 16970.0 at 2023/7/24 11:29
# profit = 9050.0
# Buy to cover at 2023/8/2 10:24 with Close 16970.0
# Trade completed
#
# Sell at 2023/7/26 9:24 with target value 17182
# exit_value = 17125.0 at 2023/7/25 10:26
# profit = 2350.0
# Buy to cover at 2023/7/26 9:25 with Close 17120.0
# Trade completed
#
# Sell at 2023/7/27 9:54 with target value 17183
# exit_value = 17180.0 at 2023/7/25 13:05
# profit = 2350.0
# Buy to cover at 2023/7/27 10:05 with Close 17251.0
# Trade completed
#
# Sell at 2023/7/27 11:19 with target value 17196
# exit_value = 17190.0 at 2023/7/27 9:53
# profit = 200.0
# Buy to cover at 2023/7/27 11:21 with Close 17186.0
# Trade completed
#
# Sell at 2023/7/28 8:45 with target value 17233
# exit_value = 17192.0 at 2023/7/27 10:58
# profit = 3050.0
# Buy to cover at 2023/7/28 8:46 with Close 17164.0
# Trade completed
#
# Sell at 2023/7/31 11:08 with target value 17349
# exit_value = 17233.0 at 2023/7/27 13:09
# profit = 6350.0
# Buy to cover at 2023/7/31 11:15 with Close 17230.0
# Trade completed
#
# Sell at 2023/8/18 10:31 with target value 16459
# exit_value = 16452.0 at 2023/8/17 13:38
# profit = 1250.0
# Buy to cover at 2023/8/18 10:32 with Close 16433.0
# Trade completed
#
# Sell at 2023/8/25 11:18 with target value 16516
# exit_value = 16456.0 at 2023/8/18 10:29
# profit = 1250.0
# Buy to cover at 2023/8/25 12:11 with Close 16499.0
# Trade completed
#
# Sell at 2023/8/25 8:45 with target value 16722
# exit_value = 16516.0 at 2023/8/23 11:24
# profit = 9950.0
# Buy to cover at 2023/8/25 9:38 with Close 16514.0
# Trade completed
#
# Sell at 2023/9/7 8:54 with target value 16733
# exit_value = 16503.0 at 2023/8/29 11:59
# profit = 9950.0
# Buy to cover at 2023/9/7 11:37 with Close 16635.0
# Trade completed
#
# Sell at 2023/9/6 9:54 with target value 16752
# exit_value = 16725.0 at 2023/9/5 8:45
# profit = 1400.0
# Buy to cover at 2023/9/6 9:55 with Close 16723.0
# Trade completed
#
# Sell at 2023/9/19 11:57 with target value 16822
# exit_value = 16570.0 at 2023/9/13 9:50
# profit = 13050.0
# Buy to cover at 2023/9/20 9:16 with Close 16570.0
# Trade completed
#
# Sell at 2023/10/3 13:17 with target value 16580
# exit_value = 16361.0 at 2023/9/28 9:44
# profit = 15850.0
# Buy to cover at 2023/10/4 8:45 with Close 16265.0
# Trade completed
#
# Sell at 2023/10/18 9:08 with target value 16708
# exit_value = 16526.0 at 2023/10/6 11:39
# profit = 9450.0
# Buy to cover at 2023/10/18 9:43 with Close 16526.0
# Trade completed
#
# Sell at 2023/10/16 8:45 with target value 16757
# exit_value = 16702.0 at 2023/10/11 9:48
# profit = 5250.0
# Buy to cover at 2023/10/16 8:46 with Close 16663.0
# Trade completed
#
# Sell at 2023/10/13 12:02 with target value 16772
# exit_value = 16742.0 at 2023/10/13 8:45
# profit = 2000.0
# Buy to cover at 2023/10/13 12:03 with Close 16740.0
# Trade completed
#
# Sell at 2023/11/9 8:45 with target value 16767
# exit_value = 16707.0 at 2023/11/6 12:48
# profit = 3100.0
# Buy to cover at 2023/11/9 9:20 with Close 16705.0
# Trade completed
#
# Sell at 2023/11/16 10:01 with target value 17173
# exit_value = 17117.0 at 2023/11/15 9:44
# profit = 3050.0
# Buy to cover at 2023/11/16 10:08 with Close 17113.0
# Trade completed
#
# Sell at 2023/11/20 9:42 with target value 17213
# exit_value = 17170.0 at 2023/11/16 9:44
# profit = 2050.0
# Buy to cover at 2023/11/20 9:44 with Close 17170.0
# Trade completed
#
# Sell at 2023/11/17 13:25 with target value 17213
# exit_value = 17205.0 at 2023/11/17 10:35
# profit = 2050.0
# Buy to cover at 2023/11/20 8:45 with Close 17277.0
# Trade completed
#
# Sell at 2023/11/22 11:37 with target value 17406
# exit_value = 17212.0 at 2023/11/17 12:19
# profit = 2050.0
# Buy to cover at 2023/11/22 12:36 with Close 17290.0
# Trade completed
#
# Sell at 2023/11/30 9:53 with target value 17372
# exit_value = 17286.0 at 2023/11/24 12:22
# profit = 2050.0
# Buy to cover at 2023/11/30 10:39 with Close 17369.0
# Trade completed
#
# Sell at 2023/11/29 10:55 with target value 17381
# exit_value = 17371.0 at 2023/11/28 13:14
# profit = 950.0
# Buy to cover at 2023/11/29 10:56 with Close 17368.0
# Trade completed
#
# Sell at 2023/12/4 10:15 with target value 17393
# exit_value = 17378.0 at 2023/11/29 10:30
# profit = 950.0
# Buy to cover at 2023/12/4 11:57 with Close 17417.0
# Trade completed
#
# Sell at 2023/12/4 10:13 with target value 17400
# exit_value = 17391.0 at 2023/12/1 11:44
# profit = 950.0
# Buy to cover at 2023/12/4 10:14 with Close 17387.0
# Trade completed
#
# Sell at 2023/12/4 10:09 with target value 17419
# exit_value = 17398.0 at 2023/12/1 13:05
# profit = 950.0
# Buy to cover at 2023/12/4 10:10 with Close 17397.0
# Trade completed
#
# Sell at 2023/12/4 13:33 with target value 17421
# exit_value = 17417.0 at 2023/12/4 9:33
# profit = 250.0
# Buy to cover at 2023/12/4 13:34 with Close 17415.0
# Trade completed

# %%
profit_series = []
profit_fee_series =[]

# 創建 Series，並使用原始 DataFrame 的索引進行對齊
profit_series = pd.Series(profit_dict)
profit_fee_series = pd.Series(profit_fee_dict)

# 確保索引與 df 的索引對齊，並填充缺失值為 0
aligned_profit = profit_series.reindex(df.index).fillna(0)
aligned_profit_fee = profit_fee_series.reindex(df.index).fillna(0)

#大盤累計報酬
df['Close_diff'] = df['Close'].diff()*50
df['Cumulative_diff'] = df['Close_diff'].cumsum()

# 生成包含對齊後數據的 DataFrame
equity = pd.DataFrame({
    'profit': aligned_profit.cumsum(),
    'profit_fee_realized': aligned_profit_fee.cumsum(),
    'market_return': df['Cumulative_diff'] 
})


# 繪製資本曲線
equity.plot(grid=True, figsize=(12, 6))
# Out:
# <Axes: >

# %%
equity.to_excel('equity_data.xlsx', index=True)

# %%
# 計算交易勝率
total_trades = len(profit_fee_dict)  # 總交易數
winning_trades = sum(1 for profit in profit_fee_dict.values() if profit > 0)  # 獲利交易數
win_rate = winning_trades / total_trades if total_trades > 0 else 0  # 避免除以 0

# 顯示結果
print(f"交易總數: {total_trades}")
print(f"獲利交易數: {winning_trades}")
print(f"勝率: {win_rate:.2%}")

#計算夏普比率
avg_return = np.mean(profit_fee_list_realized)
std_return = np.std(profit_fee_list_realized)
risk_free_rate = 0.04  # 假設無風險利率為 0
sharpe_ratio = (avg_return - risk_free_rate) / std_return
print(f"Sharpe Ratio: {sharpe_ratio}")
# Out:
# 交易總數: 2318
# 獲利交易數: 2198
# 勝率: 94.82%
# Sharpe Ratio: 0.7654431764583615

# %%
# 計算每筆交易的持倉時間（出場索引 - 進場索引）
holding_times_short = [buytocover[i] - sellshort[i] for i in range(len(sellshort))] 
holding_times_long = [selltoover[i] - buylong[i] for i in range(len(buylong))] 
holding_times = holding_times_short + holding_times_long

# 使用 describe 來展示統計數值
holding_times_series = pd.Series(holding_times)
holding_times_series.describe()

holding_times_series.describe()
# Out:
# count    2405.000000
# mean       25.347609
# std        39.394657
# min         1.000000
# 25%         1.000000
# 50%         5.000000
# 75%        37.000000
# max       301.000000
# dtype: float64

# %%
#標住Long Entry

# 繪製 Close 價格圖表
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Close'], label='Close Price', color='black')

# 標註 long_entry 的位置
long_entries = df[df['Trough_value'].notna()]
plt.scatter(long_entries.index, long_entries['Trough_value'], color='red', label='Short Entry', marker='v', s=100)

#標註掛單點
long_entries = df[df['calculated_long_entry'].notna()]
plt.scatter(long_entries.index, long_entries['calculated_long_entry'], color='blue', label='Entry Point', marker='_', s=100)

# 添加標題和圖例
plt.title('Stock Prices with Short Entry Points')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

#限制觀察範圍
plt.xlim(50000,100000)
plt.ylim(min(df.loc[50000:100000, 'Close']) - 10, max(df.loc[50000:100000, 'Close']) + 10)

# 顯示圖表
plt.grid(True)
plt.show()

# %%
#標住進出場點
# 畫圖
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], label='Close Prices', color='black')

# 標註做多點（藍色）
plt.scatter(sellshort, df.loc[sellshort, 'Close'], color='blue', label='Entry (Sell Short)', marker='^', s=100)
plt.scatter(selltoover, df.loc[selltoover, 'Close'], color='blue', label='Entry (Selltoover)', marker='^', s=100)

# 標註做空點（紅色）
plt.scatter(buytocover, df.loc[buytocover, 'Close'], color='red', label='Exit (Buy to Cover)', marker='v', s=100)
plt.scatter(buylong, df.loc[buylong, 'Close'], color='red', label='Exit (buylong)', marker='v', s=100)

# 添加圖例和標籤
plt.title('Trading Strategy: Short Entry and Exit Points')
plt.xlabel('Index')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)

#限制觀察範圍
plt.xlim(921600, 921750)
plt.ylim(min(df.loc[921600:921750, 'Close']) - 10, max(df.loc[921600:921750, 'Close']) + 10)

# 顯示圖表
plt.show()

# %%
from scipy import stats

# 計算策略的實現收益
profit_fee_list_realized = np.array(profit_fee_list_realized)

# 檢查是否有足夠的交易來進行檢驗
if len(profit_fee_list_realized) > 1:
    # 設定假設檢驗的零假設為：策略的平均收益等於0（即無顯著收益）
    t_statistic, p_value = stats.ttest_1samp(profit_fee_list_realized, 0)

    print(f"T-Statistic: {t_statistic}")
    print(f"P-Value: {p_value}")

    # 判斷是否拒絕零假設
    alpha = 0.05  # 顯著性水準（通常為0.05）
    if p_value < alpha:
        print("策略具有顯著性，收益顯著大於0")
    else:
        print("策略不具有顯著性，無法證明收益顯著大於0")
else:
    print("交易次數不足，無法進行 T 檢驗")

# %%
equity_curve = pd.Series(profit_fee_list_realized).cumsum()

# 計算最大回策 (MDD)
def MDD(equity_curve):
    cumulative_max = equity_curve.cummax()
    drawdown = equity_curve - cumulative_max
    max_drawdown = drawdown.min()
    return max_drawdown

max_drawdown = MDD(equity_curve)

# 如果需要以百分比顯示，可以如下進行轉換
max_drawdown_percentage = (max_drawdown / equity_curve.cummax().iloc[-1]) * 100
print(f"策略的MDD為: {max_drawdown_percentage:.2f}%")
# Out:
# 策略的MDD為: -0.21%

# %%
equity.to_csv('equity.csv', index=False)

# %%
initial_capital = 100000  # 假設初始資金為 100,000
# 將損益轉換成 DataFrame 並包含日期資訊
profit_df = pd.DataFrame(list(profit_fee_dict.items()), columns=['Index', 'Profit_Fee'])
profit_df['Date'] = df.loc[profit_df['Index'], 'Date'].values

# 步驟1：提取年份和月份
profit_df['Year'] = pd.to_datetime(profit_df['Date']).dt.year
profit_df['Month'] = pd.to_datetime(profit_df['Date']).dt.month

# 步驟2：計算每月的總報酬
monthly_profit = profit_df.groupby(['Year', 'Month'])['Profit_Fee'].sum().reset_index()
monthly_profit['Profit_Fee'] = (monthly_profit['Profit_Fee'] / initial_capital) * 100

# 步驟3：將數據轉換成適合熱力圖的格式
heatmap_data = monthly_profit.pivot(index='Year', columns='Month', values='Profit_Fee')

# 步驟4：繪製熱力圖
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=True, fmt=".2f", center=0, linewidths=0.5)
plt.title('Strategy - Monthly Returns (%)')
plt.xlabel('Month')
plt.ylabel('Year')
plt.show()
