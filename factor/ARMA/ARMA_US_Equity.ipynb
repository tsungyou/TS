# %%
import pandas as pd
import json
with open("zackRanks_SP500.json", "r") as f:
    data = json.load(f)

list_ = list(data.keys())
list_
# Out:
# ['MSFT',
#  'AAPL',
#  'NVDA',
#  'AMZN',
#  'META',
#  'GOOGL',
#  'GOOG',
#  'AVGO',
#  'TSLA',
#  'LLY',
#  'JPM',
#  'UNH',
#  'V',
#  'XOM',
#  'JNJ',
#  'MA',
#  'PG',
#  'HD',
#  'COST',
#  'MRK',
#  'ABBV',
#  'ADBE',
#  'CRM',
#  'AMD',
#  'CVX',
#  'NFLX',
#  'WMT',
#  'BAC',
#  'PEP',
#  'KO',
#  'ACN',
#  'MCD',
#  'TMO',
#  'CSCO',
#  'ABT',
#  'LIN',
#  'CMCSA',
#  'INTC',
#  'WFC',
#  'VZ',
#  'ORCL',
#  'INTU',
#  'DIS',
#  'AMGN',
#  'IBM',
#  'QCOM',
#  'DHR',
#  'NOW',
#  'CAT',
#  'PFE',
#  'UNP',
#  'TXN',
#  'SPGI',
#  'GE',
#  'PM',
#  'AMAT',
#  'UBER',
#  'HON',
#  'ISRG',
#  'COP',
#  'RTX',
#  'T',
#  'GS',
#  'NKE',
#  'LOW',
#  'BKNG',
#  'NEE',
#  'BA',
#  'PLD',
#  'MDT',
#  'ELV',
#  'AXP',
#  'SYK',
#  'VRTX',
#  'MS',
#  'LRCX',
#  'TJX',
#  'BLK',
#  'C',
#  'SBUX',
#  'DE',
#  'PANW',
#  'PGR',
#  'UPS',
#  'MDLZ',
#  'ADP',
#  'REGN',
#  'CB',
#  'BMY',
#  'ETN',
#  'GILD',
#  'ADI',
#  'MMC',
#  'CVS',
#  'LMT',
#  'MU',
#  'SCHW',
#  'BSX',
#  'AMT',
#  'BX',
#  'CI',
#  'ZTS',
#  'FI',
#  'TMUS',
#  'SNPS',
#  'KLAC',
#  'CDNS',
#  'EQIX',
#  'SO',
#  'CME',
#  'DUK',
#  'ICE',
#  'SHW',
#  'ITW',
#  'MO',
#  'CSX',
#  'SLB',
#  'BDX',
#  'CL',
#  'WM',
#  'MCK',
#  'EOG',
#  'PYPL',
#  'CMG',
#  'ANET',
#  'USB',
#  'TGT',
#  'PSX',
#  'NOC',
#  'MPC',
#  'ABNB',
#  'MCO',
#  'ORLY',
#  'TDG',
#  'HCA',
#  'APH',
#  'PNC',
#  'GD',
#  'AON',
#  'PH',
#  'MAR',
#  'TT',
#  'ROP',
#  'FCX',
#  'APD',
#  'FDX',
#  'NXPI',
#  'ADSK',
#  'PXD',
#  'GM',
#  'MSI',
#  'NSC',
#  'PCAR',
#  'CTAS',
#  'EMR',
#  'LULU',
#  'MMM',
#  'COF',
#  'ECL',
#  'AJG',
#  'TFC',
#  'HLT',
#  'AIG',
#  'AZO',
#  'TRV',
#  'WELL',
#  'EW',
#  'ROST',
#  'MSCI',
#  'VLO',
#  'CCI',
#  'DXCM',
#  'HUM',
#  'F',
#  'MCHP',
#  'NUE',
#  'CARR',
#  'SPG',
#  'O',
#  'SRE',
#  'PSA',
#  'AFL',
#  'TEL',
#  'MET',
#  'DHI',
#  'IDXX',
#  'BK',
#  'DLR',
#  'URI',
#  'WMB',
#  'CPRT',
#  'FTNT',
#  'AEP',
#  'KMB',
#  'SYY',
#  'ALL',
#  'MNST',
#  'CNC',
#  'NEM',
#  'OKE',
#  'STZ',
#  'GWW',
#  'LHX',
#  'PAYX',
#  'AMP',
#  'FAST',
#  'CEG',
#  'HES',
#  'COR',
#  'CTSH',
#  'D',
#  'IQV',
#  'A',
#  'OXY',
#  'PRU',
#  'GIS',
#  'DOW',
#  'LEN',
#  'AME',
#  'CHTR',
#  'FIS',
#  'YUM',
#  'OTIS',
#  'JCI',
#  'BIIB',
#  'IT',
#  'PCG',
#  'VRSK',
#  'RSG',
#  'ODFL',
#  'EXC',
#  'GPN',
#  'CSGP',
#  'CMI',
#  'EA',
#  'MRNA',
#  'PPG',
#  'XEL',
#  'KMI',
#  'IR',
#  'CTVA',
#  'HAL',
#  'KDP',
#  'MLM',
#  'ED',
#  'VICI',
#  'EL',
#  'ON',
#  'ACGL',
#  'EXR',
#  'CDW',
#  'KR',
#  'VMC',
#  'RCL',
#  'EFX',
#  'FICO',
#  'ADM',
#  'KHC',
#  'ROK',
#  'HSY',
#  'DG',
#  'PEG',
#  'BKR',
#  'ANSS',
#  'PWR',
#  'RMD',
#  'WST',
#  'FTV',
#  'FANG',
#  'DLTR',
#  'KEYS',
#  'DVN',
#  'CAH',
#  'XYL',
#  'DD',
#  'DFS',
#  'CBRE',
#  'ZBH',
#  'HIG',
#  'TTWO',
#  'MTD',
#  'EIX',
#  'WEC',
#  'WTW',
#  'DAL',
#  'AVB',
#  'HPQ',
#  'GLW',
#  'ULTA',
#  'CHD',
#  'TSCO',
#  'TROW',
#  'SBAC',
#  'BR',
#  'AWK',
#  'WY',
#  'LYB',
#  'WAB',
#  'FITB',
#  'APTV',
#  'MTB',
#  'STT',
#  'ILMN',
#  'PHM',
#  'NVR',
#  'WBD',
#  'HWM',
#  'DTE',
#  'STE',
#  'PTC',
#  'BLDR',
#  'EBAY',
#  'ETR',
#  'DOV',
#  'FLT',
#  'RJF',
#  'MOH',
#  'IFF',
#  'EQR',
#  'EXPE',
#  'GPC',
#  'IRM',
#  'TDY',
#  'HPE',
#  'BAX',
#  'NDAQ',
#  'DRI',
#  'CBOE',
#  'PPL',
#  'ALGN',
#  'INVH',
#  'FE',
#  'ES',
#  'TRGP',
#  'ARE',
#  'LH',
#  'WAT',
#  'CTRA',
#  'VTR',
#  'AKAM',
#  'COO',
#  'EXPD',
#  'WDC',
#  'STLD',
#  'GRMN',
#  'BRO',
#  'HBAN',
#  'HOLX',
#  'NTAP',
#  'FDS',
#  'LVS',
#  'AEE',
#  'CLX',
#  'HUBB',
#  'OMC',
#  'LUV',
#  'VRSN',
#  'CNP',
#  'TYL',
#  'AXON',
#  'BALL',
#  'CINF',
#  'RF',
#  'PFG',
#  'MKC',
#  'J',
#  'ATO',
#  'SWKS',
#  'CMS',
#  'WRB',
#  'CCL',
#  'EG',
#  'TXT',
#  'STX',
#  'NTRS',
#  'JBHT',
#  'WBA',
#  'AVY',
#  'SYF',
#  'JBL',
#  'EPAM',
#  'IEX',
#  'TSN',
#  'FSLR',
#  'SNA',
#  'CFG',
#  'MAS',
#  'LDOS',
#  'ESS',
#  'DPZ',
#  'PKG',
#  'TER',
#  'LW',
#  'MAA',
#  'CE',
#  'EQT',
#  'K',
#  'CF',
#  'SWK',
#  'POOL',
#  'DGX',
#  'ENPH',
#  'VTRS',
#  'BBY',
#  'CAG',
#  'AMCR',
#  'KEY',
#  'NDSN',
#  'UAL',
#  'HST',
#  'SJM',
#  'ALB',
#  'MRO',
#  'PODD',
#  'GEN',
#  'RVTY',
#  'BG',
#  'IPG',
#  'TRMB',
#  'LYV',
#  'LKQ',
#  'IP',
#  'KIM',
#  'ZBRA',
#  'LNT',
#  'ROL',
#  'JKHY',
#  'PNR',
#  'NRG',
#  'MGM',
#  'JNPR',
#  'EVRG',
#  'TAP',
#  'TFX',
#  'KMX',
#  'AES',
#  'TECH',
#  'CRL',
#  'INCY',
#  'UDR',
#  'FFIV',
#  'ALLE',
#  'DAY',
#  'GL',
#  'NI',
#  'MTCH',
#  'REG',
#  'HII',
#  'WRK',
#  'PEAK',
#  'MOS',
#  'CPT',
#  'EMN',
#  'CHRW',
#  'HSIC',
#  'QRVO',
#  'BBWI',
#  'UHS',
#  'APA',
#  'AOS',
#  'NWSA',
#  'BXP',
#  'CTLT',
#  'CZR',
#  'AAL',
#  'PAYC',
#  'WYNN',
#  'TPR',
#  'AIZ',
#  'CPB',
#  'HRL',
#  'MKTX',
#  'RHI',
#  'FOXA',
#  'BWA',
#  'ETSY',
#  'PNW',
#  'BEN',
#  'FRT',
#  'NCLH',
#  'XRAY',
#  'IVZ',
#  'FMC',
#  'PARA',
#  'GNRC',
#  'CMA',
#  'BIO',
#  'HAS',
#  'ZION',
#  'WHR',
#  'DVA',
#  'RL',
#  'VFC',
#  'MHK',
#  'GPS']

# %%
from ib_insync import *
import pandas as pd

def GetDataDf(contract):
    data = ib.reqHistoricalData(
        contract, endDateTime='', durationStr='9 D',
        barSizeSetting='5 mins', whatToShow='TRADES', useRTH=False)
    df = pd.DataFrame(data)
    return df

ib = IB()
ib.connect('127.0.0.1', 4001, clientId=1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 12
#       9     return df
#      11 ib = IB()
# ---> 12 ib.connect('127.0.0.1', 4001, clientId=1)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
#     277         account: Main account to receive updates for.
#     278     """
# --> 279     return self._run(self.connectAsync(
#     280         host, port, clientId, timeout, readonly, account))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:318, in IB._run(self, *awaitables)
#     317 def _run(self, *awaitables: Awaitable):
# --> 318     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/util.py:341, in run(timeout, *awaitables)
#     339 globalErrorEvent.connect(onError)
#     340 try:
# --> 341     result = loop.run_until_complete(task)
#     342 except asyncio.CancelledError as e:
#     343     raise globalErrorEvent.value() or e
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py:630, in BaseEventLoop.run_until_complete(self, future)
#     619 """Run until the Future is done.
#     620
#     621 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     627 Return the Future's result, or raise its exception.
#     628 """
#     629 self._check_closed()
# --> 630 self._check_running()
#     632 new_task = not futures.isfuture(future)
#     633 future = tasks.ensure_future(future, loop=self)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py:589, in BaseEventLoop._check_running(self)
#     587 def _check_running(self):
#     588     if self.is_running():
# --> 589         raise RuntimeError('This event loop is already running')
#     590     if events._get_running_loop() is not None:
#     591         raise RuntimeError(
#     592             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
# Error 10275, reqId -1: Positions info is not available for account(s): U12615382 until the application is finished and approved.

# %%
from ib_insync import *
# util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=2)

contract = Stock('TSLA')
bars = ib.reqHistoricalData(
    contract, endDateTime='', durationStr='30 D',
    barSizeSetting='1 D', whatToShow='MIDPOINT', useRTH=True)

# convert to pandas dataframe (pandas needs to be installed):
df = util.df(bars)
print(df)
# Out:
# Peer closed connection. clientId 2 already in use?
# Task exception was never retrieved
# future: <Task finished name='Task-17' coro=<IB.connectAsync() done, defined at /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:1739> exception=ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 7497)")>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py", line 1748, in connectAsync
#     await self.client.connectAsync(host, port, clientId, timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/client.py", line 211, in connectAsync
#     await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 489, in wait_for
#     return fut.result()
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/connection.py", line 39, in connectAsync
#     self.transport, _ = await loop.create_connection(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1086, in create_connection
#     raise exceptions[0]
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1070, in create_connection
#     sock = await self._connect_sock(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 974, in _connect_sock
#     await self.sock_connect(sock, address)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/selector_events.py", line 638, in sock_connect
#     return await fut
#            ^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/selector_events.py", line 678, in _sock_connect_cb
#     raise OSError(err, f'Connect call failed {address}')
# ConnectionRefusedError: [Errno 61] Connect call failed ('127.0.0.1', 7497)
# Task exception was never retrieved
# future: <Task finished name='Task-19' coro=<IB.connectAsync() done, defined at /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:1739> exception=ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 7497)")>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py", line 1748, in connectAsync
#     await self.client.connectAsync(host, port, clientId, timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/client.py", line 211, in connectAsync
#     await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 489, in wait_for
#     return fut.result()
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/connection.py", line 39, in connectAsync
#     self.transport, _ = await loop.create_connection(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1086, in create_connection
#     raise exceptions[0]
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1070, in create_connection
#     sock = await self._connect_sock(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 974, in _connect_sock
#     await self.sock_connect(sock, address)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/selector_events.py", line 638, in sock_connect
#     return await fut
#            ^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/selector_events.py", line 678, in _sock_connect_cb
#     raise OSError(err, f'Connect call failed {address}')
# ConnectionRefusedError: [Errno 61] Connect call failed ('127.0.0.1', 7497)
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<IB.connectAsync() done, defined at /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:1739> exception=TimeoutError()>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 500, in wait_for
#     return fut.result()
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/futures.py", line 198, in result
#     raise exc
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 279, in __step
#     result = coro.throw(exc)
#              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 694, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/futures.py", line 287, in __await__
#     yield self  # This tells Task to wait for completion.
#     ^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 349, in __wakeup
#     future.result()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/futures.py", line 198, in result
#     raise exc
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 277, in __step
#     result = coro.send(None)
#              ^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py", line 1748, in connectAsync
#     await self.client.connectAsync(host, port, clientId, timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/client.py", line 217, in connectAsync
#     await asyncio.wait_for(self.apiStart, timeout)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/tasks.py", line 502, in wait_for
#     raise exceptions.TimeoutError() from exc
# TimeoutError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 # util.startLoop()  # uncomment this line when in a notebook
#       4 ib = IB()
# ----> 5 ib.connect('127.0.0.1', 7497, clientId=2)
#       7 contract = Stock('TSLA')
#       8 bars = ib.reqHistoricalData(
#       9     contract, endDateTime='', durationStr='30 D',
#      10     barSizeSetting='1 D', whatToShow='MIDPOINT', useRTH=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)
#     277         account: Main account to receive updates for.
#     278     """
# --> 279     return self._run(self.connectAsync(
#     280         host, port, clientId, timeout, readonly, account))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/ib.py:318, in IB._run(self, *awaitables)
#     317 def _run(self, *awaitables: Awaitable):
# --> 318     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ib_insync/util.py:341, in run(timeout, *awaitables)
#     339 globalErrorEvent.connect(onError)
#     340 try:
# --> 341     result = loop.run_until_complete(task)
#     342 except asyncio.CancelledError as e:
#     343     raise globalErrorEvent.value() or e
#
# File ~/Library/Python/3.11/lib/python/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/Library/Python/3.11/lib/python/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:
# API connection failed: TimeoutError()

# %%
from ib_insync import IB

# Start the event loop if running in a notebook
from ib_insync import util
util.startLoop()

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=6)
# Out:
# Error 10275, reqId -1: Positions info is not available for account(s): U12615382 until the application is finished and approved.
# <IB connected to 127.0.0.1:7497 clientId=6>

# %%
contract = Stock("TSLA", "SMART", "USD")
# contract = Forex("EURUSD")
bars = ib.reqHistoricalData(
    contract, endDateTime='', durationStr='30 D',
    barSizeSetting='1 day', whatToShow='ADJUSTED_LAST', useRTH=True)
# Out:
# Error 162, reqId 8: Historical Market Data Service error message:No market data permissions for ISLAND STK. Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details., contract: Stock(symbol='TSLA', exchange='SMART', currency='USD')
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.

# %%
for bar in bars:
    print(bar)
